# %%
from boostvqe.utils import *

# %%
b_rand2 = [a+b for a,b in zip(np.random.rand(10)*.2,np.linspace(1,0,10))]
eo_d = MagneticFieldEvolutionOracle.load(b_rand2)
eo_d_Ising = IsingNNEvolutionOracle.load([0]*10,[1]*10)
# Out:
# [Qibo 0.2.9|INFO|2024-07-16 14:14:35]: Using tensorflow backend on /device:CPU:0
# INFO:qibo.config:Using tensorflow backend on /device:CPU:0

# %%
c1 = eo_d_Ising.circuit(0.1)
eo_d_Ising.please_use_coarse_compiling = True
c2 = eo_d_Ising.circuit(0.1)
np.linalg.norm(c1.unitary()-c2.unitary())
# Out:
# 0.0

# %%
GroupCommutatorIterationWithEvolutionOracles.count_gates(c1,gates.CNOT)
# Out:
# 10

# %%
GroupCommutatorIterationWithEvolutionOracles.count_gates(c2,gates.CNOT)
# Out:
# 10

# %%
print(c2.draw())
# Out:
# q0: ─o────o──────────────────────X─RZ─X─RZ─
# q1: ─X─RZ─X─o────o───────────────|────|─RZ─
# q2: ────────X─RZ─X─o────o────────|────|─RZ─
# q3: ───────────────X─RZ─X─o────o─|────|─RZ─
# q4: ──────────────────────X─RZ─X─o────o─RZ─
