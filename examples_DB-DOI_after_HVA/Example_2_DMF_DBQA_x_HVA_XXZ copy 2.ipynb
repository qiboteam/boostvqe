# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
from copy import deepcopy

from qibo.backends import construct_backend
from qibo import hamiltonians, Circuit, gates, set_backend
from qibo import gates, symbols
from qibo.gates import Unitary, CNOT, CZ
from qibo.symbols import X, Y, Z
from qibo import hamiltonians
from qibo.hamiltonians import Hamiltonian, SymbolicHamiltonian

from dbf_dbqa.group_commutator_iteration import GroupCommutatorIteration, DoubleBracketRotationApproximationType
from dbf_dbqa.utils_XXZ_compilation import *
# Out:
# /home/marek/.local/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
L = 16
H_XXZ = XXZ_compilation_line(L,gateset="CNOT")

E0,E1 = H_XXZ.eigenergies_ED()
print(E0,E1)
# Out:
# [Qibo 0.2.21|INFO|2025-08-04 11:17:38]: Using qibojit (numba) backend on /CPU:0
# -27.646948582300364 -26.769841716098917

# %%
init_circ, _, _ = H_XXZ.find_XXZ_HVA_circuit(nlayers=1)

init_circ2, f, _ = H_XXZ.find_XXZ_HVA_circuit(nlayers=1,warm_start_qc=init_circ,initial_params=[-.1,-.1])

init_circ2, f, _ = H_XXZ.find_XXZ_HVA_circuit(nlayers=1,warm_start_qc=init_circ,initial_params=[.2,.31])
# Out:
# Initial loss: -24.7651208337816
# -26.93772471970199
#    Normal return from subroutine COBYLA
#
#    NFVALS =   17   F =-2.693772E+01    MAXCV = 0.000000E+00
#    X = 2.221721E-01   1.218286E-01
#
# [0.22217206 0.12182855]
# Initial loss: -26.904363240711987
# -26.97849010575614
#    Normal return from subroutine COBYLA
#
#    NFVALS =   19   F =-2.697849E+01    MAXCV = 0.000000E+00
#    X =-6.411709E-02  -6.678980E-02
#
# [-0.06411709 -0.0667898 ]
# Initial loss: -21.13954547153971
# -26.997404475749256
#    Normal return from subroutine COBYLA
#
#    NFVALS =   19   F =-2.699740E+01    MAXCV = 0.000000E+00
#    X =-1.830630E-02  -1.261798E-02
#
# [-0.0183063  -0.01261798]

# %%
init_circ2, _, _ = H_XXZ.find_XXZ_HVA_circuit(nlayers=2)
init_circ3, _, _ = H_XXZ.find_XXZ_HVA_circuit(nlayers=3)
init_circ4, _, _ = H_XXZ.find_XXZ_HVA_circuit(nlayers=4)
# Out:
# Initial loss: -19.588221556805085
# -27.12220684833791
# [1.18169678 0.11669787 0.21851257 0.23955009]
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =   40   F =-2.712221E+01    MAXCV = 0.000000E+00
#    X = 1.181697E+00   1.166979E-01   2.185126E-01   2.395501E-01
# Initial loss: -21.070601367862075
# -27.202199723147682
#    Normal return from subroutine COBYLA
#
#    NFVALS =   38   F =-2.720220E+01    MAXCV = 0.000000E+00
#    X = 1.606796E-01   1.410868E-01  -1.632210E-01  -3.969013E-02  -1.859634E-01
#       -2.557837E-01
#
# [ 0.16067956  0.14108676 -0.16322097 -0.03969013 -0.18596341 -0.25578365]
# Initial loss: -20.283433659217483
# -27.10077212841347
#    Normal return from subroutine COBYLA
#
#    NFVALS =   57   F =-2.710077E+01    MAXCV = 0.000000E+00
#    X = 2.138329E-01   4.927899E-02   4.255495E-02   1.167289E-01   1.113534E-01
#        1.559514E-02   2.089684E-02  -5.373837E-03
#
# [ 0.21383289  0.04927899  0.04255495  0.11672894  0.11135338  0.01559514
#   0.02089684 -0.00537384]

# %%
fs = []
f2 = []
for t1 in np.linspace(-.31,.3,8):
    for t2 in np.linspace(-.3,.3,8):
        init_circ2, f, _ = H_XXZ.find_XXZ_HVA_circuit(nlayers=1,warm_start_qc=init_circ,initial_params=[t1,t2])
        fs.append(f)
        f2.append([t1,t2,f])
min_f = min(fs)
print("Minimum function value found:", min_f)
# Out:
# Initial loss: -13.389988322279367
# -26.355167715702372
# [-0.02967652 -0.01837594]
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =   20   F =-2.635517E+01    MAXCV = 0.000000E+00
#    X =-2.967652E-02  -1.837594E-02
# Initial loss: -15.324674298683219
# capi_return is NULL
# Call-back cb_calcfc_in__cobyla__user__routines failed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/numba/core/serialize.py:30, in _numba_unpickle(address, bytedata, hashed)
#      27 _unpickled_memo = {}
# ---> 30 def _numba_unpickle(address, bytedata, hashed):
#      31     """Used by `numba_unpickle` from _helperlib.c
#      32
#      33     Parameters
#    (...)
#      42         unpickled object
#      43     """
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[9], line 5
#       3 for t1 in np.linspace(-.31,.3,8):
#       4     for t2 in np.linspace(-.3,.3,8):
# ----> 5         init_circ2, f, _ = H_XXZ.find_XXZ_HVA_circuit(nlayers=1,warm_start_qc=init_circ,initial_params=[t1,t2])
#       6         fs.append(f)
#       7         f2.append([t1,t2,f])
#
# File ~/Projectes_git/boostvqe/src/dbf_dbqa/utils_XXZ_compilation.py:121, in XXZ_compilation_line.find_XXZ_HVA_circuit(self, max_evals, nlayers, initial_params, warm_start_qc)
#     118 print('Initial loss:', HVA_cost_function(initial_params))
#     119 from scipy.optimize import minimize
# --> 121 result = minimize(
#     122     HVA_cost_function,
#     123     initial_params,
#     124     method="COBYLA",
#     125     options={"disp": True, "maxiter": max_evals},
#     126     tol=1e-2,
#     127 )
#     129 print(result.fun)
#     130 print(result.x)
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_minimize.py:744, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#     743 elif meth == 'cobyla':
# --> 744     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     745                            bounds=bounds, **options)
#     746 elif meth == 'cobyqa':
#     747     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     748                            **options)
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:293, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     290         callback(np.copy(x))
#     292 info = np.zeros(4, np.float64)
# --> 293 xopt, info = cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     294                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     295                               dinfo=info, callback=wrapped_callback)
#     297 if info[3] > catol:
#     298     # Check constraint violation
#     299     info[0] = 4
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:281, in _minimize_cobyla.<locals>.calcfc(x, con)
#     280 def calcfc(x, con):
# --> 281     f = sf.fun(x)
#     282     i = 0
#     283     for size, c in izip(cons_lengths, constraints):
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:326, in ScalarFunction.fun(self, x)
#     324 if not np.array_equal(x, self.x):
#     325     self._update_x(x)
# --> 326 self._update_fun()
#     327 return self.f
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:295, in ScalarFunction._update_fun(self)
#     293 def _update_fun(self):
#     294     if not self.f_updated:
# --> 295         fx = self._wrapped_fun(self.x)
#     296         if fx < self._lowest_f:
#     297             self._lowest_x = self.x
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# File ~/Projectes_git/boostvqe/src/dbf_dbqa/utils_XXZ_compilation.py:113, in XXZ_compilation_line.find_XXZ_HVA_circuit.<locals>.HVA_cost_function(parameters)
#     110 for n in range(nlayers):
#     111     qc = self.XXZ_HVA_circuit(parameters[2*n], parameters[2*n+1], qc=qc)
#     112 return self.expectation(
# --> 113     self.backend.execute_circuit(circuit=qc).state())
#
# File ~/.local/lib/python3.12/site-packages/qibo/backends/numpy.py:474, in NumpyBackend.execute_circuit(self, circuit, initial_state, nshots)
#     467     state = (
#     468         self.zero_state(nqubits)
#     469         if initial_state is None
#     470         else self.cast(initial_state)
#     471     )
#     473     for gate in circuit.queue:
# --> 474         state = gate.apply(self, state, nqubits)
#     476 if circuit.has_unitary_channel:
#     477     # here we necessarily have `density_matrix=True`, otherwise
#     478     # execute_circuit_repeated would have been called
#     479     if circuit.measurements:
#
# File ~/.local/lib/python3.12/site-packages/qibo/gates/abstract.py:563, in Gate.apply(self, backend, state, nqubits)
#     562 def apply(self, backend, state, nqubits):
# --> 563     return backend.apply_gate(self, state, nqubits)
#
# File ~/.local/lib/python3.12/site-packages/qibojit/backends/cpu.py:178, in NumbaBackend.apply_gate(self, gate, state, nqubits)
#     176 if len(targets) == 1:
#     177     op = GATE_OPS.get(gate.__class__.__name__, "apply_gate")
# --> 178     return self.one_qubit_base(state, nqubits, *targets, op, matrix, qubits)
#     179 elif len(targets) == 2:
#     180     op = GATE_OPS.get(gate.__class__.__name__, "apply_two_qubit_gate")
#
# File ~/.local/lib/python3.12/site-packages/qibojit/backends/cpu.py:112, in NumbaBackend.one_qubit_base(self, state, nqubits, target, kernel, gate, qubits)
#     110 if ncontrols:
#     111     kernel = getattr(self.gates, "multicontrol_{}_kernel".format(kernel))
# --> 112     return kernel(state, gate, qubits, nstates, m)
#     113 kernel = getattr(self.gates, "{}_kernel".format(kernel))
#     114 return kernel(state, gate, nstates, m)
#
# SystemError: CPUDispatcher(<function multicontrol_apply_x_kernel at 0x7380376ca3e0>) returned a result with an exception set

# %%
for i in range(1,6):
    init_circ, _, _ = H_XXZ.find_XXZ_HVA_circuit(nlayers=i)
# Out:
# Initial loss: -24.7651208337816
# -26.93772471970199
#    Normal return from subroutine COBYLA
#
#    NFVALS =   17   F =-2.693772E+01    MAXCV = 0.000000E+00
#    X = 2.221721E-01   1.218286E-01
#
# [0.22217206 0.12182855]
# Initial loss: -19.588221556805085
# -27.12220684833791
#    Normal return from subroutine COBYLA
#
#    NFVALS =   40   F =-2.712221E+01    MAXCV = 0.000000E+00
#    X = 1.181697E+00   1.166979E-01   2.185126E-01   2.395501E-01
#
# [1.18169678 0.11669787 0.21851257 0.23955009]
# Initial loss: -21.070601367862075
# capi_return is NULL
# Call-back cb_calcfc_in__cobyla__user__routines failed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/numba/core/serialize.py:30, in _numba_unpickle(address, bytedata, hashed)
#      27 _unpickled_memo = {}
# ---> 30 def _numba_unpickle(address, bytedata, hashed):
#      31     """Used by `numba_unpickle` from _helperlib.c
#      32
#      33     Parameters
#    (...)
#      42         unpickled object
#      43     """
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 for i in range(1,6):
# ----> 2     init_circ, _, _ = H_XXZ.find_XXZ_HVA_circuit(nlayers=i)
#
# File ~/Projectes_git/boostvqe/src/dbf_dbqa/utils_XXZ_compilation.py:121, in XXZ_compilation_line.find_XXZ_HVA_circuit(self, max_evals, nlayers, initial_params, warm_start_qc)
#     118 print('Initial loss:', HVA_cost_function(initial_params))
#     119 from scipy.optimize import minimize
# --> 121 result = minimize(
#     122     HVA_cost_function,
#     123     initial_params,
#     124     method="COBYLA",
#     125     options={"disp": True, "maxiter": max_evals},
#     126     tol=1e-2,
#     127 )
#     129 print(result.fun)
#     130 print(result.x)
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_minimize.py:744, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#     743 elif meth == 'cobyla':
# --> 744     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     745                            bounds=bounds, **options)
#     746 elif meth == 'cobyqa':
#     747     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     748                            **options)
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:293, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     290         callback(np.copy(x))
#     292 info = np.zeros(4, np.float64)
# --> 293 xopt, info = cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     294                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     295                               dinfo=info, callback=wrapped_callback)
#     297 if info[3] > catol:
#     298     # Check constraint violation
#     299     info[0] = 4
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:281, in _minimize_cobyla.<locals>.calcfc(x, con)
#     280 def calcfc(x, con):
# --> 281     f = sf.fun(x)
#     282     i = 0
#     283     for size, c in izip(cons_lengths, constraints):
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:326, in ScalarFunction.fun(self, x)
#     324 if not np.array_equal(x, self.x):
#     325     self._update_x(x)
# --> 326 self._update_fun()
#     327 return self.f
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:295, in ScalarFunction._update_fun(self)
#     293 def _update_fun(self):
#     294     if not self.f_updated:
# --> 295         fx = self._wrapped_fun(self.x)
#     296         if fx < self._lowest_f:
#     297             self._lowest_x = self.x
#
# File ~/.local/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# File ~/Projectes_git/boostvqe/src/dbf_dbqa/utils_XXZ_compilation.py:113, in XXZ_compilation_line.find_XXZ_HVA_circuit.<locals>.HVA_cost_function(parameters)
#     110 for n in range(nlayers):
#     111     qc = self.XXZ_HVA_circuit(parameters[2*n], parameters[2*n+1], qc=qc)
#     112 return self.expectation(
# --> 113     self.backend.execute_circuit(circuit=qc).state())
#
# File ~/.local/lib/python3.12/site-packages/qibo/backends/numpy.py:474, in NumpyBackend.execute_circuit(self, circuit, initial_state, nshots)
#     467     state = (
#     468         self.zero_state(nqubits)
#     469         if initial_state is None
#     470         else self.cast(initial_state)
#     471     )
#     473     for gate in circuit.queue:
# --> 474         state = gate.apply(self, state, nqubits)
#     476 if circuit.has_unitary_channel:
#     477     # here we necessarily have `density_matrix=True`, otherwise
#     478     # execute_circuit_repeated would have been called
#     479     if circuit.measurements:
#
# File ~/.local/lib/python3.12/site-packages/qibo/gates/abstract.py:563, in Gate.apply(self, backend, state, nqubits)
#     562 def apply(self, backend, state, nqubits):
# --> 563     return backend.apply_gate(self, state, nqubits)
#
# File ~/.local/lib/python3.12/site-packages/qibojit/backends/cpu.py:178, in NumbaBackend.apply_gate(self, gate, state, nqubits)
#     176 if len(targets) == 1:
#     177     op = GATE_OPS.get(gate.__class__.__name__, "apply_gate")
# --> 178     return self.one_qubit_base(state, nqubits, *targets, op, matrix, qubits)
#     179 elif len(targets) == 2:
#     180     op = GATE_OPS.get(gate.__class__.__name__, "apply_two_qubit_gate")
#
# File ~/.local/lib/python3.12/site-packages/qibojit/backends/cpu.py:114, in NumbaBackend.one_qubit_base(self, state, nqubits, target, kernel, gate, qubits)
#     112     return kernel(state, gate, qubits, nstates, m)
#     113 kernel = getattr(self.gates, "{}_kernel".format(kernel))
# --> 114 return kernel(state, gate, nstates, m)
#
# SystemError: CPUDispatcher(<function apply_gate_kernel at 0x738038166e80>) returned a result with an exception set

# %% [markdown]
# ## DBQA with Diagonal B-field (DBF)

# %%
B_i = [1]*L
dbf = hamiltonians.SymbolicHamiltonian(
    sum([ B_i[i] * Z(i) for i in range(L)]))

# %%
gci_hva = GroupCommutatorIteration(
    h=deepcopy(H_XXZ),
    preparation_circuit=init_circ,
    double_bracket_rotation_approximation_type=DoubleBracketRotationApproximationType.group_commutator_reduced)

# %%
from dbf_dbqa.utils_reporting import *
print_gate_count_report(init_circ)
# Out:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 45
# Total gate count: 392
# Gate counts:
#   X: 16
#   H: 8
#   CNOT: 143
#   RZ: 135
#   RY: 90
# Number of gates with generic Unitary type acting on exactly 1 qubit: 0
# Number of gates acting on exactly 2 qubits: 143

# %%
def find_XXZ_HVA_circuit(self, max_evals = 1000, nlayers = 1, initial_params=None, warm_start_qc = None):
    def HVA_cost_function(parameters):
        qc = deepcopy(warm_start_qc)
        for n in range(nlayers):    
            qc = self.XXZ_HVA_circuit(parameters[2*n], parameters[2*n+1], qc=qc)
        return self.expectation(
            self.backend.execute_circuit(circuit=qc).state())

    if initial_params is None:
        initial_params = [0.25] * (nlayers * 2)

    print('Initial loss:', HVA_cost_function(initial_params))
    from scipy.optimize import minimize
    custom_options = {
        'maxiter': 500, # Set a high maximum number of iterations
        'disp': True,    # Display convergence messages
        'tol': 1e-3     # Optional: decrease the tolerance for a more precise solution
    }
    minimizer_kwargs = {
    'method': 'COBYLA',
    'options': custom_options # We can even pass our custom COBYLA options here
    }

    result = basinhopping(
        HVA_cost_function,
        initial_params,
        minimizer_kwargs=minimizer_kwargs,
        niter=20,  # Number of global iterations
        disp=True # Display convergence messages for basinhopping
    )
    result2 = minimize(
        HVA_cost_function,
        initial_params,
        method="COBYLA",
        options={"disp": True, "maxiter": max_evals},
        tol=1e-4,
    )

    print(result.fun)
    print(result.x)
    print("Local:")
    print(result2.fun)
    print(result2.x)
    parameters = result.x
    qc = warm_start_qc
    for n in range(nlayers):    
        qc = self.XXZ_HVA_circuit(parameters[2*n], parameters[2*n+1], qc=qc)
    return qc, result.fun, result.x

# %%
a, x,z = H_XXZ.find_XXZ_HVA_circuit(nlayers=4)
# Out:
# Initial loss: -20.283433659217483
# -27.43682165198271
#
# [ 0.3300118   0.13032506  0.09957616  0.14001792  0.13279334  0.11775719
#  -0.00662452 -0.00817631]
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS = 1000   F =-2.743682E+01    MAXCV = 0.000000E+00
#    X = 3.300118E-01   1.303251E-01   9.957616E-02   1.400179E-01   1.327933E-01
#        1.177572E-01  -6.624519E-03  -8.176310E-03

# %%
init_circ, a,b = find_XXZ_HVA_circuit(H_XXZ,nlayers=3)
# Out:
# Initial loss: -21.070601367862075
# basinhopping step 0: f -27.428
#    Normal return from subroutine COBYLA
#
#    NFVALS =  240   F =-2.742804E+01    MAXCV = 0.000000E+00
#    X = 1.681196E-01   1.305269E-01  -2.346906E-01  -1.228205E-01  -1.776886E-01
#       -2.492745E-01
#
# basinhopping step 1: f -27.4076 trial_f -27.4076 accepted 1  lowest_f -27.428
#    Normal return from subroutine COBYLA
#
#    NFVALS =  138   F =-2.740759E+01    MAXCV = 0.000000E+00
#    X =-2.904433E-03   3.427241E-01  -3.727436E-01   1.083597E+00  -1.812731E-01
#       -2.459127E-01
#
# basinhopping step 2: f -27.4262 trial_f -27.4262 accepted 1  lowest_f -27.428
#    Normal return from subroutine COBYLA
#
#    NFVALS =   69   F =-2.742619E+01    MAXCV = 0.000000E+00
#    X = 1.267280E+00   1.435771E+00  -7.269150E-02   1.529578E+00  -1.685410E-01
#       -2.019021E-01
#
# basinhopping step 3: f -27.2363 trial_f -27.2363 accepted 1  lowest_f -27.428
#    Normal return from subroutine COBYLA
#
#    NFVALS =  167   F =-2.723625E+01    MAXCV = 0.000000E+00
#    X = 7.943262E-01   3.051754E+00  -4.212078E-01   1.766335E+00   1.750286E-01
#        2.218843E-01
#
# basinhopping step 4: f -27.2591 trial_f -27.2591 accepted 1  lowest_f -27.428
#    Normal return from subroutine COBYLA
#
#    NFVALS =  155   F =-2.725913E+01    MAXCV = 0.000000E+00
#    X = 2.385930E+00   3.234944E+00  -5.668571E-01   1.352957E+00   3.517019E-01
#        4.280571E-02
#
# basinhopping step 5: f -27.1378 trial_f -27.1378 accepted 1  lowest_f -27.428
#    Normal return from subroutine COBYLA
#
#    NFVALS =  146   F =-2.713784E+01    MAXCV = 0.000000E+00
#    X = 1.746888E+00   4.563783E+00  -3.468081E-01   1.168274E-01   7.250272E-01
#        4.075537E-02
#
# basinhopping step 6: f -27.3578 trial_f -27.3578 accepted 1  lowest_f -27.428
#    Normal return from subroutine COBYLA
#
#    NFVALS =  289   F =-2.735775E+01    MAXCV = 0.000000E+00
#    X = 3.092649E+00   5.592915E+00  -9.151239E-01   5.592245E-01   6.588772E-01
#       -5.874998E-02
#
# basinhopping step 7: f -26.8081 trial_f -26.8081 accepted 1  lowest_f -27.428
#    Normal return from subroutine COBYLA
#
#    NFVALS =  223   F =-2.680805E+01    MAXCV = 0.000000E+00
#    X = 2.826245E+00   4.820384E+00   4.098684E-01   2.097113E-01   6.278947E-01
#       -6.782955E-03
#
# basinhopping step 8: f -27.1316 trial_f -27.1316 accepted 1  lowest_f -27.428
#    Normal return from subroutine COBYLA
#
#    NFVALS =  166   F =-2.713159E+01    MAXCV = 0.000000E+00
#    X = 3.931678E+00   6.197152E+00  -5.319806E-02  -7.068676E-03   1.895283E-01
#        2.137097E-01
#
# basinhopping step 9: f -27.2431 trial_f -27.2431 accepted 1  lowest_f -27.428
#    Normal return from subroutine COBYLA
#
#    NFVALS =  159   F =-2.724307E+01    MAXCV = 0.000000E+00
#    X = 3.922636E+00   6.376351E+00   4.381303E-01  -1.925695E-01  -1.671667E-01
#       -2.085699E-01
#
# basinhopping step 10: f -27.2528 trial_f -27.2528 accepted 1  lowest_f -27.428
#    Normal return from subroutine COBYLA
#
#    NFVALS =  283   F =-2.725278E+01    MAXCV = 0.000000E+00
#    X = 4.526064E+00   6.368499E+00  -4.495278E-02   7.601315E-01   1.260121E+00
#        6.493169E-01
#
# basinhopping step 11: f -27.2528 trial_f -26.9844 accepted 0  lowest_f -27.428
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =   94   F =-2.698438E+01    MAXCV = 0.000000E+00
#    X = 4.106586E+00   7.907363E+00  -6.991316E-01  -1.033795E-01   1.015109E+00
#        2.224602E-01
# basinhopping step 12: f -27.5233 trial_f -27.5233 accepted 1  lowest_f -27.5233
#    Normal return from subroutine COBYLA
#
#    NFVALS =  199   F =-2.752331E+01    MAXCV = 0.000000E+00
#    X = 5.103137E+00   6.419933E+00   3.594241E-01   1.858047E+00   1.726857E+00
#        2.660045E-01
#
# found new global minimum on step 12 with function value -27.5233
# basinhopping step 13: f -27.2064 trial_f -27.2064 accepted 1  lowest_f -27.5233
#    Normal return from subroutine COBYLA
#
#    NFVALS =  148   F =-2.720641E+01    MAXCV = 0.000000E+00
#    X = 5.359811E+00   7.752004E+00   1.360149E+00   1.750037E+00   1.203722E+00
#       -1.616980E-01
#
# basinhopping step 14: f -27.417 trial_f -27.417 accepted 1  lowest_f -27.5233
#    Normal return from subroutine COBYLA
#
#    NFVALS =  142   F =-2.741700E+01    MAXCV = 0.000000E+00
#    X = 5.680230E+00   7.912895E+00   1.288959E+00   1.449363E+00   1.408170E+00
#       -2.186299E-01
#
# basinhopping step 15: f -27.3357 trial_f -27.3357 accepted 1  lowest_f -27.5233
#    Normal return from subroutine COBYLA
#
#    NFVALS =  113   F =-2.733570E+01    MAXCV = 0.000000E+00
#    X = 6.749108E+00   9.513484E+00   1.532228E+00   8.162603E-01   1.308835E+00
#       -9.009689E-01
#
# basinhopping step 16: f -27.4141 trial_f -27.4141 accepted 1  lowest_f -27.5233
#    Normal return from subroutine COBYLA
#
#    NFVALS =  431   F =-2.741412E+01    MAXCV = 0.000000E+00
#    X = 8.209841E+00   9.560768E+00   1.567827E+00   2.636540E+00   1.739074E+00
#       -8.355851E-01
#
# basinhopping step 17: f -26.8374 trial_f -26.8374 accepted 1  lowest_f -27.5233
#    Normal return from subroutine COBYLA
#
#    NFVALS =   91   F =-2.683739E+01    MAXCV = 0.000000E+00
#    X = 7.864516E+00   1.018017E+01   1.983591E+00   2.485665E+00   2.558495E+00
#        2.062318E-01
#
# basinhopping step 18: f -27.2456 trial_f -27.2456 accepted 1  lowest_f -27.5233
#    Normal return from subroutine COBYLA
#
#    NFVALS =  145   F =-2.724559E+01    MAXCV = 0.000000E+00
#    X = 7.830717E+00   9.905876E+00   1.973353E+00   2.530923E+00   2.962551E+00
#       -2.323503E-01
#
# basinhopping step 19: f -27.1938 trial_f -27.1938 accepted 1  lowest_f -27.5233
#    Normal return from subroutine COBYLA
#
#    NFVALS =  204   F =-2.719378E+01    MAXCV = 0.000000E+00
#    X = 7.838910E+00   9.681599E+00   3.515712E+00   2.767434E+00   4.507365E+00
#       -2.394531E-01
#
# basinhopping step 20: f -27.0772 trial_f -27.0772 accepted 1  lowest_f -27.5233
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  173   F =-2.707720E+01    MAXCV = 0.000000E+00
#    X = 7.179632E+00   1.097992E+01   4.764052E+00   2.592245E+00   5.746478E+00
#       -8.621680E-01
# -27.523313781253876
#    Normal return from subroutine COBYLA
#
#    NFVALS =  916   F =-2.744043E+01    MAXCV = 0.000000E+00
#    X = 1.597988E-01   9.281525E-02  -2.681912E-01  -1.388561E-01  -1.695031E-01
#       -2.353011E-01
#
# [5.10313681 6.41993266 0.35942408 1.85804683 1.72685678 0.26600453]
# Local:
# -27.44043069187736
# [ 0.15979877  0.09281525 -0.26819118 -0.13885613 -0.16950312 -0.23530115]

# %%
init_circ, _, _ = find_XXZ_HVA_circuit(H_XXZ,nlayers=4)
# Out:
# Initial loss: -20.283433659217483
# basinhopping step 0: f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  345   F =-2.742441E+01    MAXCV = 0.000000E+00
#    X = 3.384042E-01   1.290683E-01   5.686232E-02   1.402387E-01   1.336091E-01
#        9.758775E-02   1.067223E-02   1.764419E-03
#
# basinhopping step 1: f -27.1502 trial_f -27.1502 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  150   F =-2.715021E+01    MAXCV = 0.000000E+00
#    X =-1.244262E-02   4.784486E-01   5.435708E-01  -3.616700E-01  -5.515349E-03
#       -3.802037E-01  -3.029886E-01   3.370382E-01
#
# basinhopping step 2: f -26.8034 trial_f -26.8034 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  197   F =-2.680343E+01    MAXCV = 0.000000E+00
#    X =-4.286927E-02   1.148323E-02   4.945129E-03   7.637695E-01  -3.137329E-01
#       -6.705571E-01  -5.351272E-01   1.780472E+00
#
# basinhopping step 3: f -27.1449 trial_f -27.1449 accepted 1  lowest_f -27.4244
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  262   F =-2.714493E+01    MAXCV = 0.000000E+00
#    X = 1.659490E-02  -2.096078E-01   8.477210E-01   3.134094E-01   7.169734E-02
#       -2.103251E-01  -2.615686E-01   1.551482E+00
# basinhopping step 4: f -27.1668 trial_f -27.1668 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  139   F =-2.716681E+01    MAXCV = 0.000000E+00
#    X =-8.391657E-03  -5.288153E-01   2.482202E-01   5.461288E-01   1.033451E+00
#       -1.089075E-01   3.233594E-01   1.616326E+00
#
# basinhopping step 5: f -27.3975 trial_f -27.3975 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  328   F =-2.739755E+01    MAXCV = 0.000000E+00
#    X =-1.778179E-01  -1.456437E+00  -4.841208E-01  -1.185998E-01   1.189915E+00
#       -2.460267E-01   1.779857E+00   1.576348E+00
#
# basinhopping step 6: f -27.0826 trial_f -27.0826 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  126   F =-2.708260E+01    MAXCV = 0.000000E+00
#    X = 1.698789E-02  -1.439317E+00  -8.198081E-01  -3.462984E-02   1.173074E+00
#       -8.462422E-03   1.382287E+00   1.518279E+00
#
# basinhopping step 7: f -27.3264 trial_f -27.3264 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  498   F =-2.732643E+01    MAXCV = 0.000000E+00
#    X = 5.436077E-01  -5.915700E-02  -8.910350E-01   2.313955E-01   7.826681E-01
#       -3.167607E-02   1.883869E+00   1.431343E+00
#
# basinhopping step 8: f -27.4082 trial_f -27.4082 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  214   F =-2.740822E+01    MAXCV = 0.000000E+00
#    X = 1.536921E+00  -2.626073E-01   8.891025E-02   3.492937E-01   1.761749E+00
#        1.289617E-02   1.723712E+00   1.765824E+00
#
# basinhopping step 9: f -27.0361 trial_f -27.0361 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  202   F =-2.703609E+01    MAXCV = 0.000000E+00
#    X = 2.359589E+00  -9.078521E-02   5.057631E-01   2.323328E-01   1.839266E+00
#        7.807349E-03   2.134164E+00   1.314046E+00
#
# basinhopping step 10: f -26.962 trial_f -26.962 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  134   F =-2.696202E+01    MAXCV = 0.000000E+00
#    X = 3.866928E+00   1.214504E-01   1.479457E-01  -7.396633E-02   3.097451E+00
#        2.586520E-01   2.088530E+00   1.119461E+00
#
# basinhopping step 11: f -27.322 trial_f -27.322 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  258   F =-2.732198E+01    MAXCV = 0.000000E+00
#    X = 3.408447E+00   1.126070E-01   4.613141E-01   2.638239E-01   2.692291E+00
#       -3.045702E-02   1.637722E+00   1.407991E+00
#
# basinhopping step 12: f -27.1011 trial_f -27.1011 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  166   F =-2.710109E+01    MAXCV = 0.000000E+00
#    X = 3.989357E+00  -2.092395E-01   1.094678E+00   4.660073E-02   2.669623E+00
#        4.321459E-02   2.349116E+00   1.722788E+00
#
# basinhopping step 13: f -27.258 trial_f -27.258 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  117   F =-2.725803E+01    MAXCV = 0.000000E+00
#    X = 5.121163E+00  -9.935254E-02   4.463952E-01  -2.042657E-01   3.159386E+00
#       -7.211281E-01   2.516822E+00   7.482316E-01
#
# basinhopping step 14: f -27.2765 trial_f -27.2765 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  422   F =-2.727646E+01    MAXCV = 0.000000E+00
#    X = 4.670470E+00   9.015544E-01   7.403358E-01  -1.004785E+00   3.123522E+00
#       -1.136337E+00   2.152767E+00   1.065596E+00
#
# basinhopping step 15: f -27.3851 trial_f -27.3851 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  298   F =-2.738506E+01    MAXCV = 0.000000E+00
#    X = 5.031884E+00   1.446533E-01   1.562131E+00  -4.546237E-01   3.172149E+00
#        3.155947E-01   1.744052E+00   3.674969E-01
#
# basinhopping step 16: f -27.1304 trial_f -27.1304 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  193   F =-2.713045E+01    MAXCV = 0.000000E+00
#    X = 5.748115E+00  -1.115358E-02   2.332341E+00  -1.116585E-01   3.185138E+00
#        4.221441E-01   2.986538E+00   1.145940E+00
#
# basinhopping step 17: f -27.2569 trial_f -27.2569 accepted 1  lowest_f -27.4244
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  291   F =-2.725686E+01    MAXCV = 0.000000E+00
#    X = 6.262862E+00   4.982691E-01   3.326799E+00   9.233202E-01   3.170934E+00
#        6.269435E-01   3.494519E+00   2.603501E+00
# basinhopping step 18: f -27.2895 trial_f -27.2895 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  200   F =-2.728949E+01    MAXCV = 0.000000E+00
#    X = 6.057889E+00   4.169262E-01   4.699920E+00   5.661626E-01   3.358113E+00
#        9.513722E-01   2.926444E+00   2.580950E+00
#
# basinhopping step 19: f -27.0837 trial_f -27.0837 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  184   F =-2.708370E+01    MAXCV = 0.000000E+00
#    X = 6.013846E+00   5.583780E-01   4.935215E+00   1.571414E+00   3.132303E+00
#        1.341480E+00   3.683251E+00   2.663631E+00
#
# basinhopping step 20: f -26.9542 trial_f -26.9542 accepted 1  lowest_f -27.4244
#    Normal return from subroutine COBYLA
#
#    NFVALS =  237   F =-2.695417E+01    MAXCV = 0.000000E+00
#    X = 6.253088E+00   1.010823E+00   5.154157E+00   2.035535E+00   3.488489E+00
#        1.496234E+00   4.158096E+00   3.275524E+00
#
# -27.424408242782025
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS = 1000   F =-2.743682E+01    MAXCV = 0.000000E+00
#    X = 3.300118E-01   1.303251E-01   9.957616E-02   1.400179E-01   1.327933E-01
#        1.177572E-01  -6.624519E-03  -8.176310E-03
#
# [0.33840417 0.1290683  0.05686232 0.14023869 0.13360911 0.09758775
#  0.01067223 0.00176442]
# Local:
# -27.43682165198271
# [ 0.3300118   0.13032506  0.09957616  0.14001792  0.13279334  0.11775719
#  -0.00662452 -0.00817631]

# %%
basinhopping_result_4_layers = [3.384042E-01,   1.290683E-01 ,  5.686232E-02,   1.402387E-01,   1.336091E-01,
       9.758775E-02,   1.067223E-02,   1.764419E-03]
basinhopping_result_4_layers_circuit = Circuit(L)

for n in range(4):    
    basinhopping_result_4_layers_circuit = H_XXZ.XXZ_HVA_circuit(basinhopping_result_4_layers[2*n], basinhopping_result_4_layers[2*n+1],
                                                                  qc=basinhopping_result_4_layers_circuit)

# %%
from dbf_dbqa.utils_reporting import take_verbose_step   
gci_hva3 = GroupCommutatorIteration(
    h=deepcopy(H_XXZ),
    preparation_circuit=init_circ,
    double_bracket_rotation_approximation_type=DoubleBracketRotationApproximationType.group_commutator_reduced)

gci_hva3.h.circuit = lambda t_duration: (
            deepcopy(gci_hva3.preparation_circuit)
            + gci_hva3.h.original_circuit(t_duration/2) + gci_hva3.h.original_circuit(t_duration/2)
            + gci_hva3.preparation_circuit.invert()
            )
#gci_hva3.double_bracket_rotation_approximation_type = DoubleBracketRotationApproximationType.group_commutator_third_order_reduced
take_verbose_step(gci_hva3,dbf)
take_verbose_step(gci_hva3,dbf)
take_verbose_step(gci_hva3,dbf)
# Out:
# Step grid: [0.0051     0.00830714 0.01151429 0.01472143 0.01792857 0.02113571
#  0.02434286 0.02755    0.03075714 0.03396429 0.03717143 0.04037857
#  0.04358571 0.04679286 0.05      ]
# Losses: [np.float64(-27.569894774000858), np.float64(-27.583070802527327), np.float64(-27.586589147769693), np.float64(-27.5823584567509), np.float64(-27.57199418746748), np.float64(-27.556860561409582), np.float64(-27.538105171208425), np.float64(-27.516688527923726), np.float64(-27.49340962914464), np.float64(-27.468928216934206), np.float64(-27.443784207321883), np.float64(-27.418414668997187), np.float64(-27.393168662021342), np.float64(-27.36832019973086), np.float64(-27.34407956057691)]
# Optimal step: 0.011514285714285715
# Minimum loss: -27.586589147769693
# -----
# Circuit analysis before:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 45
# Total gate count: 392
# Gate counts:
#   X: 16
#   H: 8
#   CNOT: 143
#   RZ: 135
#   RY: 90
# Number of gates with generic Unitary type acting on exactly 1 qubit: 0
# Number of gates acting on exactly 2 qubits: 143
# Circuit analysis after:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 179
# Total gate count: 1592
# Gate counts:
#   Unitary: 64
#   X: 48
#   H: 24
#   CNOT: 561
#   RZ: 537
#   RY: 358
# Number of gates with generic Unitary type acting on exactly 1 qubit: 64
# Number of gates acting on exactly 2 qubits: 561
# Step grid: [0.0051     0.00830714 0.01151429 0.01472143 0.01792857 0.02113571
#  0.02434286 0.02755    0.03075714 0.03396429 0.03717143 0.04037857
#  0.04358571 0.04679286 0.05      ]
# Losses: [np.float64(-27.600796527002977), np.float64(-27.604246966246073), np.float64(-27.60489125021642), np.float64(-27.603595207441234), np.float64(-27.601017068211704), np.float64(-27.597650380188313), np.float64(-27.593857541558908), np.float64(-27.589896810816107), np.float64(-27.58594429427981), np.float64(-27.582111904492304), np.float64(-27.5784620247946), np.float64(-27.57501945627139), np.float64(-27.571781112420304), np.float64(-27.56872384378314), np.float64(-27.565810709679674)]
# Optimal step: 0.011514285714285715
# Minimum loss: -27.60489125021642
# -----
# Circuit analysis before:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 179
# Total gate count: 1592
# Gate counts:
#   Unitary: 64
#   X: 48
#   H: 24
#   CNOT: 561
#   RZ: 537
#   RY: 358
# Number of gates with generic Unitary type acting on exactly 1 qubit: 64
# Number of gates acting on exactly 2 qubits: 561
# Circuit analysis after:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 580
# Total gate count: 5192
# Gate counts:
#   Unitary: 256
#   X: 144
#   H: 72
#   CNOT: 1815
#   RZ: 1743
#   RY: 1162
# Number of gates with generic Unitary type acting on exactly 1 qubit: 256
# Number of gates acting on exactly 2 qubits: 1815
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/numba/core/serialize.py:30, in _numba_unpickle(address, bytedata, hashed)
#      27 _unpickled_memo = {}
# ---> 30 def _numba_unpickle(address, bytedata, hashed):
#      31     """Used by `numba_unpickle` from _helperlib.c
#      32
#      33     Parameters
#    (...)
#      42         unpickled object
#      43     """
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[28], line 15
#      13 take_verbose_step(gci_hva3,dbf)
#      14 take_verbose_step(gci_hva3,dbf)
# ---> 15 take_verbose_step(gci_hva3,dbf)
#
# File ~/Projectes_git/boostvqe/src/dbf_dbqa/utils_reporting.py:32, in take_verbose_step(self, magnetic_hamiltonian)
#      29 from collections import Counter
#      31 step_grid = np.linspace(0.0051, 0.05, 15)
# ---> 32 s_opt, s_min, losses, _ = self.choose_step(
#      33     magnetic_hamiltonian, step_grid=step_grid)
#      34 print("Step grid:", step_grid)
#      35 print("Losses:", losses)
#
# File ~/Projectes_git/boostvqe/src/dbf_dbqa/group_commutator_iteration.py:206, in GroupCommutatorIteration.choose_step(self, d, step_grid, mode_dbr)
#     204 elif step_grid is None:
#     205     step_grid = np.linspace(0.0001, 0.1, 10)
# --> 206 losses = [ self.loss(s, d, mode_dbr) for s in step_grid]
#     207 return step_grid[np.argmin(losses)], np.min(losses), losses, step_grid
#
# File ~/Projectes_git/boostvqe/src/dbf_dbqa/group_commutator_iteration.py:194, in GroupCommutatorIteration.loss(self, step_duration, eo_d, mode_dbr)
#     192 else:
#     193     circ = self.preparation_circuit
# --> 194 return self.h.expectation(circ().state())
#
# File ~/.local/lib/python3.12/site-packages/qibo/models/circuit.py:1101, in Circuit.__call__(self, initial_state, nshots, **kwargs)
#    1099 def __call__(self, initial_state=None, nshots=1000, **kwargs):
#    1100     """Equivalent to ``circuit.execute``."""
# -> 1101     return self.execute(initial_state=initial_state, nshots=nshots, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/qibo/models/circuit.py:1097, in Circuit.execute(self, initial_state, nshots, **kwargs)
#    1094     weight = kwargs["weight"]
#    1095     args = args[:1] + [weight] + args[1:]
# -> 1097 return backend.execute_circuit(*args)
#
# File ~/.local/lib/python3.12/site-packages/qibo/backends/numpy.py:474, in NumpyBackend.execute_circuit(self, circuit, initial_state, nshots)
#     467     state = (
#     468         self.zero_state(nqubits)
#     469         if initial_state is None
#     470         else self.cast(initial_state)
#     471     )
#     473     for gate in circuit.queue:
# --> 474         state = gate.apply(self, state, nqubits)
#     476 if circuit.has_unitary_channel:
#     477     # here we necessarily have `density_matrix=True`, otherwise
#     478     # execute_circuit_repeated would have been called
#     479     if circuit.measurements:
#
# File ~/.local/lib/python3.12/site-packages/qibo/gates/abstract.py:563, in Gate.apply(self, backend, state, nqubits)
#     562 def apply(self, backend, state, nqubits):
# --> 563     return backend.apply_gate(self, state, nqubits)
#
# File ~/.local/lib/python3.12/site-packages/qibojit/backends/cpu.py:178, in NumbaBackend.apply_gate(self, gate, state, nqubits)
#     176 if len(targets) == 1:
#     177     op = GATE_OPS.get(gate.__class__.__name__, "apply_gate")
# --> 178     return self.one_qubit_base(state, nqubits, *targets, op, matrix, qubits)
#     179 elif len(targets) == 2:
#     180     op = GATE_OPS.get(gate.__class__.__name__, "apply_two_qubit_gate")
#
# File ~/.local/lib/python3.12/site-packages/qibojit/backends/cpu.py:114, in NumbaBackend.one_qubit_base(self, state, nqubits, target, kernel, gate, qubits)
#     112     return kernel(state, gate, qubits, nstates, m)
#     113 kernel = getattr(self.gates, "{}_kernel".format(kernel))
# --> 114 return kernel(state, gate, nstates, m)
#
# SystemError: CPUDispatcher(<function apply_gate_kernel at 0x73991e283880>) returned a result with an exception set

# %%
from dbf_dbqa.utils_reporting import take_verbose_step   
gci_hva2 = GroupCommutatorIteration(
    h=deepcopy(H_XXZ),
    preparation_circuit=init_circ,
    double_bracket_rotation_approximation_type=DoubleBracketRotationApproximationType.group_commutator_reduced)
take_verbose_step(gci_hva2,dbf)
# Out:
# Step grid: [0.0051     0.00830714 0.01151429 0.01472143 0.01792857 0.02113571
#  0.02434286 0.02755    0.03075714 0.03396429 0.03717143 0.04037857
#  0.04358571 0.04679286 0.05      ]
# Losses: [np.float64(-27.472380197479275), np.float64(-27.489308964400518), np.float64(-27.49725010053559), np.float64(-27.496796831564676), np.float64(-27.488370734840895), np.float64(-27.472278311291927), np.float64(-27.448743847920674), np.float64(-27.417931468345955), np.float64(-27.37996108437216), np.float64(-27.33492042601691), np.float64(-27.28287432900442), np.float64(-27.223871996091273), np.float64(-27.15795270636889), np.float64(-27.085150306968142), np.float64(-27.00549673434423)]
# Optimal step: 0.011514285714285715
# Minimum loss: -27.49725010053559
# -----
# Circuit analysis before:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 59
# Total gate count: 512
# Gate counts:
#   X: 16
#   H: 8
#   CNOT: 188
#   RZ: 180
#   RY: 120
# Number of gates with generic Unitary type acting on exactly 1 qubit: 0
# Number of gates acting on exactly 2 qubits: 188
# Circuit analysis after:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 201
# Total gate count: 1776
# Gate counts:
#   Unitary: 64
#   X: 48
#   H: 24
#   CNOT: 630
#   RZ: 606
#   RY: 404
# Number of gates with generic Unitary type acting on exactly 1 qubit: 64
# Number of gates acting on exactly 2 qubits: 630

# %%
take_verbose_step(gci_hva2,dbf)
# Out:
# Step grid: [0.0051     0.00830714 0.01151429 0.01472143 0.01792857 0.02113571
#  0.02434286 0.02755    0.03075714 0.03396429 0.03717143 0.04037857
#  0.04358571 0.04679286 0.05      ]
# Losses: [np.float64(-27.52093611796527), np.float64(-27.530313399057384), np.float64(-27.536338123714454), np.float64(-27.539353611063966), np.float64(-27.53951771928758), np.float64(-27.536858847133576), np.float64(-27.5313118063035), np.float64(-27.52274361250078), np.float64(-27.510973045794874), np.float64(-27.495785884195293), np.float64(-27.47694692546054), np.float64(-27.454209529392763), np.float64(-27.427323199739686), np.float64(-27.39603959285001), np.float64(-27.360117251597767)]
# Optimal step: 0.01792857142857143
# Minimum loss: -27.53951771928758
# -----
# Circuit analysis before:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 201
# Total gate count: 1776
# Gate counts:
#   Unitary: 64
#   X: 48
#   H: 24
#   CNOT: 630
#   RZ: 606
#   RY: 404
# Number of gates with generic Unitary type acting on exactly 1 qubit: 64
# Number of gates acting on exactly 2 qubits: 630
# Circuit analysis after:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 627
# Total gate count: 5568
# Gate counts:
#   Unitary: 256
#   X: 144
#   H: 72
#   CNOT: 1956
#   RZ: 1884
#   RY: 1256
# Number of gates with generic Unitary type acting on exactly 1 qubit: 256
# Number of gates acting on exactly 2 qubits: 1956

# %%
take_verbose_step(gci_hva2,dbf)
# Out:
# Step grid: [0.0051     0.00830714 0.01151429 0.01472143 0.01792857 0.02113571
#  0.02434286 0.02755    0.03075714 0.03396429 0.03717143 0.04037857
#  0.04358571 0.04679286 0.05      ]
# Losses: [np.float64(-27.561827443840805), np.float64(-27.568817239287835), np.float64(-27.571634084928583), np.float64(-27.570972293254886), np.float64(-27.567270414017315), np.float64(-27.560770287616943), np.float64(-27.55156577764242), np.float64(-27.53964169212231), np.float64(-27.52490442347017), np.float64(-27.507205840567863), np.float64(-27.48636176794796), np.float64(-27.462166163339216), np.float64(-27.434401900551336), np.float64(-27.402848889831965), np.float64(-27.367290122147242)]
# Optimal step: 0.011514285714285715
# Minimum loss: -27.571634084928583
# -----
# Circuit analysis before:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 627
# Total gate count: 5568
# Gate counts:
#   Unitary: 256
#   X: 144
#   H: 72
#   CNOT: 1956
#   RZ: 1884
#   RY: 1256
# Number of gates with generic Unitary type acting on exactly 1 qubit: 256
# Number of gates acting on exactly 2 qubits: 1956
# Circuit analysis after:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 1905
# Total gate count: 16944
# Gate counts:
#   Unitary: 832
#   X: 432
#   H: 216
#   CNOT: 5934
#   RZ: 5718
#   RY: 3812
# Number of gates with generic Unitary type acting on exactly 1 qubit: 832
# Number of gates acting on exactly 2 qubits: 5934

# %%
gci_hva3 = GroupCommutatorIteration(
    h=deepcopy(H_XXZ),
    preparation_circuit=init_circ3,
    double_bracket_rotation_approximation_type=DoubleBracketRotationApproximationType.group_commutator_reduced)
for i in range(3):
    take_verbose_step(gci_hva3,dbf)
# Out:
# Step grid: [0.0051     0.00830714 0.01151429 0.01472143 0.01792857 0.02113571
#  0.02434286 0.02755    0.03075714 0.03396429 0.03717143 0.04037857
#  0.04358571 0.04679286 0.05      ]
# Losses: [np.float64(-27.302995310769024), np.float64(-27.345180937272477), np.float64(-27.371040227864853), np.float64(-27.38114858168215), np.float64(-27.376213807869973), np.float64(-27.356994527784455), np.float64(-27.32425986971414), np.float64(-27.278767288314548), np.float64(-27.221249840520557), np.float64(-27.1524089198494), np.float64(-27.07291034457523), np.float64(-26.98338258772396), np.float64(-26.88441640493773), np.float64(-26.776565382098504), np.float64(-26.660347084985347)]
# Optimal step: 0.014721428571428573
# Minimum loss: -27.38114858168215
# -----
# Circuit analysis before:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 45
# Total gate count: 392
# Gate counts:
#   X: 16
#   H: 8
#   CNOT: 143
#   RZ: 135
#   RY: 90
# Number of gates with generic Unitary type acting on exactly 1 qubit: 0
# Number of gates acting on exactly 2 qubits: 143
# Circuit analysis after:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 159
# Total gate count: 1416
# Gate counts:
#   Unitary: 64
#   X: 48
#   H: 24
#   CNOT: 495
#   RZ: 471
#   RY: 314
# Number of gates with generic Unitary type acting on exactly 1 qubit: 64
# Number of gates acting on exactly 2 qubits: 495
# Step grid: [0.0051     0.00830714 0.01151429 0.01472143 0.01792857 0.02113571
#  0.02434286 0.02755    0.03075714 0.03396429 0.03717143 0.04037857
#  0.04358571 0.04679286 0.05      ]
# Losses: [np.float64(-27.422904273200135), np.float64(-27.440841261335393), np.float64(-27.453880084642567), np.float64(-27.462649041207367), np.float64(-27.467533817073804), np.float64(-27.46875885649295), np.float64(-27.466432918982935), np.float64(-27.460578929973224), np.float64(-27.451155343847187), np.float64(-27.43807226946475), np.float64(-27.4212040589036), np.float64(-27.40039935174302), np.float64(-27.375489203574435), np.float64(-27.346293723272655), np.float64(-27.31262752040434)]
# Optimal step: 0.021135714285714285
# Minimum loss: -27.46875885649295
# -----
# Circuit analysis before:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 159
# Total gate count: 1416
# Gate counts:
#   Unitary: 64
#   X: 48
#   H: 24
#   CNOT: 495
#   RZ: 471
#   RY: 314
# Number of gates with generic Unitary type acting on exactly 1 qubit: 64
# Number of gates acting on exactly 2 qubits: 495
# Circuit analysis after:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 501
# Total gate count: 4488
# Gate counts:
#   Unitary: 256
#   X: 144
#   H: 72
#   CNOT: 1551
#   RZ: 1479
#   RY: 986
# Number of gates with generic Unitary type acting on exactly 1 qubit: 256
# Number of gates acting on exactly 2 qubits: 1551
# Step grid: [0.0051     0.00830714 0.01151429 0.01472143 0.01792857 0.02113571
#  0.02434286 0.02755    0.03075714 0.03396429 0.03717143 0.04037857
#  0.04358571 0.04679286 0.05      ]
# Losses: [np.float64(-27.50304587518281), np.float64(-27.51840734921242), np.float64(-27.52935198955223), np.float64(-27.536143522717822), np.float64(-27.53896682166014), np.float64(-27.537935423501498), np.float64(-27.533102804940153), np.float64(-27.524473645875734), np.float64(-27.512014064025482), np.float64(-27.495660572062725), np.float64(-27.475327765701262), np.float64(-27.450914841230272), np.float64(-27.422311068750634), np.float64(-27.389400350029607), np.float64(-27.352064982330543)]
# Optimal step: 0.01792857142857143
# Minimum loss: -27.53896682166014
# -----
# Circuit analysis before:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 501
# Total gate count: 4488
# Gate counts:
#   Unitary: 256
#   X: 144
#   H: 72
#   CNOT: 1551
#   RZ: 1479
#   RY: 986
# Number of gates with generic Unitary type acting on exactly 1 qubit: 256
# Number of gates acting on exactly 2 qubits: 1551
# Circuit analysis after:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 1527
# Total gate count: 13704
# Gate counts:
#   Unitary: 832
#   X: 432
#   H: 216
#   CNOT: 4719
#   RZ: 4503
#   RY: 3002
# Number of gates with generic Unitary type acting on exactly 1 qubit: 832
# Number of gates acting on exactly 2 qubits: 4719

# %%
from collections import Counter
two_qubit_counter = lambda circ: sum(1 for gate in circ.queue if len(gate.qubits) == 2)

dbf_dbqa_two_qubit_counts = [ two_qubit_counter(init_circ) ]
dbf_dbqa_energies =  [ gci_hva.loss() ]
for step in range(5):
    print("--------------------------")
    print(f"Step {step+1}")   

    step_grid = np.linspace(0.001, 0.05, 15)
    s_opt, s_min, losses, _ = gci_hva.choose_step(
        dbf, step_grid=step_grid)
    print("Step grid:", step_grid)
    print("Losses:", losses)
    print(f"Optimal step: {s_opt}")
    print(f"Minimum loss: {s_min}")
    plt.figure()
    plt.plot(step_grid, losses, marker='o')
    plt.xlabel('Step size')
    plt.ylabel('Loss')
    plt.title('Loss vs Step size for gci_hva.choose_step')
    plt.show()
   
    gci_hva(s_opt, dbf)
    print("Circuit analysis after:")
    print_gate_count_report(gci_hva.preparation_circuit)  
    dbf_dbqa_two_qubit_counts.append( two_qubit_counter(gci_hva.preparation_circuit))
    dbf_dbqa_energies.append( gci_hva.loss() )
# Out:
# --------------------------
# Step 1
# Step grid: [0.001  0.0045 0.008  0.0115 0.015  0.0185 0.022  0.0255 0.029  0.0325
#  0.036  0.0395 0.043  0.0465 0.05  ]
# Losses: [np.float64(-27.0336738484201), np.float64(-27.14945351194741), np.float64(-27.230647727150753), np.float64(-27.280472171765396), np.float64(-27.301432243070117), np.float64(-27.295647172975166), np.float64(-27.264976456964416), np.float64(-27.211089184652803), np.float64(-27.13550759348503), np.float64(-27.039636458971923), np.float64(-26.92478379576667), np.float64(-26.792175854663377), np.float64(-26.64296820819513), np.float64(-26.47825407571268), np.float64(-26.299070662623013)]
# Optimal step: 0.015
# Minimum loss: -27.301432243070117
# Circuit analysis after:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 243
# Total gate count: 2136
# Gate counts:
#   Unitary: 64
#   X: 48
#   H: 24
#   CNOT: 765
#   RZ: 741
#   RY: 494
# Number of gates with generic Unitary type acting on exactly 1 qubit: 64
# Number of gates acting on exactly 2 qubits: 765
# --------------------------
# Step 2
# Step grid: [0.001  0.0045 0.008  0.0115 0.015  0.0185 0.022  0.0255 0.029  0.0325
#  0.036  0.0395 0.043  0.0465 0.05  ]
# Losses: [np.float64(-27.318076066232766), np.float64(-27.365578675263368), np.float64(-27.39952951920392), np.float64(-27.422547690990225), np.float64(-27.436556612951694), np.float64(-27.44303575409645), np.float64(-27.443123312112036), np.float64(-27.437681225829046), np.float64(-27.427343571873358), np.float64(-27.412555358663354), np.float64(-27.39360480916817), np.float64(-27.37065077050948), np.float64(-27.343746242281345), np.float64(-27.312858687844905), np.float64(-27.277887609245383)]
# Optimal step: 0.022000000000000002
# Minimum loss: -27.443123312112036
# Circuit analysis after:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 752
# Total gate count: 6648
# Gate counts:
#   Unitary: 256
#   X: 144
#   H: 72
#   CNOT: 2361
#   RZ: 2289
#   RY: 1526
# Number of gates with generic Unitary type acting on exactly 1 qubit: 256
# Number of gates acting on exactly 2 qubits: 2361
# --------------------------
# Step 3
# Step grid: [0.001  0.0045 0.008  0.0115 0.015  0.0185 0.022  0.0255 0.029  0.0325
#  0.036  0.0395 0.043  0.0465 0.05  ]
# Losses: [np.float64(-27.456229740494702), np.float64(-27.491575154954706), np.float64(-27.512953188908508), np.float64(-27.523425066347574), np.float64(-27.525364676039633), np.float64(-27.52051774981115), np.float64(-27.510116407852287), np.float64(-27.494985154563295), np.float64(-27.475631028657535), np.float64(-27.452318188540808), np.float64(-27.425128760506368), np.float64(-27.394011995796788), np.float64(-27.35882364249115), np.float64(-27.319357204808465), np.float64(-27.2753685201497)]
# Optimal step: 0.015
# Minimum loss: -27.525364676039633
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 24
#      21 plt.title('Loss vs Step size for gci_hva.choose_step')
#      22 plt.show()
# ---> 24 gci_hva(s_opt, dbf)
#      25 print("Circuit analysis after:")
#      26 print_gate_count_report(gci_hva.preparation_circuit)
#
# File ~/Projectes_git/boostvqe/src/dbf_dbqa/group_commutator_iteration.py:171, in GroupCommutatorIteration.__call__(self, step_duration, d, mode_dbr)
#     168     d = SymbolicHamiltonian(sum([Z(i) for i in range(self.nqubits)]))
#     169 """This will run the appropriate group commutator step"""
# --> 171 self.preparation_circuit = deepcopy(
#     172     group_commutator(step_duration, d, self.h, mode_dbr)
#     173     + self.preparation_circuit
#     174 )
#
# File /usr/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File /usr/lib/python3.12/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File /usr/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File /usr/lib/python3.12/copy.py:276, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     274 if deep:
#     275     for item in listiter:
# --> 276         item = deepcopy(item, memo)
#     277         y.append(item)
#     278 else:
#
# File /usr/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File /usr/lib/python3.12/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File /usr/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File /usr/lib/python3.12/copy.py:253, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     251 if deep and args:
#     252     args = (deepcopy(arg, memo) for arg in args)
# --> 253 y = func(*args)
#     254 if deep:
#     255     memo[id(x)] = y
#
# File /usr/lib/python3.12/copy.py:252, in <genexpr>(.0)
#     250 deep = memo is not None
#     251 if deep and args:
# --> 252     args = (deepcopy(arg, memo) for arg in args)
#     253 y = func(*args)
#     254 if deep:
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.plot(dbf_dbqa_two_qubit_counts, dbf_dbqa_energies, marker='o')
plt.xlabel('Two-qubit gate count')
plt.ylabel('Energy')
plt.title('Energy vs Two-qubit gate count for DBF-DBQA')
plt.show()

# %%
import pickle

def load_data(filename):
    with open(filename+'.pickle', 'rb') as file:
        # Load the object from the file
        data = pickle.load(file)
    return data

def run_param_rc(fontsize = 30):
        import matplotlib.pyplot as plt
        plt.rcParams['axes.labelsize'] = fontsize
        plt.rcParams['axes.titlesize'] = fontsize
        plt.rcParams['font.size'] = fontsize
        #set_matplotlib_formats('pdf', 'png')
        plt.rcParams['savefig.dpi'] = 75
        plt.rcParams['lines.linewidth'] = 2.0
        plt.rcParams['lines.markersize'] = 8
        plt.rcParams['legend.fontsize'] = 12
        plt.rcParams['legend.labelspacing'] = .3
        plt.rcParams['legend.columnspacing']= .3
        plt.rcParams['legend.handletextpad']= .1
        plt.rcParams['text.usetex'] = True
        plt.rcParams['font.family'] = "serif"
        plt.rcParams['font.serif'] = "cm"

path = "../simulation_results/Qrisp_simulations_DB_QITE_and_QPE/data/benchmarks_2nd_L=16_05-21-18"
db_qite_simulation_results = load_data(path)
db_qite_energies = db_qite_simulation_results[1]['optimal_energies']
db_qite_cz_counts = [db_qite_simulation_results[0]['circuit_data'][0][i]['cz'] for i in range(len(db_qite_energies))]
print(db_qite_energies)
# Out:
# [np.float64(-26.971036078151435), np.float64(-27.387533684571018), np.float64(-27.516956618690205), np.float64(-27.56818922719701), np.float64(-27.59337703920386), np.float64(-27.608655432129435)]

# %%
plt.figure()
plt.plot(dbf_dbqa_two_qubit_counts, dbf_dbqa_energies, marker='o')
plt.plot(db_qite_cz_counts, db_qite_energies, marker='x', label='DB-QITE')
plt.xlabel('Two-qubit gate count')
plt.ylabel('Energy')
plt.title('Energy vs Two-qubit gate count for DBF-DBQA')
plt.show()

# %%
from dbf_dbqa.utils_reporting import take_verbose_step   
take_verbose_step(gci_hva,dbf)
# Out:
# Step grid: [0.0051     0.00830714 0.01151429 0.01472143 0.01792857 0.02113571
#  0.02434286 0.02755    0.03075714 0.03396429 0.03717143 0.04037857
#  0.04358571 0.04679286 0.05      ]
# Losses: [np.float64(-27.092459028187342), np.float64(-27.158460666880877), np.float64(-27.205527537964173), np.float64(-27.236253436504075), np.float64(-27.25255277529906), np.float64(-27.25589097757097), np.float64(-27.247413016219888), np.float64(-27.228026034499347), np.float64(-27.198456805791746), np.float64(-27.159293649907102), np.float64(-27.111017957146412), np.float64(-27.054028376850987), np.float64(-26.98865962616755), np.float64(-26.91519724324013), np.float64(-26.833889220979433)]
# Optimal step: 0.021135714285714285
# Minimum loss: -27.25589097757097
# -----
# Circuit analysis before:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 17
# Total gate count: 152
# Gate counts:
#   X: 16
#   H: 8
#   CNOT: 53
#   RZ: 45
#   RY: 30
# Number of gates with generic Unitary type acting on exactly 1 qubit: 0
# Number of gates acting on exactly 2 qubits: 53
# Circuit analysis after:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 75
# Total gate count: 696
# Gate counts:
#   Unitary: 64
#   X: 48
#   H: 24
#   CNOT: 225
#   RZ: 201
#   RY: 134
# Number of gates with generic Unitary type acting on exactly 1 qubit: 64
# Number of gates acting on exactly 2 qubits: 225

# %%
take_verbose_step(gci_hva,dbf)
# Out:
# Step grid: [0.0051     0.00830714 0.01151429 0.01472143 0.01792857 0.02113571
#  0.02434286 0.02755    0.03075714 0.03396429 0.03717143 0.04037857
#  0.04358571 0.04679286 0.05      ]
# Losses: [np.float64(-27.348963220530898), np.float64(-27.386797424583666), np.float64(-27.410614003594645), np.float64(-27.42207143844543), np.float64(-27.42267981657917), np.float64(-27.41378095637514), np.float64(-27.396549227001277), np.float64(-27.37200004572888), np.float64(-27.34100147002064), np.float64(-27.304286921966142), np.float64(-27.262468100808068), np.float64(-27.216047596426936), np.float64(-27.165430943987165), np.float64(-27.11093798204561), np.float64(-27.05281344602845)]
# Optimal step: 0.01792857142857143
# Minimum loss: -27.42267981657917
# -----
# Circuit analysis before:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 75
# Total gate count: 696
# Gate counts:
#   Unitary: 64
#   X: 48
#   H: 24
#   CNOT: 225
#   RZ: 201
#   RY: 134
# Number of gates with generic Unitary type acting on exactly 1 qubit: 64
# Number of gates acting on exactly 2 qubits: 225
# Circuit analysis after:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 249
# Total gate count: 2328
# Gate counts:
#   Unitary: 256
#   X: 144
#   H: 72
#   CNOT: 741
#   RZ: 669
#   RY: 446
# Number of gates with generic Unitary type acting on exactly 1 qubit: 256
# Number of gates acting on exactly 2 qubits: 741

# %%
take_verbose_step(gci_hva,dbf)
# Out:
# Step grid: [0.0051     0.00830714 0.01151429 0.01472143 0.01792857 0.02113571
#  0.02434286 0.02755    0.03075714 0.03396429 0.03717143 0.04037857
#  0.04358571 0.04679286 0.05      ]
# Losses: [np.float64(-27.480087793369204), np.float64(-27.4982913414311), np.float64(-27.50600686054565), np.float64(-27.505411855050436), np.float64(-27.49816169161244), np.float64(-27.485474184301566), np.float64(-27.4682102772709), np.float64(-27.446944626002363), np.float64(-27.422025566991405), np.float64(-27.393625349449096), np.float64(-27.36178182342096), np.float64(-27.32643277983847), np.float64(-27.287444037587825), np.float64(-27.244632244949614), np.float64(-27.197783234881705)]
# Optimal step: 0.011514285714285715
# Minimum loss: -27.50600686054565
# -----
# Circuit analysis before:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 249
# Total gate count: 2328
# Gate counts:
#   Unitary: 256
#   X: 144
#   H: 72
#   CNOT: 741
#   RZ: 669
#   RY: 446
# Number of gates with generic Unitary type acting on exactly 1 qubit: 256
# Number of gates acting on exactly 2 qubits: 741
# Circuit analysis after:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 771
# Total gate count: 7224
# Gate counts:
#   Unitary: 832
#   X: 432
#   H: 216
#   CNOT: 2289
#   RZ: 2073
#   RY: 1382
# Number of gates with generic Unitary type acting on exactly 1 qubit: 832
# Number of gates acting on exactly 2 qubits: 2289

# %%
take_verbose_step(gci_hva,dbf)
# Out:
# Step grid: [0.0051     0.00830714 0.01151429 0.01472143 0.01792857 0.02113571
#  0.02434286 0.02755    0.03075714 0.03396429 0.03717143 0.04037857
#  0.04358571 0.04679286 0.05      ]
# Losses: [np.float64(-27.532692260731924), np.float64(-27.537965906858915), np.float64(-27.53700945806073), np.float64(-27.5312829668114), np.float64(-27.52171014778504), np.float64(-27.5088113125842), np.float64(-27.492812430296155), np.float64(-27.473731075367343), np.float64(-27.451442810674013), np.float64(-27.425731666982514), np.float64(-27.396327940438645), np.float64(-27.36293600379545), np.float64(-27.325254336879606), np.float64(-27.282989557482765), np.float64(-27.235865877878783)]
# Optimal step: 0.008307142857142857
# Minimum loss: -27.537965906858915
# -----
# Circuit analysis before:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 771
# Total gate count: 7224
# Gate counts:
#   Unitary: 832
#   X: 432
#   H: 216
#   CNOT: 2289
#   RZ: 2073
#   RY: 1382
# Number of gates with generic Unitary type acting on exactly 1 qubit: 832
# Number of gates acting on exactly 2 qubits: 2289
# Circuit analysis after:
# Gate count report:
# -------------------
# Number of qubits: 16
# Circuit depth: 2337
# Total gate count: 21912
# Gate counts:
#   Unitary: 2560
#   X: 1296
#   H: 648
#   CNOT: 6933
#   RZ: 6285
#   RY: 4190
# Number of gates with generic Unitary type acting on exactly 1 qubit: 2560
# Number of gates acting on exactly 2 qubits: 6933

# %%
from qrisp.operators import X, Y, Z

import numpy as np
import networkx as nx
from scipy.sparse.linalg import eigsh
import matplotlib.pyplot as plt

import pickle

def save_data(data, filename):  
    # Open a file for writing
    with open(filename+'.pickle', 'wb') as file:
        # Write the object to the file
        pickle.dump(data, file)

def load_data(filename):
    with open(filename+'.pickle', 'rb') as file:
        # Load the object from the file
        data = pickle.load(file)
    return data

def compute_moments(psi, H):
    E = (psi.conj().T @ H.dot(psi)).real
    S = (psi.conj().T @ (H @ H).dot(psi)).real
    return E, S, S - E**2

def run_param_rc(fontsize = 30):
        import matplotlib.pyplot as plt
        plt.rcParams['axes.labelsize'] = fontsize
        plt.rcParams['axes.titlesize'] = fontsize
        plt.rcParams['font.size'] = fontsize
        #set_matplotlib_formats('pdf', 'png')
        plt.rcParams['savefig.dpi'] = 75
        plt.rcParams['lines.linewidth'] = 2.0
        plt.rcParams['lines.markersize'] = 8
        plt.rcParams['legend.fontsize'] = 12
        plt.rcParams['legend.labelspacing'] = .3
        plt.rcParams['legend.columnspacing']= .3
        plt.rcParams['legend.handletextpad']= .1
        plt.rcParams['text.usetex'] = True
        plt.rcParams['font.family'] = "serif"
        plt.rcParams['font.serif'] = "cm"

# %%
path = "../simulation_results/Qrisp_simulations_DB_QITE_and_QPE/data/benchmarks_2nd_L=16_05-21-18"
db_qite_simulation_results = load_data(path)
print(db_qite_simulation_results[1]['optimal_energies'])

# %%
db_qite_simulation_results[1].keys()
# Out:
# dict_keys(['evolution_times', 'optimal_energies', 'variances', 'circuit_data', 'runtimes', 'statevectors'])

# %%
print(db_qite_simulation_results[1]['optimal_energies'])
# Out:
# [np.float64(-26.971036078151435), np.float64(-27.387533684571018), np.float64(-27.516956618690205), np.float64(-27.56818922719701), np.float64(-27.59337703920386), np.float64(-27.608655432129435)]

# %%
print(db_qite_simulation_results[1]['circuit_data'])
# Out:
# [{0: {'u3': 128, 'cz': 68}, 1: {'u3': 1085, 'cz': 660}, 2: {'u3': 3803, 'cz': 2352}, 3: {'u3': 11957, 'cz': 7428}, 4: {'u3': 36419, 'cz': 22656}, 5: {'u3': 109568, 'cz': 68208}}, {0: 16, 1: 18, 2: 18, 3: 18, 4: 18, 5: 18}, {0: 19, 1: 295, 2: 1099, 3: 3511, 4: 10747, 5: 32419}, {0: 16, 1: 18, 2: 18, 3: 18, 4: 18, 5: 18}]

# %%
results_10 = load_data('data/benchmarks_2nd_L=10_05-21-16') 
results_12 = load_data('data/benchmarks_2nd_L=12_05-21-17')
results_14 = load_data('data/benchmarks_2nd_L=14_05-21-17')  
results_16 = load_data('data/benchmarks_2nd_L=16_05-21-18')  
results_18 = load_data('data/benchmarks_2nd_L=18_05-21-19')  
results_20 = load_data('data/benchmarks_2nd_L=20_05-21-22') 

results_QITE = dict()
results_QITE[10] = results_10
results_QITE[12] = results_12
results_QITE[14] = results_14
results_QITE[16] = results_16
results_QITE[18] = results_18
results_QITE[20] = results_20
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 results_10 = load_data('data/benchmarks_2nd_L=10_05-21-16')
#       2 results_12 = load_data('data/benchmarks_2nd_L=12_05-21-17')
#       3 results_14 = load_data('data/benchmarks_2nd_L=14_05-21-17')
#
# Cell In[8], line 17, in load_data(filename)
#      16 def load_data(filename):
# ---> 17     with open(filename+'.pickle', 'rb') as file:
#      18         # Load the object from the file
#      19         data = pickle.load(file)
#      20     return data
#
# File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/benchmarks_2nd_L=10_05-21-16.pickle'

# %%
def generate_plot_E_DBQITE(ax1, L):
    
    lables_energies=[r"~$~\ |\omega_0\rangle =|$Singlet$\rangle = 2^{-L/4}(|01\rangle-|10\rangle)^{\otimes L/2}$",
                     r"~$~\ |\omega_0\rangle =|$HVA$\rangle = U_\mathrm{HVA}|\mathrm{Singlet}\rangle$"]
    lables_fidelities=[r"$F_k\ |$Singlet$\rangle$",r"$F_k\ |$HVA$\rangle$"]
    alphas = [1.0, 0.6]
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    
    markers = ['o', 's', '^', 'v', '<', '>', 'd']
    indices = [0,1] 
    steps = [0,1,2,3,4,5]

    results = db_qite_simulation_results[L]

    ###############################################################################
    # SUBPLOT 1: Energy
    ###############################################################################

    # 1) Plot energies on the left y-axis
    #for i,ind in enumerate(indices):
        #line1, = ax1.plot(results[ind]['evolution_times'], results[ind]['optimal_energies'], label=lables_energies[ind], color='blue', marker=markers[i], linestyle='solid', linewidth=2, zorder=3, alpha=alphas[i])
    ind = indices[ 0]
    line1, = ax1.plot(steps, results[ind]['optimal_energies'], label=lables_energies[ind], 
                      color=colors[0], marker='v', linestyle='solid', linewidth=2, zorder=3, alpha = 0.6)
    ind = indices[1]
    line1, = ax1.plot(steps, results[ind]['optimal_energies'], label=lables_energies[ind],
                      color=colors[0], marker=markers[2], linestyle='solid', linewidth=2, zorder=3)

    ax1.axhline(y=E0_val[L], color="red", linestyle=':', alpha=1.0)
    #ax1.axhline(y=E0_val[L]+0.1, color="orange", linestyle=':', alpha=0.8)
    ax1.axhline(y=E1_val[L], color="red", linestyle=':', alpha=0.6)
    
    ax1.set_xlabel(r"Steps $k$")
    ax1.set_ylabel(r"Energy $E_k$")
    ax1.set_xticks(ticks = range(0, 6, 1))
    ax1.set_yticks(ticks = [-30,-31,-32,-33, -34,-35])
    ax1.legend(loc="center right", fontsize=15)
    ax1.set_title(f"DB-QITE for $L={L}$")

    ###############################################################################

    # 3) Combine legends from both axes
    lines_1, labels_1 = ax1.get_legend_handles_labels()
   
    ax1.legend(lines_1 , labels_1 , loc="best", ncol=1, fontsize=17)

run_param_rc(23)

index = 1 # 0 Singlet, 1 HVA
markers = ['o', 's', '^', 'v', '<', '>', 'd']
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']


fig, ((axE_QITE, axF_QITE, axF_QPE)) = plt.subplots(1, 3, figsize=(20, 5))#, gridspec_kw={"width_ratios": [4,2,10,1]})

###############################################################################
# SUBPLOT 1: Energy and fidelity QITE
###############################################################################

generate_plot_E_DBQITE(axE_QITE,20)
axE_QITE.annotate('a)', xy = (-.2, 1.05), xycoords='axes fraction')
axE_QITE.annotate(' ',
            xy=(5.2, E0_val[20]),  # theta, radius
            xytext=(5.2, -32.6),    # fraction, fraction
            textcoords='data',
            arrowprops=dict(facecolor='gray', shrink=0.001),
            horizontalalignment='left',
            verticalalignment='bottom')
axE_QITE.annotate(' ',
            xy=(4.8, -34),  # theta, radius
            xytext=(4.8, -33.1),    # fraction, fraction
            textcoords='data',
            arrowprops=dict(facecolor='gray', shrink=0.001),
            horizontalalignment='left',
            verticalalignment='bottom')
axE_QITE.set_xlim([-0.1,5.35])
axE_QITE.text(
    4.4,           
    -33,       
    r"$\lambda_1$",                          
    va="center",
    ha="left",
    color="black",
    alpha = 0.6
)   

axE_QITE.text(
    4.8,           
    -32.5  ,           
    r"$\lambda_0$",                           
    va="center",
    ha="left",
    color="black"
    )
###############################################################################
# SUBPLOT 2: Fidelity and CZ count QITE
###############################################################################

#generate_fidelity_cz_qite(axF_QITE, "HVA")
ax = axF_QITE
init_type="HVA"

if init_type=="Singlet":
    index = 0
    ax.set_title(r"DB-QITE for $|$Singlet$\rangle$")
if init_type=="HVA":
    index = 1
    ax.set_title(r"DB-QITE for $|$HVA$\rangle$")

steps = list(range(0,6))

cz_data_qite = dict()

for i,L in enumerate(list(range(10,22,2))):
    results = db_qite_simulation_results[L]
    cz = np.array([results[index]["circuit_data"][0][k]['cz'] for k in steps])
    cz_data_qite[L] = cz

alphas =[0.5,0.75,1,0.7]
cz_count_HVA = {}
fidelities_HVA = {}
ax2 = ax.twinx()
for i,L in enumerate([12,16,20]):
    results = db_qite_simulation_results[L]

    psi = E0_vec[L] # ground state
    states = results[index]["statevectors"]
    fidelities = []
    for phi in states:
        fidelities.append(np.round(np.abs(np.dot(psi.conj().transpose(),phi))**2,3))

    cz_counts = cz_data_qite[L]
    cz_count_HVA[L] = cz_data_qite[L][0]
    fidelities_HVA[L] = fidelities[0]
    ax2.plot(cz_counts, fidelities, marker=markers[i], zorder = 4+i, label=f'$L={L}$',color= colors[0], alpha = alphas[i])


ax.legend(loc="best", ncols=2, fontsize=15)
#ax.set_xticks(ticks = range(0, 6, 1))
ax.set_xscale('log')
ax.set_xlabel(r"Number of CZ gates")
ax.set_ylabel(r"Fidelity $F_k$")
ax.set_title(r"DB-QITE and QPE for $|$HVA$\rangle$")

steps = list(range(1,6))

cz_data_qpe = dict()
for i,L in enumerate([12,16,20]):
    cz = [results_QPE[index][L][k]['ops']['cz'] for k in steps]
    cz.insert(0, cz_count_HVA[L])
    cz_data_qpe[L] = cz


for i,L in enumerate([12,16,20]):
    fidelities = [results_QPE[index][L][k]['F0'] for k in steps]
    fidelities.insert(0, fidelities_HVA[L])
    cz_counts = cz_data_qpe[L]
    #adding the initialization data
    ax.plot(cz_counts, fidelities, marker=markers[i], label=f'$L={L}$', zorder = i, color= colors[1], alpha = alphas[i], markerfacecolor='none')
if init_type=="HVA":
    steps = list(range(1,8))


ax.axhline(y=1, color="orange", linestyle=':', alpha=1.0,linewidth = 1)
ax.axhline(y=0.975, color="orange", linestyle=':', alpha=0.8,linewidth = 1)
ax.axhline(y=0.95, color="orange", linestyle=':', alpha=0.6,linewidth = 1)
ax.legend(loc="best", ncols=1, fontsize=16, title='QPE',title_fontsize='17', bbox_to_anchor=(0.715, 0.42))
ax2.legend(loc="best", ncols=1, fontsize=16, title='DB-QITE',title_fontsize='17', bbox_to_anchor=(0.715, 0.795))

ax.set_xscale('log')
#ax.set_xticks(ticks = range(1, 6, 1))
ax.set_xlabel(r"Number of CZ gates")   
ax.set_ylabel(r"Fidelity $F_k$")
    
axF_QITE.annotate('b)', xy = (-.2, 1.05), xycoords='axes fraction')
#axF_QITE.annotate(r'DB-QITE', xy=(1e4,0.98), textcoords='data', fontsize=15,rotation=90)
#axF_QITE.annotate(r'QPE', xy=(1e4,0.75), textcoords='data', fontsize=15,rotation=90)
###############################################################################
# SUBPLOT 3: Fidelity and CZ count QPE
###############################################################################

L = 20
index = 1 # HVA

results = db_qite_simulation_results[L]

psi = E0_vec[L] # ground state
states = results[index]["statevectors"]
fidelities = []
for phi in states:
    fidelities.append(np.round(np.abs(np.dot(psi.conj().transpose(),phi))**2,3))

cz_counts = cz_data_qite[L]
axF_QPE.plot(cz_counts, fidelities, marker=markers[2], label=f'DB-QITE',color= colors[0], alpha = alphas[i])

steps = list(range(1,6))
fidelities = [results_QPE[index][L][k]['F0'] for k in steps]
fidelities.insert(0, fidelities_HVA[L])
cz_counts = cz_data_qpe[L]
axF_QPE.plot(cz_counts, fidelities, marker=markers[2], label=f'QPE $[0,1)$', color= colors[1], alpha = 0.5)

steps = list(range(1,8))
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
fidelities = [results_QPE_rescaled_05[index][20][k]['F0'] for k in steps]
fidelities.insert(0, fidelities_HVA[L])
cz_counts = [results_QPE_rescaled_05[index][20][k]['ops']['cz'] for k in steps]
cz_counts.insert(0, cz_count_HVA[L])
axF_QPE.plot(cz_counts, fidelities, color=colors[1], label=f'QPE $[0,0.5)$'
             , marker=markers[3], markerfacecolor='none', alpha = 0.75)


fidelities = [results_QPE_rescaled_01[index][20][k]['F0'] for k in steps]
fidelities.insert(0, fidelities_HVA[L])
cz_counts = [results_QPE_rescaled_01[index][20][k]['ops']['cz'] for k in steps]
cz_counts.insert(0, cz_count_HVA[L])

axF_QPE.plot(cz_counts, fidelities, color=colors[1], label=f'QPE $[0,0.1)$'
             , marker=markers[4], markerfacecolor='none',alpha = 1)

axF_QPE.axhline(y=1, color="orange", linestyle=':', alpha=1.0,linewidth = 1)
axF_QPE.axhline(y=0.975, color="orange", linestyle=':', alpha=0.8,linewidth = 1)
axF_QPE.axhline(y=0.95, color="orange", linestyle=':', alpha=0.6,linewidth = 1)

axF_QPE.annotate('c)', xy = (-.12, 1.05), xycoords='axes fraction')
axF_QITE.annotate(r'$k=0$', xy=(37,0.917), textcoords='data', fontsize=17,zorder = 11)
axF_QITE.annotate(r'$k=1$', xy=(170,0.957), textcoords='data', fontsize=17,zorder = 12)
axF_QITE.annotate(r'$k=2$', xy=(625,0.983), textcoords='data', fontsize=17,zorder = 13)
#axF_QPE.annotate(r'$L=20,$', xy=(16100,0.87), textcoords='data', fontsize=15)
#axF_QPE.annotate(r'$[0,0.5)$', xy=(16100,0.85), textcoords='data', fontsize=15)
#axF_QPE.annotate(r'$L=20,$', xy=(39000,0.795), textcoords='data', fontsize=15)
#axF_QPE.annotate(r'$[0,0.1)$', xy=(39000,0.7753), textcoords='data', fontsize=15)
axF_QPE.set_xscale('log')
axF_QPE.set_xlabel(r"Number of CZ gates")  
axF_QPE.set_title(r"DB-QITE vs. spectral rescalings of QPE")
axF_QPE.legend(loc="upper left", ncols=1, fontsize=17)#,title=f'$L=20$',title_fontsize='15')
plt.tight_layout()
#plt.savefig("plots/QITE_Heisenberg_main.pdf")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 60
#      54 fig, ((axE_QITE, axF_QITE, axF_QPE)) = plt.subplots(1, 3, figsize=(20, 5))#, gridspec_kw={"width_ratios": [4,2,10,1]})
#      56 ###############################################################################
#      57 # SUBPLOT 1: Energy and fidelity QITE
#      58 ###############################################################################
# ---> 60 generate_plot_E_DBQITE(axE_QITE,20)
#      61 axE_QITE.annotate('a)', xy = (-.2, 1.05), xycoords='axes fraction')
#      62 axE_QITE.annotate(' ',
#      63             xy=(5.2, E0_val[20]),  # theta, radius
#      64             xytext=(5.2, -32.6),    # fraction, fraction
#    (...)
#      67             horizontalalignment='left',
#      68             verticalalignment='bottom')
#
# Cell In[49], line 13, in generate_plot_E_DBQITE(ax1, L)
#      10 indices = [0,1]
#      11 steps = [0,1,2,3,4,5]
# ---> 13 results = db_qite_simulation_results[L]
#      15 ###############################################################################
#      16 # SUBPLOT 1: Energy
#      17 ###############################################################################
#    (...)
#      20 #for i,ind in enumerate(indices):
#      21     #line1, = ax1.plot(results[ind]['evolution_times'], results[ind]['optimal_energies'], label=lables_energies[ind], color='blue', marker=markers[i], linestyle='solid', linewidth=2, zorder=3, alpha=alphas[i])
#      22 ind = indices[ 0]
#
# IndexError: list index out of range

# %%
# check rxx formula
t = 0.5
qc = Circuit(2)
qc.add(gates.RXX(0, 1, t*2))
x = np.array([[0,1], [1,0]])
xx = np.kron(x, x)
u = sp.linalg.expm(-1j*t*xx)
print(np.linalg.norm(u-qc.unitary())<1e-11)
# Out:
# True

# %%
def XXZ_simulation(nqubits, delta, t, trotter_steps=2, boundary="open", layer=3):
    qc = Circuit(nqubits)
    even_pairs = [(i, i+1) for i in range(0, nqubits-1, 2)]
    odd_pairs = [(i, i+1) for i in range(1, nqubits-1, 2)]
    if boundary == 'closed':
        odd_pairs.append((0, nqubits-1))
        
    dt_even = t/trotter_steps*2
    dt_odd = t/trotter_steps*2
    if layer == 3:
        dt_even /= 2
        
    for _ in range(trotter_steps):
        for i,j in even_pairs:
            qc.add(gates.RXX(i, j, dt_even))
            qc.add(gates.RYY(i, j, dt_even))
            qc.add(gates.RZZ(i, j, dt_even*delta))
        for i, j in odd_pairs:
            qc.add(gates.RXX(i, j, dt_odd))
            qc.add(gates.RYY(i, j, dt_odd))
            qc.add(gates.RZZ(i, j, dt_odd*delta))
        if layer == 3:
            for i,j in even_pairs:
                qc.add(gates.RXX(i, j, dt_even))
                qc.add(gates.RYY(i, j, dt_even))
                qc.add(gates.RZZ(i, j, dt_even*delta))
                
    return qc

# %%
# check hamiltonian simulation
L_test = 6
delta_test = 0.5
boundary_test = 'open'
H_test = construct_XXZ(L_test, delta_test, boundary_test)
t = 0.2
print(np.linalg.norm(sp.linalg.expm(-1j*t*H_test.matrix) - XXZ_simulation(L_test, delta_test, t, layer=3).unitary()))
# Out:
# [Qibo 0.2.21|WARNING|2025-07-29 15:37:49]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.21|WARNING|2025-07-29 15:37:49]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# 0.03903661129144955

# %% [markdown]
# ## Magnetic field
#
# RZ in qibo: $e^{-i\frac{\theta}{2}D}$

# %%
# magnetic field
def magnetic_field_circ(coefs, t):
    # implments e^{-itD}
    nqubits = len(coefs)
    qc = Circuit(nqubits)
    
    for idx, coef in enumerate(coefs):
        qc.add(gates.RZ(idx, coef*t*2))
    return qc

# %%
# test d formula
theta = 0.5
d = magnetic_field_circ([1], theta)
d_u = sp.linalg.expm(-1j*theta*np.array([[1,0],[0,-1]]))
print(np.linalg.norm(d.unitary()-d_u)<1e-3)
# Out:
# True

# %% [markdown]
# ## Construct GCI circuit
# In the initialization step, we have
# $$
# \bra{\psi_0(\theta)} H\ket{\psi_0(\theta)}=\bra{0}U_\theta^\dagger H U_\theta\ket{0}=\bra{0}A_0\ket{0}
# $$
# For one step of DBQA,
# $$
# V_1 = e^{itD}U^\dagger e^{-itH_0}Ue^{-itD}
# $$
# and that
# $$
# A_1 = V_1^\dagger U^\dagger H_0 U V_1.
# $$
#
# With this we find
# $$
# \langle 0|A_1|0\rangle =\langle \psi_1|H|\psi_1\rangle = \bra 0 U_1^\dagger H U_1\ket 0
# $$
# where
# $$
# |\psi_1\rangle = U* V_1|0\rangle.
# $$
#
# Therefore, our composed DBQA circuit should follow
#
# $$
# U_1 = U*V_1 = U_\theta e^{itD}U_\theta ^\dagger e^{-itH}U_\theta e^{-itD}
# $$
#
# $$
# U_1^{(RHOPF)} = U \cdot V_1^{(RHOPF)}=Ue^{-i\phi \sqrt t D}U^\dagger e^{-i\sqrt tH} U
#             e^{i(\phi+1)\sqrt t D}U^\dagger e^{i(1-\phi)\sqrt tH} U e^{-i\phi \sqrt t D}.
# $$

# %%
def GCI(H, H_sim_fun, D_circ_fun, init_circ, t):
    qc = Circuit(H.nqubits)
    H_sim = H_sim_fun(t)
    D_circ = D_circ_fun(t)
    qc.wire_names = init_circ.wire_names
    D_circ.wire_names = qc.wire_names
    H_sim.wire_names = qc.wire_names
    qc = qc + D_circ + init_circ + H_sim + init_circ.invert() + D_circ.invert() + init_circ
    return qc, h_expectation_from_circ(H, qc)

# %%
# test t=0 same value as E_init
t = 0
coefs = [1] * L
H_sim_fun = lambda t: XXZ_simulation(L, delta, t)
D_circ_fun = lambda t: magnetic_field_circ(coefs, t)
gci_circ, gci_val = GCI(H_XXZ, H_sim_fun, D_circ_fun, init_circ, t)
print(np.abs(gci_val-h_expectation_from_circ(H_XXZ, init_circ))<1e-3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 6
#       4 H_sim_fun = lambda t: XXZ_simulation(L, delta, t)
#       5 D_circ_fun = lambda t: magnetic_field_circ(coefs, t)
# ----> 6 gci_circ, gci_val = GCI(H, H_sim_fun, D_circ_fun, init_circ, t)
#       7 print(np.abs(gci_val-h_expectation_from_circ(H, init_circ))<1e-3)
#
# Cell In[14], line 9, in GCI(H, H_sim_fun, D_circ_fun, init_circ, t)
#       7 H_sim.wire_names = qc.wire_names
#       8 qc = qc + D_circ + init_circ + H_sim + init_circ.invert() + D_circ.invert() + init_circ
# ----> 9 return qc, h_expectation_from_circ(H, qc)
#
# NameError: name 'h_expectation_from_circ' is not defined

# %%
run_grid_search = False
if run_grid_search:
    t_space = np.linspace(0,0.3,20)
    E_ls = []
    for t in t_space:
        gci_circ, gci_val = GCI(H_XXZ, H_sim_fun, D_circ_fun, init_circ, t)
        E_ls.append(gci_val)

# %%
if run_grid_search:
    E_min = min(E_ls)
    min_idx = E_ls.index(E_min)
    t_min = t_space[min_idx]
    plt.plot(t_space, E_ls)
    plt.scatter(t_min, E_min, color='red', label=f"({t_min:.2f}, {E_min:.2f})")
    plt.title(f'DBQA gain with time - XXZ (L={L})')
    plt.xlabel('time')
    plt.ylabel(r'$\langle H\rangle$')
    plt.legend()

# %%
gci_circ.gate_names
# Out:
# Counter({'h': 384,
#          'rzz': 181,
#          'sdg': 90,
#          's': 90,
#          'x': 48,
#          'rxx': 46,
#          'ryy': 46,
#          'rz': 32,
#          'cx': 24})

# %%
print("Circuit depth:", gci_circ.depth)
print("Circuit total gate count:", gci_circ.ngates)
print("Circuit CX count:", gci_circ.gate_names['cx'])
print("Estimated equivalent CZ count:", gci_circ.gate_names['cx']+
      gci_circ.gate_names['rxx']+gci_circ.gate_names['ryy']+gci_circ.gate_names['rzz']
      )
# Out:
# Circuit depth: 83
# Circuit total gate count: 941
# Circuit CX count: 24
# Circuit CZ count: 297

# %% [markdown]
# ## Optimize parameters

# %% [markdown]
# ### Fixed D optimize t
#
# Here we expect the same value as the grid search but faster run time.

# %%
from scipy.optimize import minimize_scalar
coefs = [1] * L
def objective(t):
    H_sim_fun = lambda t: XXZ_simulation(L, delta, t)
    D_circ_fun = lambda t: magnetic_field_circ(coefs, t)
    gci_circ, gci_val = GCI(H_XXZ, H_sim_fun, D_circ_fun, init_circ, t)
    return gci_val

# %%
res = minimize_scalar(
    objective,                  
    method='brent',    
    options={'maxiter': 15,
             'xtol': 1e-3} 
)
print(res.fun)
print(res.x)
# Out:
# -27.327291516178352
# 0.14351650971963992

# %% [markdown]
# ### Optimize both D and t

# %%
from scipy.optimize import minimize
coefs = [1] * L
D_s = coefs + [0.1]
def objective(D_s):
    coefs = D_s[:-1]
    t = D_s[-1]
    H_sim_fun = lambda t: XXZ_simulation(L, delta, t)
    D_circ_fun = lambda t: magnetic_field_circ(coefs, t)
    gci_circ, gci_val = GCI(H_XXZ, H_sim_fun, D_circ_fun, init_circ, t)
    return gci_val

# %%
max_iter = 1000
result = minimize(
    objective,
    D_s,
    method="COBYLA",
    options={"disp": True, "maxiter": max_iter},
    tol=1e-2,
)

print(result.fun)
print(result.x)
# Out:
# Return from COBYLA because the trust region radius reaches its lower bound.
# Number of function values = 111   Least value of F = -27.306620269782684
# The corresponding X is:
# [1.94500013 1.94499979 1.94500054 1.94500004 1.94500005 1.94500031
#  1.94500042 1.94499978 1.94500016 1.94499983 1.94500002 1.94500011
#  1.99499996 1.00499996 1.9949998  1.98250001 0.09964276]
#
# -27.306620269782684
# [1.94500013 1.94499979 1.94500054 1.94500004 1.94500005 1.94500031
#  1.94500042 1.94499978 1.94500016 1.94499983 1.94500002 1.94500011
#  1.99499996 1.00499996 1.9949998  1.98250001 0.09964276]
