# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
from copy import deepcopy

from qibo.backends import construct_backend
from qibo import hamiltonians, Circuit, gates, set_backend
from qibo import gates, symbols
from qibo.gates import Unitary, CNOT, CZ
from qibo.symbols import X, Y, Z
from qibo import hamiltonians
from qibo.hamiltonians import Hamiltonian, SymbolicHamiltonian

from db_doi.group_commutator_iteration import GroupCommutatorIteration, DoubleBracketRotationApproximationType
from db_doi.utils_XXZ_compilation import *
# Out:
# /home/marek/.local/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# #### 1 For each $L$ run HVA

# %%
def run_HVA_training(L, nlayers_max = 2, niter = 1):
    print("---------------\n\n")
    print(f"Initializing HVA training for L={L} and up to {nlayers_max} layers.")
    print(f"Will not run basinhopping." if niter == 0 else f"Will run basinhopping with {niter} iterations")

    H_XXZ = XXZ_compilation_line(L,gateset="CNOT")

    data_collection = {}
    E0,E1 = H_XXZ.eigenergies_ED()
    print(E0,E1)
    data_collection["E0"] = E0
    data_collection["E1"] = E1

    HVA_circ = {}

    for nlayers in range(1,nlayers_max+1):
        print(f"\nRunning layer number {nlayers} for system size L={L}")
        HVA_circ, E_HVA, t_HVA = H_XXZ.find_XXZ_HVA_circuit(nlayers=nlayers, please_use_basinhopping= niter)
        data_collection[f"HVA_Nlayers_{nlayers}"] = { "nlayers": nlayers, "circuit": HVA_circ, "E_HVA": E_HVA, "t_HVA": t_HVA } 

    from db_doi.utils_reporting import save_data, simulation_data_path
    save_data(data_collection, simulation_data_path() + f"XXZ_HVA_data_L{L}")

# %%
run_HVA_training(6,6,3)
# Out:
# ---------------
#
#
# Initializing HVA training for L=6 and up to 6 layers.
# Will run basinhopping with 3 iterations
# [Qibo 0.2.21|INFO|2025-08-05 22:53:45]: Using qibojit (numba) backend on /CPU:0
# -9.974308535551723 -8.00798142759415
#
# Running layer number 1 for system size L=6
# Initial loss: -9.3523324962421
# basinhopping step 0: f -9.881
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =   31   F =-9.880996E+00    MAXCV = 0.000000E+00
#    X = 2.160346E-01   1.417298E-01
# basinhopping step 1: f -9.80237 trial_f -9.80237 accepted 1  lowest_f -9.881
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =   39   F =-9.802367E+00    MAXCV = 0.000000E+00
#    X = 9.961355E-01   1.695491E+00
# basinhopping step 2: f -9.80237 trial_f -9.80237 accepted 1  lowest_f -9.881
#    Normal return from subroutine COBYLA
#
#    NFVALS =   34   F =-9.802367E+00    MAXCV = 0.000000E+00
#    X = 9.962032E-01   1.695482E+00
#
# basinhopping step 3: f -9.80237 trial_f -9.80237 accepted 1  lowest_f -9.881
# Final cost function:
# -9.880995628986685
# Parameters yielding final value:
# [0.21603462 0.14172978]
#
# Running layer number 2 for system size L=6
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =   37   F =-9.802367E+00    MAXCV = 0.000000E+00
#    X = 2.567089E+00   1.695317E+00
# Initial loss: -7.564254688837972
# basinhopping step 0: f -9.92234
#    Normal return from subroutine COBYLA
#
#    NFVALS =  207   F =-9.922344E+00    MAXCV = 0.000000E+00
#    X = 1.168550E+00   1.063222E-01   1.980905E-01   2.375301E-01
#
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-9.886673E+00    MAXCV = 0.000000E+00
#    X = 2.623875E+00   3.066029E-02   1.379779E+00  -1.220345E-01
#
# basinhopping step 1: f -9.92234 trial_f -9.88667 accepted 0  lowest_f -9.92234
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-9.899976E+00    MAXCV = 0.000000E+00
#    X = 1.935523E+00   9.642253E-02  -1.801521E-01  -5.041443E-02
#
# basinhopping step 2: f -9.92234 trial_f -9.89998 accepted 0  lowest_f -9.92234
# basinhopping step 3: f -9.86411 trial_f -9.86411 accepted 1  lowest_f -9.92234
#
# Final cost function:
# -9.92234353585274
# Parameters yielding final value:
# [1.16854985 0.10632219 0.19809046 0.2375301 ]
#
# Running layer number 3 for system size L=6
#    Normal return from subroutine COBYLA
#
#    NFVALS =  263   F =-9.864107E+00    MAXCV = 0.000000E+00
#    X = 1.875787E+00   1.424880E+00   5.146200E-01   1.309461E+00
# Initial loss: -7.752414714946693
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-9.919595E+00    MAXCV = 0.000000E+00
#    X = 1.405668E+00   6.351578E-02   1.260269E+00   7.216357E-02   2.067884E-01
#        2.369455E-01
#
# basinhopping step 0: f -9.9196
# basinhopping step 1: f -9.96568 trial_f -9.96568 accepted 1  lowest_f -9.96568
#    Normal return from subroutine COBYLA
#
#    NFVALS =  433   F =-9.965678E+00    MAXCV = 0.000000E+00
#    X = 8.741262E-01  -5.116139E-01   2.246485E+00   7.591428E-01   2.128257E-01
#        6.575422E-01
#
# found new global minimum on step 1 with function value -9.96568
# basinhopping step 2: f -9.96914 trial_f -9.96914 accepted 1  lowest_f -9.96914
#    Normal return from subroutine COBYLA
#
#    NFVALS =  605   F =-9.969138E+00    MAXCV = 0.000000E+00
#    X = 1.081825E+00   6.761471E-01   1.981866E+00   1.540020E+00  -2.398715E-01
#        6.364329E-01
#
# found new global minimum on step 2 with function value -9.96914
# basinhopping step 3: f -9.97379 trial_f -9.97379 accepted 1  lowest_f -9.97379
#    Normal return from subroutine COBYLA
#
#    NFVALS =  387   F =-9.973786E+00    MAXCV = 0.000000E+00
#    X = 1.063760E+00   1.333960E-01   1.498799E+00   9.380420E-01   7.320737E-01
#        6.064574E-01
#
# found new global minimum on step 3 with function value -9.97379
# Final cost function:
# -9.97378633791881
# Parameters yielding final value:
# [1.06376007 0.13339597 1.49879883 0.93804198 0.7320737  0.6064574 ]
#
# Running layer number 4 for system size L=6
# Initial loss: -6.820252391719599
# basinhopping step 0: f -9.97408
#    Normal return from subroutine COBYLA
#
#    NFVALS =  356   F =-9.974082E+00    MAXCV = 0.000000E+00
#    X = 2.376941E-01   8.991663E-02   2.400597E-01   1.180062E-01   1.445049E-01
#        2.010787E-01  -4.866451E-02  -4.146173E-02
#
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-9.881516E+00    MAXCV = 0.000000E+00
#    X =-1.098734E-03   1.293854E+00  -1.184385E-01  -1.056180E-01   5.676015E-02
#        1.581246E-01   7.108282E-01   1.289184E-01
#
# basinhopping step 1: f -9.97408 trial_f -9.88152 accepted 0  lowest_f -9.97408
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-9.971826E+00    MAXCV = 0.000000E+00
#    X =-1.066131E-01  -1.796829E-01   1.640432E+00  -3.584555E-01   1.025893E+00
#        6.144381E-01   1.513237E-01   1.764645E-01
#
# basinhopping step 2: f -9.97408 trial_f -9.97183 accepted 0  lowest_f -9.97408
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-9.962038E+00    MAXCV = 0.000000E+00
#    X = 1.378721E-01   2.962561E-01   1.101779E+00  -2.269194E-01   1.470788E+00
#        8.019600E-02  -5.321420E-01   3.040811E-01
#
# basinhopping step 3: f -9.97408 trial_f -9.96204 accepted 0  lowest_f -9.97408
# Final cost function:
# -9.974082039727117
# Parameters yielding final value:
# [ 0.23769409  0.08991663  0.24005972  0.1180062   0.14450492  0.20107866
#  -0.04866451 -0.04146173]
#
# Running layer number 5 for system size L=6
# Initial loss: -7.861017355223032
# basinhopping step 0: f -9.9743
#    Normal return from subroutine COBYLA
#
#    NFVALS =  411   F =-9.974301E+00    MAXCV = 0.000000E+00
#    X = 1.253741E+00   1.970282E-01   1.244165E+00   2.272175E-01   1.209843E+00
#        1.734586E-01   1.301775E+00   7.593793E-02   1.737763E-01   1.426588E-01
#
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-9.973776E+00    MAXCV = 0.000000E+00
#    X = 2.288678E+00  -7.787340E-01   1.942966E+00   6.642849E-02   6.896883E-01
#        2.418467E-02   1.466729E+00  -2.616599E-01   2.905204E-01  -2.667334E-01
#
# basinhopping step 1: f -9.9743 trial_f -9.97378 accepted 0  lowest_f -9.9743
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-9.963408E+00    MAXCV = 0.000000E+00
#    X = 8.324286E-01  -1.566661E-01   2.238361E+00   2.256090E-01   1.753411E+00
#        1.543166E+00   1.753869E+00  -1.279399E-01   1.307593E+00  -1.613520E-01
#
# basinhopping step 2: f -9.9743 trial_f -9.96341 accepted 0  lowest_f -9.9743
# basinhopping step 3: f -9.97425 trial_f -9.97425 accepted 1  lowest_f -9.9743
#    Normal return from subroutine COBYLA
#
#    NFVALS =  590   F =-9.974255E+00    MAXCV = 0.000000E+00
#    X = 1.972853E+00   1.197858E+00   1.740834E+00   2.507788E-01   1.441484E+00
#        3.461608E-01   9.866073E-01   8.932824E-01   4.340333E-02   4.226528E-01
#
# Final cost function:
# -9.974301486475643
# Parameters yielding final value:
# [1.25374102 0.19702821 1.24416476 0.2272175  1.20984329 0.1734586
#  1.30177461 0.07593793 0.17377627 0.14265878]
#
# Running layer number 6 for system size L=6
# Initial loss: -9.862414805069196
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-9.970371E+00    MAXCV = 0.000000E+00
#    X = 2.947810E-01   1.684657E-01   2.539334E-01   2.238893E-01   2.805994E-01
#        2.467016E-01   2.431363E-01   2.296077E-01   2.861789E-01   2.342657E-01
#        1.934472E-01   2.386530E-01
#
# basinhopping step 0: f -9.97037
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-9.968676E+00    MAXCV = 0.000000E+00
#    X =-1.137913E-01  -3.496896E-01   2.034874E-01  -5.864330E-02   1.375533E-01
#        5.569283E-01   4.765769E-01   2.107489E-01   8.206467E-01  -2.003366E-02
#        1.144290E+00   4.689083E-01
#
# basinhopping step 1: f -9.96868 trial_f -9.96868 accepted 1  lowest_f -9.97037
# basinhopping step 2: f -9.9743 trial_f -9.9743 accepted 1  lowest_f -9.9743
#    Normal return from subroutine COBYLA
#
#    NFVALS =  388   F =-9.974298E+00    MAXCV = 0.000000E+00
#    X = 6.575721E-01   5.709079E-01   3.975485E-01   6.114789E-01   2.174502E-01
#        4.673451E-01   1.096267E-01   5.857843E-02   1.239524E+00   3.228460E-01
#        1.678314E+00   3.627427E-01
#
# found new global minimum on step 2 with function value -9.9743
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-9.973880E+00    MAXCV = 0.000000E+00
#    X = 1.454777E+00   3.362021E-01   1.704105E+00  -2.740121E-01   4.354159E-01
#        1.308102E+00  -3.845940E-01  -9.934417E-02   9.002393E-01  -6.027843E-02
#        9.981952E-01   1.158636E-01
#
# basinhopping step 3: f -9.9743 trial_f -9.97388 accepted 0  lowest_f -9.9743
# Final cost function:
# -9.97429800597079
# Parameters yielding final value:
# [0.65757213 0.57090794 0.39754849 0.61147888 0.21745021 0.46734511
#  0.10962667 0.05857843 1.23952408 0.32284602 1.67831353 0.36274272]

# %%
run_HVA_training(8,6,3)
# Out:
# ---------------
#
#
# Initializing HVA training for L=8 and up to 6 layers.
# Will run basinhopping with 3 iterations
# -13.499730394751603 -11.928961951051525
#
# Running layer number 1 for system size L=8
# Initial loss: -12.434890163749998
# basinhopping step 0: f -13.2998
#    Normal return from subroutine COBYLA
#
#    NFVALS =   40   F =-1.329982E+01    MAXCV = 0.000000E+00
#    X = 2.161001E-01   1.386892E-01
#
# basinhopping step 1: f -13.1617 trial_f -13.1617 accepted 1  lowest_f -13.2998
#    Normal return from subroutine COBYLA
#
#    NFVALS =   40   F =-1.316172E+01    MAXCV = 0.000000E+00
#    X = 5.756349E-01   1.451508E+00
#
# basinhopping step 2: f -13.1617 trial_f -13.1617 accepted 1  lowest_f -13.2998
#    Normal return from subroutine COBYLA
#
#    NFVALS =   40   F =-1.316172E+01    MAXCV = 0.000000E+00
#    X = 5.754905E-01   1.451412E+00
#
# basinhopping step 3: f -13.1617 trial_f -13.1617 accepted 1  lowest_f -13.2998
#    Normal return from subroutine COBYLA
#
#    NFVALS =   36   F =-1.316172E+01    MAXCV = 0.000000E+00
#    X = 9.954055E-01   1.690061E+00
#
# Final cost function:
# -13.299821655477515
# Parameters yielding final value:
# [0.2161001  0.13868919]
#
# Running layer number 2 for system size L=8
# Initial loss: -9.976144466811284
# basinhopping step 0: f -13.371
#    Normal return from subroutine COBYLA
#
#    NFVALS =  220   F =-1.337099E+01    MAXCV = 0.000000E+00
#    X = 1.160970E+00   9.906681E-02   1.965113E-01   2.261232E-01
#
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.332652E+01    MAXCV = 0.000000E+00
#    X = 1.287573E+00   1.475221E+00   1.309817E-01   6.276831E-02
#
# basinhopping step 1: f -13.371 trial_f -13.3265 accepted 0  lowest_f -13.371
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.335527E+01    MAXCV = 0.000000E+00
#    X = 2.407387E+00   9.001178E-02   1.381737E+00  -2.151100E-01
#
# basinhopping step 2: f -13.371 trial_f -13.3553 accepted 0  lowest_f -13.371
# basinhopping step 3: f -13.1617 trial_f -13.1617 accepted 1  lowest_f -13.371
#    Normal return from subroutine COBYLA
#
#    NFVALS =  240   F =-1.316175E+01    MAXCV = 0.000000E+00
#    X = 2.122175E+00  -2.296303E-03   9.929288E-01   1.184601E-01
#
# Final cost function:
# -13.37098731105816
# Parameters yielding final value:
# [1.16096956 0.09906681 0.19651126 0.22612322]
#
# Running layer number 3 for system size L=8
# Initial loss: -10.590203628213008
# warning: basinhopping: local minimization failure
# basinhopping step 0: f -13.344
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.334402E+01    MAXCV = 0.000000E+00
#    X = 1.429763E-01  -8.467406E-02   3.254041E-01   9.416771E-02   1.191596E-01
#        9.979435E-02
# basinhopping step 1: f -13.3716 trial_f -13.3716 accepted 1  lowest_f -13.3716
#    Normal return from subroutine COBYLA
#
#    NFVALS =  691   F =-1.337157E+01    MAXCV = 0.000000E+00
#    X = 1.158052E-01  -8.994934E-03   4.007038E-01  -9.422107E-02   1.374652E+00
#       -2.260605E-01
#
# found new global minimum on step 1 with function value -13.3716
# basinhopping step 2: f -13.3745 trial_f -13.3745 accepted 1  lowest_f -13.3745
#    Normal return from subroutine COBYLA
#
#    NFVALS =  327   F =-1.337452E+01    MAXCV = 0.000000E+00
#    X = 1.953224E-02   1.689259E+00  -3.231138E-02  -9.856201E-01   1.355916E+00
#       -8.660518E-01
#
# found new global minimum on step 2 with function value -13.3745
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.337800E+01    MAXCV = 0.000000E+00
#    X = 9.178681E-03   2.015692E+00  -3.992053E-02  -1.320345E+00   1.346087E+00
#       -8.620216E-01
#
# basinhopping step 3: f -13.3745 trial_f -13.378 accepted 0  lowest_f -13.3745
# Final cost function:
# -13.374515714087316
# Parameters yielding final value:
# [ 0.01953224  1.68925939 -0.03231138 -0.98562008  1.35591599 -0.86605181]
#
# Running layer number 4 for system size L=8
# Initial loss: -10.17859629222436
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.347408E+01    MAXCV = 0.000000E+00
#    X = 2.667597E-01   1.007815E-01   2.077724E-01   1.245128E-01   1.963287E-01
#        1.479392E-01  -1.271599E-01  -4.296992E-02
#
# basinhopping step 0: f -13.4741
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.341567E+01    MAXCV = 0.000000E+00
#    X = 1.136410E+00   6.785018E-01   1.568498E+00   2.471228E-01   3.786146E-01
#       -2.721803E-01  -2.393181E-01   6.874157E-01
#
# basinhopping step 1: f -13.4157 trial_f -13.4157 accepted 1  lowest_f -13.4741
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.324290E+01    MAXCV = 0.000000E+00
#    X = 1.066415E+00   6.515467E-01   2.081792E+00   9.791930E-04   1.885507E+00
#        8.064356E-01   5.228062E-01   1.343764E+00
#
# basinhopping step 2: f -13.4157 trial_f -13.2429 accepted 0  lowest_f -13.4741
# basinhopping step 3: f -13.4357 trial_f -13.4357 accepted 1  lowest_f -13.4357
#    Normal return from subroutine COBYLA
#
#    NFVALS =  679   F =-1.343569E+01    MAXCV = 0.000000E+00
#    X = 2.302827E+00   1.722860E+00   1.659562E+00   1.481101E+00   3.601226E-02
#       -7.184944E-01  -5.469772E-01   8.187043E-01
#
# found new global minimum on step 3 with function value -13.4357
# Final cost function:
# -13.435685955586246
# Parameters yielding final value:
# [ 2.30282716  1.72286004  1.65956187  1.48110144  0.03601226 -0.71849443
#  -0.54697717  0.81870433]
#
# Running layer number 5 for system size L=8
# Initial loss: -9.613773344778169
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.345212E+01    MAXCV = 0.000000E+00
#    X = 1.210345E+00   1.164919E-01   1.304318E+00   2.084533E-01   1.313170E+00
#        2.547219E-01   1.249928E+00   2.917836E-01   1.951442E-01   2.631240E-01
#
# basinhopping step 0: f -13.4521
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.344162E+01    MAXCV = 0.000000E+00
#    X = 1.964776E+00   8.410045E-01   2.734653E+00   1.558422E+00   1.120890E+00
#        8.192102E-01   1.512619E+00   3.603445E-01   2.577613E-01   1.410936E+00
#
# basinhopping step 1: f -13.4416 trial_f -13.4416 accepted 1  lowest_f -13.4521
# warning: basinhopping: local minimization failure
# basinhopping step 2: f -13.3646 trial_f -13.3646 accepted 1  lowest_f -13.4521
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.336461E+01    MAXCV = 0.000000E+00
#    X = 2.276874E+00   8.814940E-01   2.443217E+00   1.587265E+00   2.188754E+00
#        6.642963E-01   1.544077E+00   6.428546E-01   1.369461E+00   7.823795E-01
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.346615E+01    MAXCV = 0.000000E+00
#    X = 2.770276E+00   1.512348E+00   3.393852E+00   3.077848E+00   2.761828E+00
#        1.525522E+00   1.918346E+00   1.079108E-01   1.732305E+00   2.554445E-01
#
# basinhopping step 3: f -13.4662 trial_f -13.4662 accepted 1  lowest_f -13.4521
# Final cost function:
# -13.452122922986014
# Parameters yielding final value:
# [1.21034453 0.11649187 1.30431794 0.20845332 1.31316961 0.25472192
#  1.24992811 0.29178363 0.19514418 0.26312399]
#
# Running layer number 6 for system size L=8
# Initial loss: -9.177842255454074
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.348156E+01    MAXCV = 0.000000E+00
#    X = 3.724168E-01   9.836614E-02   3.546414E-01   1.762453E-01   3.628547E-01
#        1.338190E-01   1.634930E-01   7.793026E-02   3.341248E-01   1.254756E-01
#        1.599529E-01   2.351783E-01
#
# basinhopping step 0: f -13.4816
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.337893E+01    MAXCV = 0.000000E+00
#    X = 5.082696E-02  -6.037528E-01   5.676926E-02   1.113873E+00   2.646467E-01
#       -4.163450E-01  -7.095792E-01  -5.831510E-02  -3.310819E-01   1.503587E+00
#        3.300464E-02   1.552501E+00
#
# basinhopping step 1: f -13.3789 trial_f -13.3789 accepted 1  lowest_f -13.4816
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.333575E+01    MAXCV = 0.000000E+00
#    X = 1.261491E+00  -3.181118E-02   4.709316E-01   1.519535E+00   3.231312E-01
#       -1.337973E-01  -3.247180E-01  -2.425525E-01  -1.029007E-01   1.780802E+00
#        5.465394E-01   1.102185E+00
#
# basinhopping step 2: f -13.3357 trial_f -13.3357 accepted 1  lowest_f -13.4816
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.346496E+01    MAXCV = 0.000000E+00
#    X = 2.112471E+00   1.331844E-01   5.297911E-01   1.689436E+00   7.303122E-01
#        1.062654E+00  -7.037027E-01   1.580219E+00  -4.997810E-01   2.158943E+00
#        1.309485E+00   1.414006E+00
#
# basinhopping step 3: f -13.465 trial_f -13.465 accepted 1  lowest_f -13.4816
# Final cost function:
# -13.48155595097533
# Parameters yielding final value:
# [0.37241679 0.09836614 0.35464136 0.17624535 0.3628547  0.13381902
#  0.16349304 0.07793026 0.33412484 0.12547556 0.15995286 0.23517831]

# %%
run_HVA_training(10,6,3)
# Out:
# ---------------
#
#
# Initializing HVA training for L=10 and up to 6 layers.
# Will run basinhopping with 3 iterations
# -17.032140829131595 -15.722694358006184
#
# Running layer number 1 for system size L=10
# Initial loss: -15.517447831257897
# basinhopping step 0: f -16.7193
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =   38   F =-1.671931E+01    MAXCV = 0.000000E+00
#    X = 2.161186E-01   1.369796E-01
# basinhopping step 1: f -16.5234 trial_f -16.5234 accepted 1  lowest_f -16.7193
#    Normal return from subroutine COBYLA
#
#    NFVALS =   36   F =-1.652341E+01    MAXCV = 0.000000E+00
#    X = 5.759661E-01   1.453980E+00
#
# basinhopping step 2: f -16.7193 trial_f -16.7193 accepted 1  lowest_f -16.7193
# found new global minimum on step 2 with function value -16.7193
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =   36   F =-1.671931E+01    MAXCV = 0.000000E+00
#    X = 1.354743E+00   1.433667E+00
# basinhopping step 3: f -16.5234 trial_f -16.5234 accepted 1  lowest_f -16.7193
#    Normal return from subroutine COBYLA
#
#    NFVALS =   37   F =-1.652341E+01    MAXCV = 0.000000E+00
#    X = 5.758891E-01   1.454014E+00
#
# Final cost function:
# -16.719306343752383
# Parameters yielding final value:
# [1.35474266 1.43366724]
#
# Running layer number 2 for system size L=10
# Initial loss: -12.37952655032684
# basinhopping step 0: f -16.8212
#    Normal return from subroutine COBYLA
#
#    NFVALS =  162   F =-1.682125E+01    MAXCV = 0.000000E+00
#    X = 1.159714E+00   9.751026E-02   1.967775E-01   2.229511E-01
#
# basinhopping step 1: f -16.671 trial_f -16.671 accepted 1  lowest_f -16.8212
#    Normal return from subroutine COBYLA
#
#    NFVALS =  609   F =-1.667095E+01    MAXCV = 0.000000E+00
#    X = 1.480913E+00   1.287846E+00   7.654583E-01   2.140374E-01
#
# basinhopping step 2: f -16.5232 trial_f -16.5232 accepted 1  lowest_f -16.8212
#    Normal return from subroutine COBYLA
#
#    NFVALS =  380   F =-1.652317E+01    MAXCV = 0.000000E+00
#    X = 1.564511E+00   1.604600E+00   9.968093E-01   8.303849E-02
#
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.672694E+01    MAXCV = 0.000000E+00
#    X = 2.353986E+00   1.621936E+00   1.788258E+00   1.658488E+00
#
# basinhopping step 3: f -16.5232 trial_f -16.7269 accepted 0  lowest_f -16.8212
# Final cost function:
# -16.821245598739488
# Parameters yielding final value:
# [1.15971445 0.09751026 0.1967775  0.22295107]
#
# Running layer number 3 for system size L=10
# Initial loss: -13.223574697645489
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.695640E+01    MAXCV = 0.000000E+00
#    X =-1.892843E-01  -9.001695E-02   2.666521E-01   1.182334E-01   1.666067E-01
#        2.379906E-01
#
# basinhopping step 0: f -16.9564
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.679667E+01    MAXCV = 0.000000E+00
#    X = 1.154897E+00   2.620248E-01   2.078736E+00   1.633231E+00   6.853085E-01
#       -2.631773E-01
#
# basinhopping step 1: f -16.7967 trial_f -16.7967 accepted 1  lowest_f -16.9564
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.694978E+01    MAXCV = 0.000000E+00
#    X = 1.801760E+00   1.394374E-01   3.278199E+00   1.578411E+00   1.713883E-01
#        2.373245E-01
#
# basinhopping step 2: f -16.9498 trial_f -16.9498 accepted 1  lowest_f -16.9564
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.679279E+01    MAXCV = 0.000000E+00
#    X = 1.329800E+00   1.505912E+00   3.879262E+00   1.582077E+00  -1.731123E-01
#       -1.744759E-01
#
# basinhopping step 3: f -16.7928 trial_f -16.7928 accepted 1  lowest_f -16.9564
# Final cost function:
# -16.956398519606598
# Parameters yielding final value:
# [-0.18928432 -0.09001695  0.26665206  0.11823337  0.16660668  0.2379906 ]
#
# Running layer number 4 for system size L=10
# Initial loss: -12.803442215760985
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.695892E+01    MAXCV = 0.000000E+00
#    X = 3.208718E-01   1.304842E-01   9.572983E-02   1.175906E-01   1.424459E-01
#        1.358949E-01   3.082606E-02   3.235004E-02
#
# basinhopping step 0: f -16.9589
# warning: basinhopping: local minimization failure
# basinhopping step 1: f -16.9571 trial_f -16.9571 accepted 1  lowest_f -16.9589
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.695712E+01    MAXCV = 0.000000E+00
#    X = 7.902267E-01  -8.355638E-02  -6.467003E-02  -1.721615E-01   1.975518E-01
#        2.914346E-01   1.559961E-01   1.886013E-01
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.686650E+01    MAXCV = 0.000000E+00
#    X = 4.823602E-01   9.010853E-01  -4.388386E-01   1.917172E-02   1.557219E+00
#        4.840909E-01   2.224547E-01   3.629054E-01
#
# basinhopping step 2: f -16.8665 trial_f -16.8665 accepted 1  lowest_f -16.9589
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.688075E+01    MAXCV = 0.000000E+00
#    X = 7.869097E-01   1.468289E+00  -4.617350E-01   5.421073E-02   1.532453E+00
#        7.314411E-01  -2.490827E-01   6.258354E-01
#
# basinhopping step 3: f -16.8807 trial_f -16.8807 accepted 1  lowest_f -16.9589
# Final cost function:
# -16.958918560513986
# Parameters yielding final value:
# [0.32087184 0.13048416 0.09572983 0.11759057 0.14244594 0.13589491
#  0.03082606 0.03235004]
#
# Running layer number 5 for system size L=10
# Initial loss: -12.970288333461873
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.677880E+01    MAXCV = 0.000000E+00
#    X = 3.151702E-01  -1.463865E-01   2.651224E-02   3.577171E-02   6.110606E-02
#        2.295815E-02   2.100934E-01  -6.560960E-02   7.082748E-01  -1.112831E-02
#
# basinhopping step 0: f -16.7788
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.681388E+01    MAXCV = 0.000000E+00
#    X = 1.536493E+00   6.659971E-01  -1.224826E-01   1.085513E+00  -2.703014E-01
#       -2.341386E-01  -3.360784E-02  -5.891585E-01   2.380772E+00  -8.524967E-01
#
# basinhopping step 1: f -16.8139 trial_f -16.8139 accepted 1  lowest_f -16.7788
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.696595E+01    MAXCV = 0.000000E+00
#    X = 3.147947E+00   1.275057E+00   7.574658E-01   5.100698E-01  -7.381331E-01
#        9.045042E-03  -3.435850E-01  -3.561984E-01   2.981618E+00  -2.330449E-01
#
# basinhopping step 2: f -16.966 trial_f -16.966 accepted 1  lowest_f -16.7788
# warning: basinhopping: local minimization failure
#
# basinhopping step 3: f -16.8162 trial_f -16.8162 accepted 1  lowest_f -16.7788
# Final cost function:
# -16.778799840930915
# Parameters yielding final value:
# [ 0.31517015 -0.14638645  0.02651224  0.03577171  0.06110606  0.02295815
#   0.21009339 -0.0656096   0.70827477 -0.01112831]
#
# Running layer number 6 for system size L=10
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.681623E+01    MAXCV = 0.000000E+00
#    X = 3.072536E+00   1.910106E+00   1.178278E+00   1.182447E+00   7.376991E-03
#        7.743777E-01   8.341446E-01  -7.426037E-01   2.258129E+00  -9.246658E-02
# Initial loss: -12.339719038421265
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.697142E+01    MAXCV = 0.000000E+00
#    X = 3.101544E-01   5.620808E-02   2.979599E-01  -1.756744E-02   3.318857E-01
#        5.763734E-02   1.824149E-01   9.420354E-02   9.037093E-02   1.138789E-01
#        1.250536E-01   1.173574E-01
#
# basinhopping step 0: f -16.9714
# basinhopping step 1: f -16.9974 trial_f -16.9974 accepted 1  lowest_f -16.9974
#    Normal return from subroutine COBYLA
#
#    NFVALS =  688   F =-1.699740E+01    MAXCV = 0.000000E+00
#    X =-1.436052E-01   2.156413E-01  -2.820307E-01   1.367324E+00   2.425562E-02
#       -4.424614E-01   1.460798E-01   5.993935E-01  -5.107169E-02   3.637764E-01
#        2.278940E-01  -1.497030E-01
#
# found new global minimum on step 1 with function value -16.9974
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.685603E+01    MAXCV = 0.000000E+00
#    X = 1.563972E+00   3.801559E-02   2.457520E-01   1.220329E+00  -1.458930E-01
#       -2.431939E-02   1.451695E+00   1.845558E+00   1.469702E-02   5.378467E-01
#        5.654137E-01  -5.051748E-01
#
# basinhopping step 2: f -16.9974 trial_f -16.856 accepted 0  lowest_f -16.9974
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.680069E+01    MAXCV = 0.000000E+00
#    X = 7.460117E-01  -9.476105E-02   1.588020E-02   2.109541E+00   5.763365E-02
#       -7.915795E-01  -6.471875E-02   3.955648E-01   7.990043E-01   1.718106E-01
#        5.512798E-01  -2.939970E-01
#
# basinhopping step 3: f -16.9974 trial_f -16.8007 accepted 0  lowest_f -16.9974
# Final cost function:
# -16.997397597822264
# Parameters yielding final value:
# [-0.14360525  0.21564133 -0.28203071  1.36732408  0.02425562 -0.44246137
#   0.14607975  0.59939354 -0.05107169  0.36377637  0.22789403 -0.149703  ]

# %%
run_HVA_training(12,6,3)
# Out:
# ---------------
#
#
# Initializing HVA training for L=12 and up to 6 layers.
# Will run basinhopping with 3 iterations
# -20.568362531362006 -19.444591748145438
#
# Running layer number 1 for system size L=12
# Initial loss: -18.600005498765803
# basinhopping step 0: f -20.139
#    Normal return from subroutine COBYLA
#
#    NFVALS =   35   F =-2.013903E+01    MAXCV = 0.000000E+00
#    X = 2.161222E-01   1.363896E-01
#
# basinhopping step 1: f -20.139 trial_f -20.139 accepted 1  lowest_f -20.139
#    Normal return from subroutine COBYLA
#
#    NFVALS =   40   F =-2.013904E+01    MAXCV = 0.000000E+00
#    X = 1.354772E+00  -1.362788E-01
#
# found new global minimum on step 1 with function value -20.139
# basinhopping step 2: f -19.886 trial_f -19.886 accepted 1  lowest_f -20.139
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =   34   F =-1.988595E+01    MAXCV = 0.000000E+00
#    X = 2.565331E+00   1.154999E-01
# basinhopping step 3: f -20.139 trial_f -20.139 accepted 1  lowest_f -20.139
#    Normal return from subroutine COBYLA
#
#    NFVALS =   35   F =-2.013904E+01    MAXCV = 0.000000E+00
#    X = 3.357653E+00   1.362325E-01
#
# found new global minimum on step 3 with function value -20.139
# Final cost function:
# -20.13903637176893
# Parameters yielding final value:
# [3.35765334 0.1362325 ]
#
# Running layer number 2 for system size L=12
# Initial loss: -14.782424885819594
# basinhopping step 0: f -20.2719
#    Normal return from subroutine COBYLA
#
#    NFVALS =  151   F =-2.027191E+01    MAXCV = 0.000000E+00
#    X = 1.160034E+00   9.714642E-02   1.975205E-01   2.222097E-01
#
# basinhopping step 1: f -20.1629 trial_f -20.1629 accepted 1  lowest_f -20.2719
#    Normal return from subroutine COBYLA
#
#    NFVALS =  104   F =-2.016290E+01    MAXCV = 0.000000E+00
#    X = 2.375065E+00  -1.260091E-01   1.014251E+00   2.389390E-01
#
# basinhopping step 2: f -19.886 trial_f -19.886 accepted 1  lowest_f -20.2719
#    Normal return from subroutine COBYLA
#
#    NFVALS =   82   F =-1.988598E+01    MAXCV = 0.000000E+00
#    X = 3.697199E+00  -2.581923E-03   9.915207E-01   1.144065E-01
#
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.023986E+01    MAXCV = 0.000000E+00
#    X = 3.675944E+00   1.170251E-01   1.265142E+00  -4.505055E-02
#
# basinhopping step 3: f -19.886 trial_f -20.2399 accepted 0  lowest_f -20.2719
# Final cost function:
# -20.271913478084066
# Parameters yielding final value:
# [1.16003394 0.09714642 0.19752049 0.22220972]
#
# Running layer number 3 for system size L=12
# Initial loss: -15.839774963989417
# basinhopping step 0: f -20.0186
#    Normal return from subroutine COBYLA
#
#    NFVALS =  296   F =-2.001856E+01    MAXCV = 0.000000E+00
#    X = 3.242511E-01  -1.088397E-01  -3.799070E-03   1.023294E-01   5.306732E-01
#       -3.208373E-01
#
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.026312E+01    MAXCV = 0.000000E+00
#    X = 1.427680E+00  -7.452179E-02  -5.862669E-01   1.663870E-01   7.682852E-01
#        3.240238E-02
#
# basinhopping step 1: f -20.0186 trial_f -20.2631 accepted 0  lowest_f -20.0186
# basinhopping step 2: f -20.0984 trial_f -20.0984 accepted 1  lowest_f -20.0984
#
# found new global minimum on step 2 with function value -20.0984
#    Normal return from subroutine COBYLA
#
#    NFVALS =  361   F =-2.009841E+01    MAXCV = 0.000000E+00
#    X = 1.136914E+00  -1.031330E-01   1.127527E+00  -2.207508E-01   5.662229E-01
#       -2.435392E-01
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.021836E+01    MAXCV = 0.000000E+00
#    X = 1.959471E+00   1.514778E+00   1.519391E+00   4.450452E-01   5.390935E-01
#       -6.568387E-01
#
# basinhopping step 3: f -20.0984 trial_f -20.2184 accepted 0  lowest_f -20.0984
# Final cost function:
# -20.0984056738681
# Parameters yielding final value:
# [ 1.13691367 -0.10313303  1.12752713 -0.22075082  0.5662229  -0.24353924]
#
# Running layer number 4 for system size L=12
# Initial loss: -15.30425980609765
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.044684E+01    MAXCV = 0.000000E+00
#    X = 3.389527E-01   1.336289E-01   7.446153E-02   1.427434E-01   1.429088E-01
#        1.069152E-01  -1.345436E-02  -9.968102E-03
#
# basinhopping step 0: f -20.4468
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.044664E+01    MAXCV = 0.000000E+00
#    X = 1.376306E+00  -2.285372E-02   5.136943E-02  -1.354564E-01  -3.907091E-01
#       -1.307519E-03  -1.704445E-01  -2.383906E-01
#
# basinhopping step 1: f -20.4466 trial_f -20.4466 accepted 1  lowest_f -20.4468
# basinhopping step 2: f -20.5179 trial_f -20.5179 accepted 1  lowest_f -20.5179
#    Normal return from subroutine COBYLA
#
#    NFVALS =  537   F =-2.051788E+01    MAXCV = 0.000000E+00
#    X = 1.180549E+00  -1.339581E-01   2.687729E-01  -2.823072E-01  -6.147987E-01
#       -1.213750E-02  -1.487606E-01  -2.520819E-01
#
# found new global minimum on step 2 with function value -20.5179
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.040191E+01    MAXCV = 0.000000E+00
#    X = 1.949662E+00  -1.037534E-01  -9.304963E-02  -2.020099E-01  -1.017697E+00
#        2.028866E-01  -3.849946E-01  -3.531314E-02
#
# basinhopping step 3: f -20.5179 trial_f -20.4019 accepted 0  lowest_f -20.5179
# Final cost function:
# -20.5178799118926
# Parameters yielding final value:
# [ 1.18054924 -0.13395812  0.26877288 -0.28230719 -0.61479874 -0.0121375
#  -0.1487606  -0.25208189]
#
# Running layer number 5 for system size L=12
# Initial loss: -15.608978555715812
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.045791E+01    MAXCV = 0.000000E+00
#    X = 2.270391E-01   1.110691E-01   1.300775E-01   7.771802E-02   5.514510E-02
#       -2.690179E-02   1.118744E-01   2.155956E-01   6.789613E-02   2.880183E-02
#
# basinhopping step 0: f -20.4579
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.034671E+01    MAXCV = 0.000000E+00
#    X = 1.602833E+00  -2.279418E-01  -4.169782E-01  -3.599425E-01   5.621420E-01
#       -4.884880E-04  -1.200237E-01   1.659911E+00   2.593749E-01   6.941735E-01
#
# basinhopping step 1: f -20.3467 trial_f -20.3467 accepted 1  lowest_f -20.4579
# warning: basinhopping: local minimization failure
# basinhopping step 2: f -20.3924 trial_f -20.3924 accepted 1  lowest_f -20.4579
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.039239E+01    MAXCV = 0.000000E+00
#    X = 1.522352E+00  -4.436786E-01  -5.231174E-02   6.672946E-01   2.058720E-01
#       -2.641192E-01   3.866874E-02   1.838065E+00  -1.631820E-01   1.175566E+00
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.045009E+01    MAXCV = 0.000000E+00
#    X = 1.574245E+00  -7.304662E-01   3.311103E-01   6.972828E-01   1.929874E-01
#        1.177485E-02   1.258773E+00   1.426731E+00   1.405700E+00   1.341874E+00
#
# basinhopping step 3: f -20.4501 trial_f -20.4501 accepted 1  lowest_f -20.4579
# Final cost function:
# -20.457909205265054
# Parameters yielding final value:
# [ 0.22703914  0.11106906  0.13007751  0.07771802  0.0551451  -0.02690179
#   0.11187438  0.21559555  0.06789613  0.02880183]
#
# Running layer number 6 for system size L=12
# Initial loss: -15.387731677649667
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.032686E+01    MAXCV = 0.000000E+00
#    X = 2.399116E-01  -1.125761E-01   1.554769E-01   4.824866E-03  -8.673224E-03
#       -1.511187E-01  -1.522294E-01   7.585646E-03   1.060900E-01   1.549771E-01
#       -1.838104E-02  -1.096974E-01
#
# basinhopping step 0: f -20.3269
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.044716E+01    MAXCV = 0.000000E+00
#    X = 9.787762E-01  -4.207526E-02   5.728362E-02  -3.614846E-01  -6.102487E-02
#        1.403189E-01   9.493165E-01   3.354530E-01   2.914109E-01   7.563965E-02
#        1.575486E-01   2.394057E-01
#
# basinhopping step 1: f -20.4472 trial_f -20.4472 accepted 1  lowest_f -20.3269
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.034484E+01    MAXCV = 0.000000E+00
#    X = 2.204505E+00  -8.023272E-02   5.095788E-01  -3.930075E-01   1.224463E-01
#       -3.044301E-02   9.192877E-01   3.219101E-02   6.126489E-01   2.787125E-01
#        7.688057E-01  -7.532942E-02
#
# basinhopping step 2: f -20.3448 trial_f -20.3448 accepted 1  lowest_f -20.3269
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-1.998435E+01    MAXCV = 0.000000E+00
#    X = 2.057743E+00  -7.693750E-03   4.430743E-01  -1.992388E-01  -1.458644E-01
#        2.250871E-01   2.410951E-01   9.826391E-01   2.070891E-01  -3.124952E-02
#        1.552697E+00  -5.974387E-02
#
# basinhopping step 3: f -19.9844 trial_f -19.9844 accepted 1  lowest_f -20.3269
# Final cost function:
# -20.32686229362789
# Parameters yielding final value:
# [ 0.23991164 -0.11257607  0.1554769   0.00482487 -0.00867322 -0.15111868
#  -0.15222937  0.00758565  0.10608999  0.15497709 -0.01838104 -0.10969744]

# %%
run_HVA_training(14,6,5)
# Out:
# ---------------
#
#
# Initializing HVA training for L=14 and up to 6 layers.
# Will run basinhopping with 5 iterations
# -24.106898647448645 -23.12197041784953
#
# Running layer number 1 for system size L=14
# Initial loss: -21.68256316627371
# basinhopping step 0: f -23.5589
#    Normal return from subroutine COBYLA
#
#    NFVALS =   37   F =-2.355888E+01    MAXCV = 0.000000E+00
#    X = 2.160326E-01   1.356905E-01
#
# basinhopping step 1: f -23.5589 trial_f -23.5589 accepted 1  lowest_f -23.5589
#    Normal return from subroutine COBYLA
#
#    NFVALS =   32   F =-2.355888E+01    MAXCV = 0.000000E+00
#    X =-2.161254E-01  -1.357582E-01
#
# found new global minimum on step 1 with function value -23.5589
# basinhopping step 2: f -23.5589 trial_f -23.2489 accepted 0  lowest_f -23.5589
#    Normal return from subroutine COBYLA
#
#    NFVALS =   39   F =-2.324888E+01    MAXCV = 0.000000E+00
#    X = 5.762843E-01  -1.145134E-01
#
# basinhopping step 3: f -23.5589 trial_f -23.5589 accepted 1  lowest_f -23.5589
#    Normal return from subroutine COBYLA
#
#    NFVALS =   36   F =-2.355888E+01    MAXCV = 0.000000E+00
#    X =-2.161638E-01  -1.357484E-01
#
# basinhopping step 4: f -23.5589 trial_f -23.5589 accepted 1  lowest_f -23.5589
#    Normal return from subroutine COBYLA
#
#    NFVALS =   33   F =-2.355888E+01    MAXCV = 0.000000E+00
#    X =-2.160315E-01  -1.356933E-01
#
# basinhopping step 5: f -23.2489 trial_f -23.2489 accepted 1  lowest_f -23.5589
#    Normal return from subroutine COBYLA
#
#    NFVALS =   38   F =-2.324888E+01    MAXCV = 0.000000E+00
#    X = 9.942992E-01   1.145468E-01
#
# Final cost function:
# -23.558884558539205
# Parameters yielding final value:
# [-0.2161254  -0.13575817]
#
# Running layer number 2 for system size L=14
# Initial loss: -17.185323221312345
# basinhopping step 0: f -23.7229
#    Normal return from subroutine COBYLA
#
#    NFVALS =  161   F =-2.372292E+01    MAXCV = 0.000000E+00
#    X = 1.158241E+00   9.610762E-02   1.968573E-01   2.201916E-01
#
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.363418E+01    MAXCV = 0.000000E+00
#    X = 1.492191E+00   1.918861E-01   3.189719E-01   1.492325E+00
#
# basinhopping step 1: f -23.7229 trial_f -23.6342 accepted 0  lowest_f -23.7229
# basinhopping step 2: f -23.6839 trial_f -23.6839 accepted 1  lowest_f -23.7229
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  686   F =-2.368387E+01    MAXCV = 0.000000E+00
#    X = 2.609215E+00  -1.162655E-01   3.041991E-01   4.495585E-02
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.369927E+01    MAXCV = 0.000000E+00
#    X = 3.594570E+00  -7.779714E-02   1.391394E+00  -1.898036E-01
#
# basinhopping step 3: f -23.6839 trial_f -23.6993 accepted 0  lowest_f -23.7229
# basinhopping step 4: f -23.5816 trial_f -23.5816 accepted 1  lowest_f -23.7229
#    Normal return from subroutine COBYLA
#
#    NFVALS =  165   F =-2.358158E+01    MAXCV = 0.000000E+00
#    X = 2.375129E+00  -1.239376E-01   1.013856E+00   2.361183E-01
#
# basinhopping step 5: f -23.9259 trial_f -23.9259 accepted 1  lowest_f -23.9259
#    Normal return from subroutine COBYLA
#
#    NFVALS =  187   F =-2.392590E+01    MAXCV = 0.000000E+00
#    X = 1.931859E+00   1.384089E-01   1.743316E+00   2.368284E-01
#
# found new global minimum on step 5 with function value -23.9259
# Final cost function:
# -23.925901789100323
# Parameters yielding final value:
# [1.93185851 0.13840887 1.74331603 0.23682845]
#
# Running layer number 3 for system size L=14
# Initial loss: -18.45519729398118
# warning: basinhopping: local minimization failure
#
# basinhopping step 0: f -23.9425
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.394250E+01    MAXCV = 0.000000E+00
#    X = 1.509965E-01   1.162956E-01  -2.458465E-01  -1.395317E-01  -1.716726E-01
#       -2.373251E-01
# basinhopping step 1: f -23.9099 trial_f -23.9099 accepted 1  lowest_f -23.9099
#    Normal return from subroutine COBYLA
#
#    NFVALS =  558   F =-2.390993E+01    MAXCV = 0.000000E+00
#    X = 4.829214E-01  -1.136821E-01   1.298712E-01  -2.670234E-01  -3.180614E-01
#        1.074302E-01
#
# found new global minimum on step 1 with function value -23.9099
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.374015E+01    MAXCV = 0.000000E+00
#    X = 8.514513E-01  -2.409103E-01   6.136982E-01   5.607102E-02  -7.308350E-01
#        2.020587E-01
#
# basinhopping step 2: f -23.9099 trial_f -23.7402 accepted 0  lowest_f -23.9099
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.363775E+01    MAXCV = 0.000000E+00
#    X = 1.800747E+00   7.211940E-02   1.581770E+00  -4.394357E-01  -1.539576E-01
#        3.363210E-01
#
# basinhopping step 3: f -23.9099 trial_f -23.6377 accepted 0  lowest_f -23.9099
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.373032E+01    MAXCV = 0.000000E+00
#    X = 1.521242E+00   9.644899E-01   9.899972E-02   1.448482E-01   5.000424E-01
#        3.961560E-01
#
# basinhopping step 4: f -23.9099 trial_f -23.7303 accepted 0  lowest_f -23.9099
# basinhopping step 5: f -23.6854 trial_f -23.6854 accepted 1  lowest_f -23.9099
#    Normal return from subroutine COBYLA
#
#    NFVALS =  383   F =-2.368538E+01    MAXCV = 0.000000E+00
#    X = 8.272910E-01   9.587623E-02   7.366441E-01  -2.242218E-01   6.401720E-01
#        4.272677E-03
#
# Final cost function:
# -23.909931125241474
# Parameters yielding final value:
# [ 0.48292143 -0.11368215  0.12987122 -0.26702336 -0.31806137  0.10743017]
#
# Running layer number 4 for system size L=14
# Initial loss: -17.79499217894681
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.396545E+01    MAXCV = 0.000000E+00
#    X = 2.721577E-01   1.154112E-01   9.649673E-02   7.206282E-02   1.384960E-01
#        1.112203E-01   1.122744E-01   1.238042E-01
#
# basinhopping step 0: f -23.9655
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.382071E+01    MAXCV = 0.000000E+00
#    X =-2.305532E-01   1.255168E+00   3.402562E-01   1.544450E+00  -3.447959E-02
#       -4.139945E-02   4.578224E-01   3.099514E-01
#
# basinhopping step 1: f -23.9655 trial_f -23.8207 accepted 0  lowest_f -23.9655
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.376477E+01    MAXCV = 0.000000E+00
#    X = 1.596902E+00   8.887651E-01   1.650894E+00  -1.165086E+00  -9.998173E-02
#        2.258935E-02   2.047978E-01   4.041582E-01
#
# basinhopping step 2: f -23.9655 trial_f -23.7648 accepted 0  lowest_f -23.9655
# basinhopping step 3: f -23.9348 trial_f -23.9348 accepted 1  lowest_f -23.9348
#    Normal return from subroutine COBYLA
#
#    NFVALS =  675   F =-2.393484E+01    MAXCV = 0.000000E+00
#    X = 3.577072E-01   1.342021E-01  -1.182499E-01   2.526474E-01   1.205099E+00
#       -1.418599E-02   6.700144E-01   9.285304E-03
#
# found new global minimum on step 3 with function value -23.9348
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.379496E+01    MAXCV = 0.000000E+00
#    X = 1.325875E-02   8.903426E-01  -2.871408E-01   6.512712E-01   1.667385E+00
#       -3.239428E-01   2.031949E+00   2.580633E-01
#
# basinhopping step 4: f -23.9348 trial_f -23.795 accepted 0  lowest_f -23.9348
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -23.9348 trial_f -23.7326 accepted 0  lowest_f -23.9348
# Final cost function:
# -23.93483810771437
# Parameters yielding final value:
# [ 0.35770723  0.13420209 -0.11824994  0.25264737  1.20509869 -0.01418599
#   0.6700144   0.0092853 ]
#
# Running layer number 5 for system size L=14
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.373262E+01    MAXCV = 0.000000E+00
#    X = 4.126317E-01   2.081399E+00  -4.482129E-01  -5.448860E-03   2.095112E+00
#       -5.930892E-01   1.722476E+00   1.166011E-01
# Initial loss: -18.197647975264587
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.395411E+01    MAXCV = 0.000000E+00
#    X = 2.359307E-01   1.208216E-01   1.251535E-01   4.692310E-02   1.580441E-02
#       -4.273547E-02   1.501495E-01   2.201188E-01   7.826559E-02   7.741439E-02
#
# basinhopping step 0: f -23.9541
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.378362E+01    MAXCV = 0.000000E+00
#    X = 3.081993E-01   1.621770E+00   7.037152E-02  -2.726264E-01  -4.966185E-01
#        2.386534E-01   8.415509E-01  -1.434955E-02   1.761642E-01   3.755483E-02
#
# basinhopping step 1: f -23.7836 trial_f -23.7836 accepted 1  lowest_f -23.9541
# warning: basinhopping: local minimization failure
#
# basinhopping step 2: f -23.7836 trial_f -23.5839 accepted 0  lowest_f -23.9541
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.358386E+01    MAXCV = 0.000000E+00
#    X =-1.887393E-01   7.530703E-01   7.991251E-03  -2.465270E-01  -5.429574E-01
#        3.087102E-01   7.170868E-01   1.316001E-04   5.581629E-01  -9.168966E-01
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.399670E+01    MAXCV = 0.000000E+00
#    X = 1.683592E+00   3.085244E+00   2.452011E-01   1.282906E-01  -1.019403E+00
#       -5.863345E-02   1.226431E+00  -2.498444E-01  -1.524753E-01  -2.385842E-01
#
# basinhopping step 3: f -23.9967 trial_f -23.9967 accepted 1  lowest_f -23.9541
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.396392E+01    MAXCV = 0.000000E+00
#    X = 1.562147E+00   2.873764E+00   2.641769E-02   1.118443E+00  -1.275887E+00
#       -7.116762E-01   1.282980E+00   1.688699E-01   4.167617E-01  -2.580407E-02
#
# basinhopping step 4: f -23.9639 trial_f -23.9639 accepted 1  lowest_f -23.9541
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -23.4766 trial_f -23.4766 accepted 1  lowest_f -23.9541
# Final cost function:
# -23.95411475297103
# Parameters yielding final value:
# [ 0.23593071  0.12082163  0.12515346  0.0469231   0.01580441 -0.04273547
#   0.15014948  0.22011875  0.07826559  0.07741439]
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.347658E+01    MAXCV = 0.000000E+00
#    X = 1.590698E+00   2.132842E+00  -1.826325E-01   1.253748E+00  -1.972987E+00
#       -4.559752E-01   2.150316E+00   9.384462E-02   4.461614E-01  -4.076012E-01
#
# Running layer number 6 for system size L=14
# Initial loss: -17.94215180308882
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.398871E+01    MAXCV = 0.000000E+00
#    X = 1.153283E-01   4.065572E-02   2.184374E-01   7.345330E-02   1.171341E-01
#        1.036645E-01   2.986486E-02  -6.650662E-02   1.867648E-01   2.030072E-01
#        9.765305E-02   1.393601E-01
#
# basinhopping step 0: f -23.9887
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.384173E+01    MAXCV = 0.000000E+00
#    X = 6.843161E-01   7.889352E-02   7.324634E-02   3.191252E-01  -4.528186E-02
#        3.280439E-01   4.903103E-02   3.168369E-01   2.825191E-01   5.214711E-01
#        2.802899E-01   7.663706E-02
#
# basinhopping step 1: f -23.8417 trial_f -23.8417 accepted 1  lowest_f -23.9887
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.353940E+01    MAXCV = 0.000000E+00
#    X = 2.054380E+00  -1.682503E-01   4.361684E-02   3.499623E-01  -2.531455E-01
#       -2.050408E-01  -1.242879E-01   5.680530E-01   1.593822E+00   2.088407E-01
#        1.166369E+00   2.308089E-01
#
# basinhopping step 2: f -23.5394 trial_f -23.5394 accepted 1  lowest_f -23.9887
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.394592E+01    MAXCV = 0.000000E+00
#    X = 2.827784E+00  -1.274426E-01  -1.357056E-02   8.041411E-01   1.161542E-02
#        1.724144E-01  -8.450379E-02   5.197181E-01   1.842157E+00  -1.758814E-01
#        1.131180E+00  -1.044207E-02
#
# basinhopping step 3: f -23.9459 trial_f -23.9459 accepted 1  lowest_f -23.9887
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.372536E+01    MAXCV = 0.000000E+00
#    X = 3.952990E+00  -1.215187E-01  -4.115426E-01   1.942865E+00   1.546516E+00
#        7.689398E-01   3.884580E-01   7.745284E-01   1.797769E+00  -1.399843E-01
#        2.347993E+00  -3.131987E-02
#
# basinhopping step 4: f -23.7254 trial_f -23.7254 accepted 1  lowest_f -23.9887
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -23.7387 trial_f -23.7387 accepted 1  lowest_f -23.9887
# Final cost function:
# -23.988712281336348
# Parameters yielding final value:
# [ 0.11532829  0.04065572  0.21843743  0.0734533   0.11713409  0.10366446
#   0.02986486 -0.06650662  0.18676482  0.20300715  0.09765305  0.13936008]
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.373872E+01    MAXCV = 0.000000E+00
#    X = 4.657098E+00   1.255943E+00  -7.578671E-01   3.420332E+00   1.408747E+00
#        2.047078E+00   3.687016E-03   1.843754E+00   1.791188E+00  -2.741891E-01
#        3.955838E+00  -3.965687E-01

# %%
run_HVA_training(16,6,5)
# Out:
# ---------------
#
#
# Initializing HVA training for L=16 and up to 6 layers.
# Will run basinhopping with 5 iterations
# -27.646948582300283 -26.769841716098806
#
# Running layer number 1 for system size L=16
# Initial loss: -24.7651208337816
# basinhopping step 0: f -26.9788
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =   37   F =-2.697880E+01    MAXCV = 0.000000E+00
#    X = 2.160696E-01   1.354034E-01
# basinhopping step 1: f -26.612 trial_f -26.612 accepted 1  lowest_f -26.9788
#    Normal return from subroutine COBYLA
#
#    NFVALS =   39   F =-2.661202E+01    MAXCV = 0.000000E+00
#    X = 9.942638E-01   1.140866E-01
#
# basinhopping step 2: f -26.612 trial_f -26.612 accepted 1  lowest_f -26.9788
#    Normal return from subroutine COBYLA
#
#    NFVALS =   36   F =-2.661202E+01    MAXCV = 0.000000E+00
#    X = 5.764145E-01  -1.138789E-01
#
# basinhopping step 3: f -26.612 trial_f -26.612 accepted 1  lowest_f -26.9788
#    Normal return from subroutine COBYLA
#
#    NFVALS =   42   F =-2.661203E+01    MAXCV = 0.000000E+00
#    X = 2.147189E+00   1.456862E+00
#
# basinhopping step 4: f -26.612 trial_f -26.612 accepted 1  lowest_f -26.9788
#    Normal return from subroutine COBYLA
#
#    NFVALS =   35   F =-2.661203E+01    MAXCV = 0.000000E+00
#    X = 2.147201E+00   3.027646E+00
#
# basinhopping step 5: f -26.9788 trial_f -26.9788 accepted 1  lowest_f -26.9788
#    Normal return from subroutine COBYLA
#
#    NFVALS =   37   F =-2.697880E+01    MAXCV = 0.000000E+00
#    X = 1.354613E+00   4.577115E+00
#
# found new global minimum on step 5 with function value -26.9788
# Final cost function:
# -26.978799398596603
# Parameters yielding final value:
# [1.35461329 4.57711529]
#
# Running layer number 2 for system size L=16
# Initial loss: -19.588221556805085
# basinhopping step 0: f -27.174
#    Normal return from subroutine COBYLA
#
#    NFVALS =  149   F =-2.717395E+01    MAXCV = 0.000000E+00
#    X = 1.158207E+00   9.610598E-02   1.973796E-01   2.198817E-01
#
# basinhopping step 1: f -26.612 trial_f -26.612 accepted 1  lowest_f -27.174
#    Normal return from subroutine COBYLA
#
#    NFVALS =   61   F =-2.661200E+01    MAXCV = 0.000000E+00
#    X = 1.557457E+00   1.572378E+00   5.762783E-01  -1.154600E-01
#
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.703417E+01    MAXCV = 0.000000E+00
#    X = 2.255407E+00   1.447415E+00   6.581859E-01  -2.044847E-02
#
# basinhopping step 2: f -26.612 trial_f -27.0342 accepted 0  lowest_f -27.174
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.664268E+01    MAXCV = 0.000000E+00
#    X = 1.614581E+00   1.423835E+00   5.262965E-01   3.875274E-02
#
# basinhopping step 3: f -26.612 trial_f -26.6427 accepted 0  lowest_f -27.174
# basinhopping step 4: f -26.8124 trial_f -26.8124 accepted 1  lowest_f -27.174
#    Normal return from subroutine COBYLA
#
#    NFVALS =  106   F =-2.681237E+01    MAXCV = 0.000000E+00
#    X = 2.723334E+00   1.471773E+00   5.767793E-01  -2.087521E-01
#
# basinhopping step 5: f -27.174 trial_f -27.174 accepted 1  lowest_f -27.174
#    Normal return from subroutine COBYLA
#
#    NFVALS =  183   F =-2.717396E+01    MAXCV = 0.000000E+00
#    X = 2.729135E+00   1.666781E+00   1.972074E-01   2.197357E-01
#
# found new global minimum on step 5 with function value -27.174
# Final cost function:
# -27.173956871006265
# Parameters yielding final value:
# [2.72913457 1.66678111 0.19720738 0.21973568]
#
# Running layer number 3 for system size L=16
# Initial loss: -21.070601367862075
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.743958E+01    MAXCV = 0.000000E+00
#    X = 1.621171E-01   9.954361E-02  -2.616465E-01  -1.357696E-01  -1.706646E-01
#       -2.372126E-01
#
# basinhopping step 0: f -27.4396
# basinhopping step 1: f -27.1037 trial_f -27.1037 accepted 1  lowest_f -27.1037
#    Normal return from subroutine COBYLA
#
#    NFVALS =  436   F =-2.710375E+01    MAXCV = 0.000000E+00
#    X = 4.989571E-01   1.050759E+00  -4.457450E-01   3.061974E-03  -5.416700E-01
#        6.742221E-01
#
# found new global minimum on step 1 with function value -27.1037
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.710902E+01    MAXCV = 0.000000E+00
#    X = 1.516052E+00   2.186218E+00   2.596172E-02   2.341002E-01  -1.018274E+00
#        5.862629E-01
#
# basinhopping step 2: f -27.1037 trial_f -27.109 accepted 0  lowest_f -27.1037
# basinhopping step 3: f -27.1927 trial_f -27.1927 accepted 1  lowest_f -27.1927
#    Normal return from subroutine COBYLA
#
#    NFVALS =  547   F =-2.719268E+01    MAXCV = 0.000000E+00
#    X = 6.090350E-01   7.187214E-01  -6.476872E-01  -4.898991E-03  -2.311094E-01
#        6.937075E-01
#
# found new global minimum on step 3 with function value -27.1927
# basinhopping step 4: f -27.2077 trial_f -27.2077 accepted 1  lowest_f -27.2077
#    Normal return from subroutine COBYLA
#
#    NFVALS =  514   F =-2.720766E+01    MAXCV = 0.000000E+00
#    X = 5.512442E-01   8.617592E-01  -5.098659E-01   1.121561E-02   2.327280E-01
#        8.719071E-01
#
# found new global minimum on step 4 with function value -27.2077
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.718003E+01    MAXCV = 0.000000E+00
#    X = 3.232868E-02   6.610206E-01  -7.889672E-01  -6.631358E-01   2.191981E-01
#        1.727256E+00
#
# basinhopping step 5: f -27.2077 trial_f -27.18 accepted 0  lowest_f -27.2077
# Final cost function:
# -27.20765789572474
# Parameters yielding final value:
# [ 0.55124421  0.86175924 -0.50986588  0.01121561  0.23272804  0.87190712]
#
# Running layer number 4 for system size L=16
# Initial loss: -20.283433659217483
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.743266E+01    MAXCV = 0.000000E+00
#    X = 3.359747E-01   1.324185E-01   8.224810E-02   1.405818E-01   1.333156E-01
#        1.112099E-01  -3.136109E-03  -8.782455E-03
#
# basinhopping step 0: f -27.4327
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.741890E+01    MAXCV = 0.000000E+00
#    X = 1.548720E+00   7.191229E-01   2.918986E-01   8.245427E-01   1.912279E+00
#        1.008014E-01   1.589139E-01   1.954481E-01
#
# basinhopping step 1: f -27.4189 trial_f -27.4189 accepted 1  lowest_f -27.4327
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.725407E+01    MAXCV = 0.000000E+00
#    X = 3.152304E+00   9.898166E-01   7.569359E-01   8.186053E-01   2.287634E+00
#       -4.305628E-02   3.625344E-01  -1.210977E-01
#
# basinhopping step 2: f -27.4189 trial_f -27.2541 accepted 0  lowest_f -27.4327
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.735492E+01    MAXCV = 0.000000E+00
#    X = 3.185255E+00   8.765714E-01   1.144175E+00   7.097738E-01   1.599304E+00
#        1.315896E+00  -2.639558E-01   1.153203E-01
#
# basinhopping step 3: f -27.3549 trial_f -27.3549 accepted 1  lowest_f -27.4327
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.718192E+01    MAXCV = 0.000000E+00
#    X = 3.138777E+00   1.054668E+00   2.397609E+00   4.264759E-01   1.507946E+00
#        1.474894E+00   1.774233E-01   2.942368E-01
#
# basinhopping step 4: f -27.1819 trial_f -27.1819 accepted 1  lowest_f -27.4327
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.732063E+01    MAXCV = 0.000000E+00
#    X = 4.735292E+00   1.162317E+00   1.650091E+00   1.390036E+00   1.461669E+00
#        1.502142E+00  -2.591009E-01   5.023898E-01
#
# basinhopping step 5: f -27.3206 trial_f -27.3206 accepted 1  lowest_f -27.4327
# Final cost function:
# -27.43266393582254
# Parameters yielding final value:
# [ 0.33597474  0.13241848  0.0822481   0.14058181  0.13331557  0.11120986
#  -0.00313611 -0.00878246]
#
# Running layer number 5 for system size L=16
# Initial loss: -20.77278612151913
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.746087E+01    MAXCV = 0.000000E+00
#    X = 1.914997E-01   1.049557E-01   8.445169E-02   4.071808E-02   1.422315E-01
#        4.280332E-02   1.229404E-01   1.722767E-01   7.562698E-02   5.702346E-02
#
# basinhopping step 0: f -27.4609
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.690771E+01    MAXCV = 0.000000E+00
#    X = 1.966121E-01  -1.949644E-01  -1.136938E-01  -2.526659E-01   2.717956E-01
#        1.777681E-01   1.273907E+00   1.902814E-01  -4.899781E-01   3.670915E-01
#
# basinhopping step 1: f -26.9077 trial_f -26.9077 accepted 1  lowest_f -27.4609
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.725225E+01    MAXCV = 0.000000E+00
#    X = 1.481975E+00   3.126544E-01   1.009716E+00  -1.585150E-01   2.665306E-01
#       -1.007674E-01   1.394079E+00   1.591964E-02  -7.387456E-01   1.207026E-01
#
# basinhopping step 2: f -27.2523 trial_f -27.2523 accepted 1  lowest_f -27.4609
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.734397E+01    MAXCV = 0.000000E+00
#    X = 1.681851E+00   2.368744E-01   1.904025E+00  -2.455576E-01  -2.985573E-02
#       -2.087588E-01   2.718760E+00   3.541487E-01  -7.855719E-01   3.377323E-02
#
# basinhopping step 3: f -27.344 trial_f -27.344 accepted 1  lowest_f -27.4609
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.739049E+01    MAXCV = 0.000000E+00
#    X = 2.508206E+00   2.798434E-01   1.590517E+00   7.032995E-01   9.232984E-01
#       -6.926707E-01   2.776084E+00   2.365671E-02  -4.484350E-01  -2.317562E-01
#
# basinhopping step 4: f -27.3905 trial_f -27.3905 accepted 1  lowest_f -27.4609
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.739592E+01    MAXCV = 0.000000E+00
#    X = 1.708119E+00   9.094071E-01   1.586149E+00   1.881967E+00   1.437289E+00
#       -2.190851E-01   2.471725E+00   6.982052E-01  -6.549845E-01   4.856149E-02
#
# basinhopping step 5: f -27.3959 trial_f -27.3959 accepted 1  lowest_f -27.4609
# Final cost function:
# -27.46086571960709
# Parameters yielding final value:
# [0.19149969 0.10495568 0.08445169 0.04071808 0.14223153 0.04280332
#  0.12294043 0.17227665 0.07562698 0.05702346]
#
# Running layer number 6 for system size L=16
# Initial loss: -20.46855583185161
# warning: basinhopping: local minimization failure
# basinhopping step 0: f -27.5039
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.750387E+01    MAXCV = 0.000000E+00
#    X = 2.289841E-01   6.295643E-02   1.823561E-01   9.302398E-02   1.933756E-01
#        1.291862E-01  -1.216306E-02   7.688419E-02   6.478073E-02  -2.899431E-03
#        1.232032E-01   1.286820E-01
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.742909E+01    MAXCV = 0.000000E+00
#    X = 6.212708E-02   5.453968E-01  -1.077257E-01  -2.647219E-01  -3.473780E-02
#        4.887855E-01  -5.401558E-01   7.241856E-01  -3.083332E-02   6.441507E-01
#       -2.014748E-01   6.760860E-01
#
# basinhopping step 1: f -27.4291 trial_f -27.4291 accepted 1  lowest_f -27.5039
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.702741E+01    MAXCV = 0.000000E+00
#    X =-1.324517E-01   1.757599E+00   7.030386E-02  -2.933991E-01   8.899713E-02
#        2.610433E-01  -7.810906E-01   1.138936E+00  -3.172242E-01   3.212277E-01
#        2.242976E-01   3.122408E-01
#
# basinhopping step 2: f -27.0274 trial_f -27.0274 accepted 1  lowest_f -27.5039
# basinhopping step 3: f -27.4272 trial_f -27.4272 accepted 1  lowest_f -27.4272
#    Normal return from subroutine COBYLA
#
#    NFVALS =  519   F =-2.742716E+01    MAXCV = 0.000000E+00
#    X = 1.199407E+00   1.431803E+00   1.130712E+00   9.174147E-01  -5.076975E-03
#        2.461309E-01  -3.092563E-01   1.317737E+00  -8.201118E-01   9.607438E-03
#       -1.794380E-01   4.069888E-01
#
# found new global minimum on step 3 with function value -27.4272
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.746850E+01    MAXCV = 0.000000E+00
#    X = 1.553398E+00   2.138510E+00   1.112697E+00   2.420079E+00   7.598400E-02
#        1.169691E-01  -9.428722E-02   1.276304E+00   3.974864E-01  -7.658064E-02
#       -5.042363E-01   4.719957E-03
#
# basinhopping step 4: f -27.4272 trial_f -27.4685 accepted 0  lowest_f -27.4272
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-2.739412E+01    MAXCV = 0.000000E+00
#    X = 8.023066E-01   1.665964E+00   1.523305E+00   2.406364E+00   6.400660E-01
#        5.017492E-01  -5.031640E-01   1.081603E+00  -1.063016E+00   1.145598E-02
#       -8.827853E-01   4.413946E-01
#
# basinhopping step 5: f -27.4272 trial_f -27.3941 accepted 0  lowest_f -27.4272
# Final cost function:
# -27.42716490332498
# Parameters yielding final value:
# [ 1.19940726  1.43180293  1.13071241  0.91741465 -0.00507698  0.24613087
#  -0.30925626  1.31773662 -0.82011182  0.00960744 -0.17943798  0.40698884]

# %%
run_HVA_training(18,6,5)
# Out:
# ---------------
#
#
# Initializing HVA training for L=18 and up to 6 layers.
# Will run basinhopping with 5 iterations
# -31.18804427414599 -30.397139536466263
#
# Running layer number 1 for system size L=18
# Initial loss: -27.847678501289515
# basinhopping step 0: f -30.3988
#    Normal return from subroutine COBYLA
#
#    NFVALS =   38   F =-3.039875E+01    MAXCV = 0.000000E+00
#    X = 2.162044E-01   1.349368E-01
#
# basinhopping step 1: f -30.3988 trial_f -30.3988 accepted 1  lowest_f -30.3988
#    Normal return from subroutine COBYLA
#
#    NFVALS =   34   F =-3.039875E+01    MAXCV = 0.000000E+00
#    X = 1.786999E+00   1.349558E-01
#
# found new global minimum on step 1 with function value -30.3988
# basinhopping step 2: f -29.9753 trial_f -29.9753 accepted 1  lowest_f -30.3988
#    Normal return from subroutine COBYLA
#
#    NFVALS =   37   F =-2.997530E+01    MAXCV = 0.000000E+00
#    X = 2.147487E+00  -1.134212E-01
#
# basinhopping step 3: f -29.9753 trial_f -29.9753 accepted 1  lowest_f -30.3988
#    Normal return from subroutine COBYLA
#
#    NFVALS =   33   F =-2.997530E+01    MAXCV = 0.000000E+00
#    X = 3.718249E+00  -1.134441E-01
#
# basinhopping step 4: f -30.3988 trial_f -30.3988 accepted 1  lowest_f -30.3988
#    Normal return from subroutine COBYLA
#
#    NFVALS =   33   F =-3.039875E+01    MAXCV = 0.000000E+00
#    X = 4.928597E+00   1.349941E-01
#
# found new global minimum on step 4 with function value -30.3988
# basinhopping step 5: f -29.9753 trial_f -29.9753 accepted 1  lowest_f -30.3988
#    Normal return from subroutine COBYLA
#
#    NFVALS =   42   F =-2.997530E+01    MAXCV = 0.000000E+00
#    X = 5.706533E+00   1.684381E+00
#
# Final cost function:
# -30.398754483541474
# Parameters yielding final value:
# [4.92859731 0.13499408]
#
# Running layer number 2 for system size L=18
# Initial loss: -21.991119892297842
# basinhopping step 0: f -30.6251
#    Normal return from subroutine COBYLA
#
#    NFVALS =   63   F =-3.062509E+01    MAXCV = 0.000000E+00
#    X = 1.157730E+00   9.570958E-02   1.971045E-01   2.190408E-01
#
# basinhopping step 1: f -30.4211 trial_f -30.4211 accepted 1  lowest_f -30.6251
#    Normal return from subroutine COBYLA
#
#    NFVALS =  165   F =-3.042108E+01    MAXCV = 0.000000E+00
#    X = 2.374820E+00  -1.216878E-01   1.013267E+00   1.803536E+00
#
# basinhopping step 2: f -30.5723 trial_f -30.5723 accepted 1  lowest_f -30.6251
#    Normal return from subroutine COBYLA
#
#    NFVALS =  394   F =-3.057231E+01    MAXCV = 0.000000E+00
#    X = 2.406382E+00   8.825226E-02   1.379506E+00   2.930376E+00
#
# basinhopping step 3: f -30.6251 trial_f -30.6251 accepted 1  lowest_f -30.6251
#    Normal return from subroutine COBYLA
#
#    NFVALS =  602   F =-3.062505E+01    MAXCV = 0.000000E+00
#    X = 1.985232E+00  -9.502346E-02   1.374299E+00   4.494404E+00
#
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.056924E+01    MAXCV = 0.000000E+00
#    X = 2.119829E+00   1.202566E-01   1.252120E+00   4.667796E+00
#
# basinhopping step 4: f -30.6251 trial_f -30.5692 accepted 0  lowest_f -30.6251
# basinhopping step 5: f -30.6459 trial_f -30.6459 accepted 1  lowest_f -30.6459
#    Normal return from subroutine COBYLA
#
#    NFVALS =  299   F =-3.064594E+01    MAXCV = 0.000000E+00
#    X = 3.104839E+00  -8.487959E-01   2.911608E+00   3.835203E+00
#
# found new global minimum on step 5 with function value -30.6459
# Final cost function:
# -30.645944129071513
# Parameters yielding final value:
# [ 3.10483898 -0.84879593  2.91160837  3.83520299]
#
# Running layer number 3 for system size L=18
# Initial loss: -23.68600544174297
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.093302E+01    MAXCV = 0.000000E+00
#    X = 1.650338E-01   1.042143E-01  -2.573384E-01  -1.326446E-01  -1.719779E-01
#       -2.388362E-01
#
# basinhopping step 0: f -30.933
# basinhopping step 1: f -30.7465 trial_f -30.7465 accepted 1  lowest_f -30.7465
#    Normal return from subroutine COBYLA
#
#    NFVALS =  573   F =-3.074654E+01    MAXCV = 0.000000E+00
#    X = 1.259647E+00   1.680491E+00  -7.044241E-01   2.257526E-01  -1.963590E-01
#       -2.618177E-01
#
# found new global minimum on step 1 with function value -30.7465
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.058125E+01    MAXCV = 0.000000E+00
#    X = 1.691864E+00   3.107313E+00  -8.744350E-01  -6.787701E-02   1.928461E-01
#        2.135183E-01
#
# basinhopping step 2: f -30.7465 trial_f -30.5813 accepted 0  lowest_f -30.7465
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.034140E+01    MAXCV = 0.000000E+00
#    X = 1.648080E+00   1.862271E+00  -3.038698E-01  -2.289907E-01  -4.674048E-01
#        3.108932E-02
#
# basinhopping step 3: f -30.7465 trial_f -30.3414 accepted 0  lowest_f -30.7465
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.083122E+01    MAXCV = 0.000000E+00
#    X = 1.483304E+00   2.883324E+00  -6.724410E-01   1.772739E-01   1.816111E-01
#        2.366588E-01
#
# basinhopping step 4: f -30.7465 trial_f -30.8312 accepted 0  lowest_f -30.7465
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -30.7465 trial_f -30.756 accepted 0  lowest_f -30.7465
# Final cost function:
# -30.746538340927646
# Parameters yielding final value:
# [ 1.25964674  1.68049089 -0.70442413  0.22575263 -0.19635901 -0.26181774]
#
# Running layer number 4 for system size L=18
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.075600E+01    MAXCV = 0.000000E+00
#    X = 1.716201E+00   1.792596E+00  -2.152237E-01   6.571579E-02   1.125129E+00
#       -2.188905E-01
# Initial loss: -22.771798928715143
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.102535E+01    MAXCV = 0.000000E+00
#    X = 2.681470E-01   9.708738E-02   1.245407E-01   7.174523E-02   2.686100E-01
#        1.676778E-01   1.289102E-01   2.055092E-01
#
# basinhopping step 0: f -31.0254
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.090009E+01    MAXCV = 0.000000E+00
#    X =-5.707059E-01  -2.712618E-01  -4.957847E-02  -1.938692E-01  -8.953436E-01
#        2.140643E-01  -3.363303E-01   1.707287E+00
#
# basinhopping step 1: f -30.9001 trial_f -30.9001 accepted 1  lowest_f -31.0254
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.048421E+01    MAXCV = 0.000000E+00
#    X =-5.408489E-01   1.197073E-01  -2.760279E-01   1.343045E-02  -2.629831E-01
#       -2.231193E-01  -7.337897E-01   1.609399E+00
#
# basinhopping step 2: f -30.9001 trial_f -30.4842 accepted 0  lowest_f -31.0254
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.065299E+01    MAXCV = 0.000000E+00
#    X =-8.188975E-01   1.023276E-01   6.629183E-01  -1.953053E-01  -8.813537E-01
#        1.930028E-01  -5.373499E-01   1.569889E+00
#
# basinhopping step 3: f -30.653 trial_f -30.653 accepted 1  lowest_f -31.0254
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.067562E+01    MAXCV = 0.000000E+00
#    X =-9.538501E-01  -9.958724E-02   8.861063E-01  -3.522189E-01  -9.153731E-01
#        1.958388E-02  -8.200456E-01   1.895596E+00
#
# basinhopping step 4: f -30.6756 trial_f -30.6756 accepted 1  lowest_f -31.0254
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.064378E+01    MAXCV = 0.000000E+00
#    X = 3.336081E-02  -6.941188E-01   1.534810E+00  -7.096306E-01  -1.581528E+00
#       -2.428384E-01   2.617625E-01   1.802627E+00
#
# basinhopping step 5: f -30.6438 trial_f -30.6438 accepted 1  lowest_f -31.0254
# Final cost function:
# -31.02535214409884
# Parameters yielding final value:
# [0.26814699 0.09708738 0.12454071 0.07174523 0.26860996 0.16767777
#  0.1289102  0.20550925]
#
# Running layer number 5 for system size L=18
# Initial loss: -23.344712504997116
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.099275E+01    MAXCV = 0.000000E+00
#    X = 1.761007E-01   7.375535E-02   1.283918E-01   8.187165E-02   9.717780E-02
#       -1.497237E-02   2.178911E-01   1.877990E-01   1.100335E-01   1.592059E-01
#
# basinhopping step 0: f -30.9927
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.086694E+01    MAXCV = 0.000000E+00
#    X =-1.268460E-02   1.098884E+00   1.013399E-01   2.498405E-01  -1.980230E-01
#        2.182692E-01   7.343728E-01  -2.208713E-03   1.660030E-01   2.234208E-01
#
# basinhopping step 1: f -30.8669 trial_f -30.8669 accepted 1  lowest_f -30.9927
# basinhopping step 2: f -30.1832 trial_f -30.1832 accepted 1  lowest_f -30.1832
#    Normal return from subroutine COBYLA
#
#    NFVALS =  315   F =-3.018323E+01    MAXCV = 0.000000E+00
#    X = 8.336115E-01   1.569642E+00   1.287226E+00  -7.425836E-02  -2.619696E-01
#       -2.415528E-01   3.065287E-01   1.353657E-02   9.754529E-01   3.387613E-01
#
# found new global minimum on step 2 with function value -30.1832
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.088659E+01    MAXCV = 0.000000E+00
#    X = 1.576988E+00   2.224663E+00   1.419698E+00  -5.398955E-01  -4.745496E-01
#       -1.411321E-01  -1.009711E-02   1.268340E+00   1.410127E+00   6.973167E-02
#
# basinhopping step 3: f -30.1832 trial_f -30.8866 accepted 0  lowest_f -30.1832
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.105035E+01    MAXCV = 0.000000E+00
#    X = 1.567236E+00   1.982222E+00   1.178518E+00   1.025392E+00  -3.554032E-01
#       -2.811742E-01  -4.819908E-03   9.432478E-01   1.419940E+00   3.668312E-01
#
# basinhopping step 4: f -30.1832 trial_f -31.0503 accepted 0  lowest_f -30.1832
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -30.1832 trial_f -30.7067 accepted 0  lowest_f -30.1832
# Final cost function:
# -30.183228193954225
# Parameters yielding final value:
# [ 0.83361148  1.56964223  1.28722606 -0.07425836 -0.26196964 -0.24155277
#   0.30652869  0.01353657  0.97545286  0.33876132]
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.070668E+01    MAXCV = 0.000000E+00
#    X = 7.910060E-01   1.486690E+00   2.053429E+00  -7.513864E-02  -3.531377E-01
#       -9.889356E-01   3.867696E-01   1.136761E-02   8.496385E-01   9.647453E-01
#
# Running layer number 6 for system size L=18
# Initial loss: -22.988721438488266
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.096442E+01    MAXCV = 0.000000E+00
#    X = 8.331959E-02   8.231331E-03   3.341601E-01   1.161818E-01  -1.513513E-02
#        5.869799E-02   4.480776E-03   7.290338E-02   2.095100E-01   5.524591E-02
#        1.086627E-01   1.467700E-01
#
# basinhopping step 0: f -30.9644
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.086178E+01    MAXCV = 0.000000E+00
#    X =-2.619510E-01   1.617668E-01   2.958446E-01  -1.038527E-02  -1.185420E+00
#       -2.292520E-01  -6.512908E-02  -3.158964E-01   1.006261E-01   2.623808E-01
#        1.594447E-01   1.302751E-01
#
# basinhopping step 1: f -30.8618 trial_f -30.8618 accepted 1  lowest_f -30.9644
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.081279E+01    MAXCV = 0.000000E+00
#    X =-2.826005E-01   1.085057E-01   5.130559E-01   1.750649E-01  -8.620861E-01
#       -1.196749E-02  -3.411026E-01   2.326827E-01  -3.140349E-01   2.329774E-03
#        8.602953E-01   3.699914E-02
#
# basinhopping step 2: f -30.8128 trial_f -30.8128 accepted 1  lowest_f -30.9644
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.087658E+01    MAXCV = 0.000000E+00
#    X =-6.362530E-01   1.364496E+00   1.359003E+00  -4.865390E-02  -7.434833E-01
#       -9.160888E-02  -5.182757E-01   5.491594E-02  -1.421488E-01  -5.851076E-02
#        3.973588E-01   2.288396E-01
#
# basinhopping step 3: f -30.8766 trial_f -30.8766 accepted 1  lowest_f -30.9644
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.078934E+01    MAXCV = 0.000000E+00
#    X = 7.423664E-01   1.632283E+00   2.450886E+00   1.317687E+00  -1.324554E+00
#        8.059397E-02  -7.901613E-01  -5.206832E-02  -4.855755E-02   1.207083E+00
#        9.225051E-01   3.665287E-01
#
# basinhopping step 4: f -30.7893 trial_f -30.7893 accepted 1  lowest_f -30.9644
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.068130E+01    MAXCV = 0.000000E+00
#    X = 1.623894E+00   2.224478E+00   3.044557E+00   1.435154E+00  -1.536908E+00
#       -5.808294E-01  -5.486799E-01  -8.069890E-03  -6.076051E-01   1.577777E+00
#        2.211274E+00  -1.224760E-01
#
# basinhopping step 5: f -30.6813 trial_f -30.6813 accepted 1  lowest_f -30.9644
# Final cost function:
# -30.964421084486084
# Parameters yielding final value:
# [ 0.08331959  0.00823133  0.33416014  0.1161818  -0.01513513  0.05869799
#   0.00448078  0.07290338  0.20950995  0.05524591  0.10866266  0.14676996]

# %%
run_HVA_training(20,6,5)
# Out:
# ---------------
#
#
# Initializing HVA training for L=20 and up to 6 layers.
# Will run basinhopping with 5 iterations
# -34.72989333759567 -34.00951479218718
#
# Running layer number 1 for system size L=20
# Initial loss: -30.93023616879742
# basinhopping step 0: f -33.8187
#    Normal return from subroutine COBYLA
#
#    NFVALS =   40   F =-3.381874E+01    MAXCV = 0.000000E+00
#    X = 2.162254E-01   1.348166E-01
#
# basinhopping step 1: f -33.3387 trial_f -33.3387 accepted 1  lowest_f -33.8187
#    Normal return from subroutine COBYLA
#
#
#    NFVALS =   35   F =-3.333867E+01    MAXCV = 0.000000E+00
#    X = 9.941183E-01   1.130865E-01
# basinhopping step 2: f -33.3387 trial_f -33.3387 accepted 1  lowest_f -33.8187
#    Normal return from subroutine COBYLA
#
#    NFVALS =   31   F =-3.333867E+01    MAXCV = 0.000000E+00
#    X = 5.766282E-01   1.457644E+00
#
# basinhopping step 3: f -33.3387 trial_f -33.3387 accepted 1  lowest_f -33.8187
#    Normal return from subroutine COBYLA
#
#    NFVALS =   39   F =-3.333867E+01    MAXCV = 0.000000E+00
#    X = 2.147546E+00   1.457682E+00
#
# basinhopping step 4: f -33.8187 trial_f -33.8187 accepted 1  lowest_f -33.8187
#    Normal return from subroutine COBYLA
#
#    NFVALS =   37   F =-3.381874E+01    MAXCV = 0.000000E+00
#    X = 2.925358E+00   1.435949E+00
#
# basinhopping step 5: f -33.3387 trial_f -33.3387 accepted 1  lowest_f -33.8187
#    Normal return from subroutine COBYLA
#
#    NFVALS =   34   F =-3.333867E+01    MAXCV = 0.000000E+00
#    X = 4.135677E+00   1.684011E+00
#
# Final cost function:
# -33.81873621456868
# Parameters yielding final value:
# [0.21622544 0.13481662]
#
# Running layer number 2 for system size L=20
# Initial loss: -24.3940182277906
# basinhopping step 0: f -34.0762
#    Normal return from subroutine COBYLA
#
#    NFVALS =  101   F =-3.407624E+01    MAXCV = 0.000000E+00
#    X = 1.156969E+00   9.519582E-02   1.969604E-01   2.181302E-01
#
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.383468E+01    MAXCV = 0.000000E+00
#    X = 7.768196E-01  -1.268458E-01   5.771064E-01  -9.634871E-03
#
# basinhopping step 1: f -34.0762 trial_f -33.8347 accepted 0  lowest_f -34.0762
# warning: basinhopping: local minimization failure
# basinhopping step 2: f -34.0762 trial_f -33.9497 accepted 0  lowest_f -34.0762
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.394966E+01    MAXCV = 0.000000E+00
#    X = 1.512040E+00   2.207020E-01   2.970463E-01   1.466208E+00
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.383037E+01    MAXCV = 0.000000E+00
#    X = 1.576423E+00   1.039877E+00   1.351788E+00   3.985273E-01
#
# basinhopping step 3: f -34.0762 trial_f -33.8304 accepted 0  lowest_f -34.0762
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.394225E+01    MAXCV = 0.000000E+00
#    X = 1.541598E+00   1.338152E+00   1.823163E-01   3.525066E-01
#
# basinhopping step 4: f -34.0762 trial_f -33.9422 accepted 0  lowest_f -34.0762
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -34.0762 trial_f -33.84 accepted 0  lowest_f -34.0762
# Final cost function:
# -34.07624263435968
# Parameters yielding final value:
# [1.15696912 0.09519582 0.19696043 0.21813017]
#
# Running layer number 3 for system size L=20
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.384002E+01    MAXCV = 0.000000E+00
#    X = 8.826483E-01  -1.414015E-01   4.681943E-01   1.583259E+00
# Initial loss: -26.30140951562389
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.442656E+01    MAXCV = 0.000000E+00
#    X = 1.706748E-01   1.062997E-01  -2.559377E-01  -1.285060E-01  -1.733006E-01
#       -2.410339E-01
#
# basinhopping step 0: f -34.4266
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.416894E+01    MAXCV = 0.000000E+00
#    X = 1.311758E+00   3.611533E-01   1.819163E-01   2.468869E-02   1.106260E+00
#       -3.132018E-01
#
# basinhopping step 1: f -34.4266 trial_f -34.1689 accepted 0  lowest_f -34.4266
# warning: basinhopping: local minimization failure
# basinhopping step 2: f -33.9281 trial_f -33.9281 accepted 1  lowest_f -34.4266
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.392814E+01    MAXCV = 0.000000E+00
#    X = 4.874271E-01  -1.437745E-01   9.924688E-03   2.161923E-01   8.368779E-01
#       -2.425098E-01
# basinhopping step 3: f -34.1346 trial_f -34.1346 accepted 1  lowest_f -34.1346
#
# found new global minimum on step 3 with function value -34.1346
#    Normal return from subroutine COBYLA
#
#    NFVALS =  218   F =-3.413462E+01    MAXCV = 0.000000E+00
#    X =-1.150571E-02  -3.405175E-01  -8.761454E-02   6.471859E-01   1.106219E+00
#       -2.614181E-01
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.414593E+01    MAXCV = 0.000000E+00
#    X =-7.829649E-02   3.736919E-01   1.463345E-02   2.755200E-01   1.090580E+00
#       -5.797213E-01
#
# basinhopping step 4: f -34.1346 trial_f -34.1459 accepted 0  lowest_f -34.1346
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.397059E+01    MAXCV = 0.000000E+00
#    X = 3.998276E-02   9.096505E-01   1.029939E-01   1.022613E+00   2.386665E+00
#       -2.672982E-01
#
# basinhopping step 5: f -34.1346 trial_f -33.9706 accepted 0  lowest_f -34.1346
# Final cost function:
# -34.13462170936076
# Parameters yielding final value:
# [-0.01150571 -0.34051752 -0.08761454  0.6471859   1.10621914 -0.26141805]
#
# Running layer number 4 for system size L=20
# Initial loss: -25.260163368334872
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.446508E+01    MAXCV = 0.000000E+00
#    X = 2.871916E-01   1.136300E-01   1.153804E-01   1.075050E-01   1.176846E-01
#        8.813831E-02   1.106586E-01   1.189386E-01
#
# basinhopping step 0: f -34.4651
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.416654E+01    MAXCV = 0.000000E+00
#    X = 4.140470E-02   5.551917E-01  -3.923318E-01  -3.945391E-01   1.229675E+00
#        1.411957E-01   9.866926E-01   1.421953E-01
#
# basinhopping step 1: f -34.1665 trial_f -34.1665 accepted 1  lowest_f -34.4651
# basinhopping step 2: f -34.0501 trial_f -34.0501 accepted 1  lowest_f -34.0501
#    Normal return from subroutine COBYLA
#
#    NFVALS =  244   F =-3.405008E+01    MAXCV = 0.000000E+00
#    X =-4.831480E-02   5.175047E-01  -2.716236E-01  -6.453586E-01   1.549496E+00
#       -1.582445E-01   8.337573E-01   1.636841E-01
#
# found new global minimum on step 2 with function value -34.0501
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.417994E+01    MAXCV = 0.000000E+00
#    X = 1.113796E-01   1.140879E+00  -1.208592E-01   6.808062E-02   1.572005E+00
#       -1.279536E-01   1.766096E+00   6.394045E-01
#
# basinhopping step 3: f -34.0501 trial_f -34.1799 accepted 0  lowest_f -34.0501
# warning: basinhopping: local minimization failure
# basinhopping step 4: f -34.0501 trial_f -34.1714 accepted 0  lowest_f -34.0501
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.417138E+01    MAXCV = 0.000000E+00
#    X = 1.492908E+00   2.418333E-01  -2.158413E-01  -1.914703E-01   1.624787E+00
#       -2.699129E-01   5.004876E-01   3.130943E-01
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.437507E+01    MAXCV = 0.000000E+00
#    X = 2.640486E-02   8.707386E-01  -1.691837E-01  -8.013166E-01   1.166627E+00
#       -8.863620E-02   1.401537E+00  -1.863573E-01
#
# basinhopping step 5: f -34.0501 trial_f -34.3751 accepted 0  lowest_f -34.0501
# Final cost function:
# -34.050082722212125
# Parameters yielding final value:
# [-0.0483148   0.51750466 -0.27162358 -0.64535864  1.54949621 -0.15824447
#   0.83375731  0.16368408]
#
# Running layer number 5 for system size L=20
# Initial loss: -25.916338946070184
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.446213E+01    MAXCV = 0.000000E+00
#    X = 2.855080E-01   1.015809E-01   1.765929E-01   1.530561E-01   4.355984E-02
#       -5.385596E-02   1.150914E-01   2.394118E-01  -2.227549E-03  -3.350706E-02
#
# basinhopping step 0: f -34.4621
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.440415E+01    MAXCV = 0.000000E+00
#    X = 1.535953E+00   1.311571E+00   1.574663E+00   1.442334E-01   6.416310E-01
#        2.070762E-01  -3.613667E-01   1.583832E+00   1.604178E-01   2.068792E-01
#
# basinhopping step 1: f -34.4041 trial_f -34.4041 accepted 1  lowest_f -34.4621
# warning: basinhopping: local minimization failure
#
# basinhopping step 2: f -34.4041 trial_f -34.3025 accepted 0  lowest_f -34.4621
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.430252E+01    MAXCV = 0.000000E+00
#    X = 1.633129E+00   8.619725E-01   1.472891E+00  -1.172099E-01   1.000188E-01
#       -2.370744E-01  -8.257080E-01   1.014759E+00   6.386133E-01  -7.960946E-02
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.406421E+01    MAXCV = 0.000000E+00
#    X = 1.534723E+00   8.959520E-01   1.562219E+00   1.323180E+00   8.352392E-02
#        4.081642E-01  -9.193576E-03   1.456405E+00   5.225450E-01   5.425625E-01
#
# basinhopping step 3: f -34.0642 trial_f -34.0642 accepted 1  lowest_f -34.4621
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.432523E+01    MAXCV = 0.000000E+00
#    X = 1.555839E+00   1.934944E+00   1.595619E+00   2.124240E+00   9.215980E-01
#        6.844641E-01   2.775820E-02   2.459984E+00   2.156977E-01   7.992118E-01
#
# basinhopping step 4: f -34.3252 trial_f -34.3252 accepted 1  lowest_f -34.4621
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.438730E+01    MAXCV = 0.000000E+00
#    X = 2.435065E+00   3.007460E+00   9.749788E-01   3.236918E+00   1.570839E+00
#        1.275935E+00  -4.070060E-01   1.946770E+00   1.734322E+00   2.502838E-01
#
# basinhopping step 5: f -34.3873 trial_f -34.3873 accepted 1  lowest_f -34.4621
# Final cost function:
# -34.46212549222226
# Parameters yielding final value:
# [ 0.285508    0.10158092  0.17659293  0.15305608  0.04355984 -0.05385596
#   0.1150914   0.23941178 -0.00222755 -0.03350706]
#
# Running layer number 6 for system size L=20
# Initial loss: -25.504102077141166
# warning: basinhopping: local minimization failure
# basinhopping step 0: f -34.5417
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.454172E+01    MAXCV = 0.000000E+00
#    X = 2.641997E-01   7.386837E-02   1.959695E-01   1.167366E-01   2.162724E-01
#        1.420681E-01  -2.243482E-02   1.119591E-02   7.723092E-02   9.702126E-02
#        1.001165E-01   1.009614E-01
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.409645E+01    MAXCV = 0.000000E+00
#    X = 4.725959E-01   4.464382E-02  -4.067491E-02   1.169866E+00   1.233553E+00
#        2.408720E-01   8.004672E-01   2.244654E-02  -5.611592E-01  -9.772215E-02
#       -6.454647E-01   1.986071E-01
#
# basinhopping step 1: f -34.5417 trial_f -34.0964 accepted 0  lowest_f -34.5417
# warning: basinhopping: local minimization failure
#
# basinhopping step 2: f -34.3731 trial_f -34.3731 accepted 1  lowest_f -34.5417
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.437314E+01    MAXCV = 0.000000E+00
#    X =-2.357918E-01   1.309382E-01  -8.563689E-02   1.438190E+00   9.615758E-02
#        2.863134E-01   8.094605E-02  -3.325968E-01  -3.175368E-02  -2.391099E-01
#       -2.625725E-01   3.687123E-01
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.438929E+01    MAXCV = 0.000000E+00
#    X =-1.194479E-01  -1.491889E-01  -5.495546E-01   1.652149E+00  -3.469755E-01
#        2.401537E-01   3.176662E-02   9.518264E-01   3.299087E-01  -6.793166E-01
#       -1.279632E-01  -2.313628E-02
#
# basinhopping step 3: f -34.3893 trial_f -34.3893 accepted 1  lowest_f -34.5417
# warning: basinhopping: local minimization failure
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.379332E+01    MAXCV = 0.000000E+00
#    X = 5.518948E-03   4.924466E-01   7.955766E-02   1.298114E+00  -1.210367E-02
#        2.855591E-01  -2.148681E-02   1.485611E+00   2.165173E+00  -2.889217E-01
#       -4.626682E-01  -1.536898E-03
#
# basinhopping step 4: f -34.3893 trial_f -33.7933 accepted 0  lowest_f -34.5417
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -34.4521 trial_f -34.4521 accepted 1  lowest_f -34.5417
# Final cost function:
# -34.541718281441824
# Parameters yielding final value:
# [ 0.26419972  0.07386837  0.19596945  0.11673659  0.21627237  0.14206812
#  -0.02243482  0.01119591  0.07723092  0.09702126  0.10011649  0.10096144]
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  700   F =-3.445209E+01    MAXCV = 0.000000E+00
#    X = 6.725763E-03  -6.329710E-01  -4.593674E-01   2.301079E+00  -5.007669E-02
#       -2.345577E-01  -4.919992E-02   6.197973E-01   1.643954E+00  -4.297093E-01
#        2.152416E-01   2.342928E-01

# %%
from db_doi.utils_reporting import load_data,simulation_data_path
data_collection = load_data(simulation_data_path() + f"XXZ_HVA_data_L{20}")
print(data_collection.keys())
# Out:
# dict_keys(['E0', 'E1', 'HVA_Nlayers_1', 'HVA_Nlayers_2', 'HVA_Nlayers_3', 'HVA_Nlayers_4', 'HVA_Nlayers_5', 'HVA_Nlayers_6'])

# %%
plt.figure(figsize=(10, 6))
for nlayers in range(1,6+1):
    E_HVA = data_collection[f"HVA_Nlayers_{nlayers}"]["E_HVA"]
    plt.plot(nlayers, E_HVA, 'o', label=f'Nlayers={nlayers}')
    plt.plot(np.arange(1,6), [data_collection["E0"]]*5, 'k--', label='E0')

# %% [markdown]
# Task 2: Please run (and first fix) this brute force grid search for t1 t2 in HVA nlayer=1; I want to see a plot what is the landscape

# %%
fs = []
f2 = []
for t1 in np.linspace(-.31,.3,8):
    for t2 in np.linspace(-.3,.3,8):
        init_circ2, f, _ = H_XXZ.find_XXZ_HVA_circuit(nlayers=1,warm_start_qc=init_circ,initial_params=[t1,t2])
        fs.append(f)
        f2.append([t1,t2,f])
min_f = min(fs)
print("Minimum function value found:", min_f)

# %% [markdown]
# Task 3: add basinhopping as an option with a flag in XXZ_compilation utils and execute similar as above storing with added file name _basinhopping_ --- if basinhopping takes more than 2 hs then terminate or use less niter

# %%
a, x,z = H_XXZ.find_XXZ_HVA_circuit(nlayers=1, please_use_basinhopping=True)

# %%
init_circ, a,b = H_XXZ.find_XXZ_HVA_circuit(nlayers=1)

# %%
init_circ, _, _ = find_XXZ_HVA_circuit(H_XXZ,nlayers=4)

# %%
basinhopping_result_4_layers = [3.384042E-01,   1.290683E-01 ,  5.686232E-02,   1.402387E-01,   1.336091E-01,
       9.758775E-02,   1.067223E-02,   1.764419E-03]
basinhopping_result_4_layers_circuit = Circuit(L)

for n in range(4):    
    basinhopping_result_4_layers_circuit = H_XXZ.XXZ_HVA_circuit(basinhopping_result_4_layers[2*n], basinhopping_result_4_layers[2*n+1],
                                                                  qc=basinhopping_result_4_layers_circuit)

# %%
from dbf_dbqa.utils_reporting import take_verbose_step   
gci_hva3 = GroupCommutatorIteration(
    h=deepcopy(H_XXZ),
    preparation_circuit=init_circ,
    double_bracket_rotation_approximation_type=DoubleBracketRotationApproximationType.group_commutator_reduced)

gci_hva3.h.circuit = lambda t_duration: (
            deepcopy(gci_hva3.preparation_circuit)
            + gci_hva3.h.original_circuit(t_duration/2) + gci_hva3.h.original_circuit(t_duration/2)
            + gci_hva3.preparation_circuit.invert()
            )
#gci_hva3.double_bracket_rotation_approximation_type = DoubleBracketRotationApproximationType.group_commutator_third_order_reduced
take_verbose_step(gci_hva3,dbf)
take_verbose_step(gci_hva3,dbf)
take_verbose_step(gci_hva3,dbf)

# %%
from dbf_dbqa.utils_reporting import take_verbose_step   
gci_hva2 = GroupCommutatorIteration(
    h=deepcopy(H_XXZ),
    preparation_circuit=init_circ,
    double_bracket_rotation_approximation_type=DoubleBracketRotationApproximationType.group_commutator_reduced)
take_verbose_step(gci_hva2,dbf)

# %%
take_verbose_step(gci_hva2,dbf)

# %%
take_verbose_step(gci_hva2,dbf)

# %%
gci_hva3 = GroupCommutatorIteration(
    h=deepcopy(H_XXZ),
    preparation_circuit=init_circ3,
    double_bracket_rotation_approximation_type=DoubleBracketRotationApproximationType.group_commutator_reduced)
for i in range(3):
    take_verbose_step(gci_hva3,dbf)

# %%
from collections import Counter
two_qubit_counter = lambda circ: sum(1 for gate in circ.queue if len(gate.qubits) == 2)

dbf_dbqa_two_qubit_counts = [ two_qubit_counter(init_circ) ]
dbf_dbqa_energies =  [ gci_hva.loss() ]
for step in range(5):
    print("--------------------------")
    print(f"Step {step+1}")   

    step_grid = np.linspace(0.001, 0.05, 15)
    s_opt, s_min, losses, _ = gci_hva.choose_step(
        dbf, step_grid=step_grid)
    print("Step grid:", step_grid)
    print("Losses:", losses)
    print(f"Optimal step: {s_opt}")
    print(f"Minimum loss: {s_min}")
    plt.figure()
    plt.plot(step_grid, losses, marker='o')
    plt.xlabel('Step size')
    plt.ylabel('Loss')
    plt.title('Loss vs Step size for gci_hva.choose_step')
    plt.show()
   
    gci_hva(s_opt, dbf)
    print("Circuit analysis after:")
    print_gate_count_report(gci_hva.preparation_circuit)  
    dbf_dbqa_two_qubit_counts.append( two_qubit_counter(gci_hva.preparation_circuit))
    dbf_dbqa_energies.append( gci_hva.loss() )

# %%
plt.figure()
plt.plot(dbf_dbqa_two_qubit_counts, dbf_dbqa_energies, marker='o')
plt.xlabel('Two-qubit gate count')
plt.ylabel('Energy')
plt.title('Energy vs Two-qubit gate count for DBF-DBQA')
plt.show()

# %%
import pickle

def load_data(filename):
    with open(filename+'.pickle', 'rb') as file:
        # Load the object from the file
        data = pickle.load(file)
    return data

def run_param_rc(fontsize = 30):
        import matplotlib.pyplot as plt
        plt.rcParams['axes.labelsize'] = fontsize
        plt.rcParams['axes.titlesize'] = fontsize
        plt.rcParams['font.size'] = fontsize
        #set_matplotlib_formats('pdf', 'png')
        plt.rcParams['savefig.dpi'] = 75
        plt.rcParams['lines.linewidth'] = 2.0
        plt.rcParams['lines.markersize'] = 8
        plt.rcParams['legend.fontsize'] = 12
        plt.rcParams['legend.labelspacing'] = .3
        plt.rcParams['legend.columnspacing']= .3
        plt.rcParams['legend.handletextpad']= .1
        plt.rcParams['text.usetex'] = True
        plt.rcParams['font.family'] = "serif"
        plt.rcParams['font.serif'] = "cm"

path = "../simulation_results/Qrisp_simulations_DB_QITE_and_QPE/data/benchmarks_2nd_L=16_05-21-18"
db_qite_simulation_results = load_data(path)
db_qite_energies = db_qite_simulation_results[1]['optimal_energies']
db_qite_cz_counts = [db_qite_simulation_results[0]['circuit_data'][0][i]['cz'] for i in range(len(db_qite_energies))]
print(db_qite_energies)

# %%
plt.figure()
plt.plot(dbf_dbqa_two_qubit_counts, dbf_dbqa_energies, marker='o')
plt.plot(db_qite_cz_counts, db_qite_energies, marker='x', label='DB-QITE')
plt.xlabel('Two-qubit gate count')
plt.ylabel('Energy')
plt.title('Energy vs Two-qubit gate count for DBF-DBQA')
plt.show()

# %%
from dbf_dbqa.utils_reporting import take_verbose_step   
take_verbose_step(gci_hva,dbf)

# %%
take_verbose_step(gci_hva,dbf)

# %%
take_verbose_step(gci_hva,dbf)

# %%
take_verbose_step(gci_hva,dbf)

# %%
from qrisp.operators import X, Y, Z

import numpy as np
import networkx as nx
from scipy.sparse.linalg import eigsh
import matplotlib.pyplot as plt

import pickle

def save_data(data, filename):  
    # Open a file for writing
    with open(filename+'.pickle', 'wb') as file:
        # Write the object to the file
        pickle.dump(data, file)

def load_data(filename):
    with open(filename+'.pickle', 'rb') as file:
        # Load the object from the file
        data = pickle.load(file)
    return data

def compute_moments(psi, H):
    E = (psi.conj().T @ H.dot(psi)).real
    S = (psi.conj().T @ (H @ H).dot(psi)).real
    return E, S, S - E**2

def run_param_rc(fontsize = 30):
        import matplotlib.pyplot as plt
        plt.rcParams['axes.labelsize'] = fontsize
        plt.rcParams['axes.titlesize'] = fontsize
        plt.rcParams['font.size'] = fontsize
        #set_matplotlib_formats('pdf', 'png')
        plt.rcParams['savefig.dpi'] = 75
        plt.rcParams['lines.linewidth'] = 2.0
        plt.rcParams['lines.markersize'] = 8
        plt.rcParams['legend.fontsize'] = 12
        plt.rcParams['legend.labelspacing'] = .3
        plt.rcParams['legend.columnspacing']= .3
        plt.rcParams['legend.handletextpad']= .1
        plt.rcParams['text.usetex'] = True
        plt.rcParams['font.family'] = "serif"
        plt.rcParams['font.serif'] = "cm"

# %%
path = "../simulation_results/Qrisp_simulations_DB_QITE_and_QPE/data/benchmarks_2nd_L=16_05-21-18"
db_qite_simulation_results = load_data(path)
print(db_qite_simulation_results[1]['optimal_energies'])

# %%
db_qite_simulation_results[1].keys()

# %%
print(db_qite_simulation_results[1]['optimal_energies'])

# %%
print(db_qite_simulation_results[1]['circuit_data'])

# %%
results_10 = load_data('data/benchmarks_2nd_L=10_05-21-16') 
results_12 = load_data('data/benchmarks_2nd_L=12_05-21-17')
results_14 = load_data('data/benchmarks_2nd_L=14_05-21-17')  
results_16 = load_data('data/benchmarks_2nd_L=16_05-21-18')  
results_18 = load_data('data/benchmarks_2nd_L=18_05-21-19')  
results_20 = load_data('data/benchmarks_2nd_L=20_05-21-22') 

results_QITE = dict()
results_QITE[10] = results_10
results_QITE[12] = results_12
results_QITE[14] = results_14
results_QITE[16] = results_16
results_QITE[18] = results_18
results_QITE[20] = results_20

# %%
def generate_plot_E_DBQITE(ax1, L):
    
    lables_energies=[r"~$~\ |\omega_0\rangle =|$Singlet$\rangle = 2^{-L/4}(|01\rangle-|10\rangle)^{\otimes L/2}$",
                     r"~$~\ |\omega_0\rangle =|$HVA$\rangle = U_\mathrm{HVA}|\mathrm{Singlet}\rangle$"]
    lables_fidelities=[r"$F_k\ |$Singlet$\rangle$",r"$F_k\ |$HVA$\rangle$"]
    alphas = [1.0, 0.6]
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    
    markers = ['o', 's', '^', 'v', '<', '>', 'd']
    indices = [0,1] 
    steps = [0,1,2,3,4,5]

    results = db_qite_simulation_results[L]

    ###############################################################################
    # SUBPLOT 1: Energy
    ###############################################################################

    # 1) Plot energies on the left y-axis
    #for i,ind in enumerate(indices):
        #line1, = ax1.plot(results[ind]['evolution_times'], results[ind]['optimal_energies'], label=lables_energies[ind], color='blue', marker=markers[i], linestyle='solid', linewidth=2, zorder=3, alpha=alphas[i])
    ind = indices[ 0]
    line1, = ax1.plot(steps, results[ind]['optimal_energies'], label=lables_energies[ind], 
                      color=colors[0], marker='v', linestyle='solid', linewidth=2, zorder=3, alpha = 0.6)
    ind = indices[1]
    line1, = ax1.plot(steps, results[ind]['optimal_energies'], label=lables_energies[ind],
                      color=colors[0], marker=markers[2], linestyle='solid', linewidth=2, zorder=3)

    ax1.axhline(y=E0_val[L], color="red", linestyle=':', alpha=1.0)
    #ax1.axhline(y=E0_val[L]+0.1, color="orange", linestyle=':', alpha=0.8)
    ax1.axhline(y=E1_val[L], color="red", linestyle=':', alpha=0.6)
    
    ax1.set_xlabel(r"Steps $k$")
    ax1.set_ylabel(r"Energy $E_k$")
    ax1.set_xticks(ticks = range(0, 6, 1))
    ax1.set_yticks(ticks = [-30,-31,-32,-33, -34,-35])
    ax1.legend(loc="center right", fontsize=15)
    ax1.set_title(f"DB-QITE for $L={L}$")

    ###############################################################################

    # 3) Combine legends from both axes
    lines_1, labels_1 = ax1.get_legend_handles_labels()
   
    ax1.legend(lines_1 , labels_1 , loc="best", ncol=1, fontsize=17)

run_param_rc(23)

index = 1 # 0 Singlet, 1 HVA
markers = ['o', 's', '^', 'v', '<', '>', 'd']
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']


fig, ((axE_QITE, axF_QITE, axF_QPE)) = plt.subplots(1, 3, figsize=(20, 5))#, gridspec_kw={"width_ratios": [4,2,10,1]})

###############################################################################
# SUBPLOT 1: Energy and fidelity QITE
###############################################################################

generate_plot_E_DBQITE(axE_QITE,20)
axE_QITE.annotate('a)', xy = (-.2, 1.05), xycoords='axes fraction')
axE_QITE.annotate(' ',
            xy=(5.2, E0_val[20]),  # theta, radius
            xytext=(5.2, -32.6),    # fraction, fraction
            textcoords='data',
            arrowprops=dict(facecolor='gray', shrink=0.001),
            horizontalalignment='left',
            verticalalignment='bottom')
axE_QITE.annotate(' ',
            xy=(4.8, -34),  # theta, radius
            xytext=(4.8, -33.1),    # fraction, fraction
            textcoords='data',
            arrowprops=dict(facecolor='gray', shrink=0.001),
            horizontalalignment='left',
            verticalalignment='bottom')
axE_QITE.set_xlim([-0.1,5.35])
axE_QITE.text(
    4.4,           
    -33,       
    r"$\lambda_1$",                          
    va="center",
    ha="left",
    color="black",
    alpha = 0.6
)   

axE_QITE.text(
    4.8,           
    -32.5  ,           
    r"$\lambda_0$",                           
    va="center",
    ha="left",
    color="black"
    )
###############################################################################
# SUBPLOT 2: Fidelity and CZ count QITE
###############################################################################

#generate_fidelity_cz_qite(axF_QITE, "HVA")
ax = axF_QITE
init_type="HVA"

if init_type=="Singlet":
    index = 0
    ax.set_title(r"DB-QITE for $|$Singlet$\rangle$")
if init_type=="HVA":
    index = 1
    ax.set_title(r"DB-QITE for $|$HVA$\rangle$")

steps = list(range(0,6))

cz_data_qite = dict()

for i,L in enumerate(list(range(10,22,2))):
    results = db_qite_simulation_results[L]
    cz = np.array([results[index]["circuit_data"][0][k]['cz'] for k in steps])
    cz_data_qite[L] = cz

alphas =[0.5,0.75,1,0.7]
cz_count_HVA = {}
fidelities_HVA = {}
ax2 = ax.twinx()
for i,L in enumerate([12,16,20]):
    results = db_qite_simulation_results[L]

    psi = E0_vec[L] # ground state
    states = results[index]["statevectors"]
    fidelities = []
    for phi in states:
        fidelities.append(np.round(np.abs(np.dot(psi.conj().transpose(),phi))**2,3))

    cz_counts = cz_data_qite[L]
    cz_count_HVA[L] = cz_data_qite[L][0]
    fidelities_HVA[L] = fidelities[0]
    ax2.plot(cz_counts, fidelities, marker=markers[i], zorder = 4+i, label=f'$L={L}$',color= colors[0], alpha = alphas[i])


ax.legend(loc="best", ncols=2, fontsize=15)
#ax.set_xticks(ticks = range(0, 6, 1))
ax.set_xscale('log')
ax.set_xlabel(r"Number of CZ gates")
ax.set_ylabel(r"Fidelity $F_k$")
ax.set_title(r"DB-QITE and QPE for $|$HVA$\rangle$")

steps = list(range(1,6))

cz_data_qpe = dict()
for i,L in enumerate([12,16,20]):
    cz = [results_QPE[index][L][k]['ops']['cz'] for k in steps]
    cz.insert(0, cz_count_HVA[L])
    cz_data_qpe[L] = cz


for i,L in enumerate([12,16,20]):
    fidelities = [results_QPE[index][L][k]['F0'] for k in steps]
    fidelities.insert(0, fidelities_HVA[L])
    cz_counts = cz_data_qpe[L]
    #adding the initialization data
    ax.plot(cz_counts, fidelities, marker=markers[i], label=f'$L={L}$', zorder = i, color= colors[1], alpha = alphas[i], markerfacecolor='none')
if init_type=="HVA":
    steps = list(range(1,8))


ax.axhline(y=1, color="orange", linestyle=':', alpha=1.0,linewidth = 1)
ax.axhline(y=0.975, color="orange", linestyle=':', alpha=0.8,linewidth = 1)
ax.axhline(y=0.95, color="orange", linestyle=':', alpha=0.6,linewidth = 1)
ax.legend(loc="best", ncols=1, fontsize=16, title='QPE',title_fontsize='17', bbox_to_anchor=(0.715, 0.42))
ax2.legend(loc="best", ncols=1, fontsize=16, title='DB-QITE',title_fontsize='17', bbox_to_anchor=(0.715, 0.795))

ax.set_xscale('log')
#ax.set_xticks(ticks = range(1, 6, 1))
ax.set_xlabel(r"Number of CZ gates")   
ax.set_ylabel(r"Fidelity $F_k$")
    
axF_QITE.annotate('b)', xy = (-.2, 1.05), xycoords='axes fraction')
#axF_QITE.annotate(r'DB-QITE', xy=(1e4,0.98), textcoords='data', fontsize=15,rotation=90)
#axF_QITE.annotate(r'QPE', xy=(1e4,0.75), textcoords='data', fontsize=15,rotation=90)
###############################################################################
# SUBPLOT 3: Fidelity and CZ count QPE
###############################################################################

L = 20
index = 1 # HVA

results = db_qite_simulation_results[L]

psi = E0_vec[L] # ground state
states = results[index]["statevectors"]
fidelities = []
for phi in states:
    fidelities.append(np.round(np.abs(np.dot(psi.conj().transpose(),phi))**2,3))

cz_counts = cz_data_qite[L]
axF_QPE.plot(cz_counts, fidelities, marker=markers[2], label=f'DB-QITE',color= colors[0], alpha = alphas[i])

steps = list(range(1,6))
fidelities = [results_QPE[index][L][k]['F0'] for k in steps]
fidelities.insert(0, fidelities_HVA[L])
cz_counts = cz_data_qpe[L]
axF_QPE.plot(cz_counts, fidelities, marker=markers[2], label=f'QPE $[0,1)$', color= colors[1], alpha = 0.5)

steps = list(range(1,8))
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
fidelities = [results_QPE_rescaled_05[index][20][k]['F0'] for k in steps]
fidelities.insert(0, fidelities_HVA[L])
cz_counts = [results_QPE_rescaled_05[index][20][k]['ops']['cz'] for k in steps]
cz_counts.insert(0, cz_count_HVA[L])
axF_QPE.plot(cz_counts, fidelities, color=colors[1], label=f'QPE $[0,0.5)$'
             , marker=markers[3], markerfacecolor='none', alpha = 0.75)


fidelities = [results_QPE_rescaled_01[index][20][k]['F0'] for k in steps]
fidelities.insert(0, fidelities_HVA[L])
cz_counts = [results_QPE_rescaled_01[index][20][k]['ops']['cz'] for k in steps]
cz_counts.insert(0, cz_count_HVA[L])

axF_QPE.plot(cz_counts, fidelities, color=colors[1], label=f'QPE $[0,0.1)$'
             , marker=markers[4], markerfacecolor='none',alpha = 1)

axF_QPE.axhline(y=1, color="orange", linestyle=':', alpha=1.0,linewidth = 1)
axF_QPE.axhline(y=0.975, color="orange", linestyle=':', alpha=0.8,linewidth = 1)
axF_QPE.axhline(y=0.95, color="orange", linestyle=':', alpha=0.6,linewidth = 1)

axF_QPE.annotate('c)', xy = (-.12, 1.05), xycoords='axes fraction')
axF_QITE.annotate(r'$k=0$', xy=(37,0.917), textcoords='data', fontsize=17,zorder = 11)
axF_QITE.annotate(r'$k=1$', xy=(170,0.957), textcoords='data', fontsize=17,zorder = 12)
axF_QITE.annotate(r'$k=2$', xy=(625,0.983), textcoords='data', fontsize=17,zorder = 13)
#axF_QPE.annotate(r'$L=20,$', xy=(16100,0.87), textcoords='data', fontsize=15)
#axF_QPE.annotate(r'$[0,0.5)$', xy=(16100,0.85), textcoords='data', fontsize=15)
#axF_QPE.annotate(r'$L=20,$', xy=(39000,0.795), textcoords='data', fontsize=15)
#axF_QPE.annotate(r'$[0,0.1)$', xy=(39000,0.7753), textcoords='data', fontsize=15)
axF_QPE.set_xscale('log')
axF_QPE.set_xlabel(r"Number of CZ gates")  
axF_QPE.set_title(r"DB-QITE vs. spectral rescalings of QPE")
axF_QPE.legend(loc="upper left", ncols=1, fontsize=17)#,title=f'$L=20$',title_fontsize='15')
plt.tight_layout()
#plt.savefig("plots/QITE_Heisenberg_main.pdf")

# %%
# check rxx formula
t = 0.5
qc = Circuit(2)
qc.add(gates.RXX(0, 1, t*2))
x = np.array([[0,1], [1,0]])
xx = np.kron(x, x)
u = sp.linalg.expm(-1j*t*xx)
print(np.linalg.norm(u-qc.unitary())<1e-11)

# %%
def XXZ_simulation(nqubits, delta, t, trotter_steps=2, boundary="open", layer=3):
    qc = Circuit(nqubits)
    even_pairs = [(i, i+1) for i in range(0, nqubits-1, 2)]
    odd_pairs = [(i, i+1) for i in range(1, nqubits-1, 2)]
    if boundary == 'closed':
        odd_pairs.append((0, nqubits-1))
        
    dt_even = t/trotter_steps*2
    dt_odd = t/trotter_steps*2
    if layer == 3:
        dt_even /= 2
        
    for _ in range(trotter_steps):
        for i,j in even_pairs:
            qc.add(gates.RXX(i, j, dt_even))
            qc.add(gates.RYY(i, j, dt_even))
            qc.add(gates.RZZ(i, j, dt_even*delta))
        for i, j in odd_pairs:
            qc.add(gates.RXX(i, j, dt_odd))
            qc.add(gates.RYY(i, j, dt_odd))
            qc.add(gates.RZZ(i, j, dt_odd*delta))
        if layer == 3:
            for i,j in even_pairs:
                qc.add(gates.RXX(i, j, dt_even))
                qc.add(gates.RYY(i, j, dt_even))
                qc.add(gates.RZZ(i, j, dt_even*delta))
                
    return qc

# %%
# check hamiltonian simulation
L_test = 6
delta_test = 0.5
boundary_test = 'open'
H_test = construct_XXZ(L_test, delta_test, boundary_test)
t = 0.2
print(np.linalg.norm(sp.linalg.expm(-1j*t*H_test.matrix) - XXZ_simulation(L_test, delta_test, t, layer=3).unitary()))

# %% [markdown]
# ## Magnetic field
#
# RZ in qibo: $e^{-i\frac{\theta}{2}D}$

# %%
# magnetic field
def magnetic_field_circ(coefs, t):
    # implments e^{-itD}
    nqubits = len(coefs)
    qc = Circuit(nqubits)
    
    for idx, coef in enumerate(coefs):
        qc.add(gates.RZ(idx, coef*t*2))
    return qc

# %%
# test d formula
theta = 0.5
d = magnetic_field_circ([1], theta)
d_u = sp.linalg.expm(-1j*theta*np.array([[1,0],[0,-1]]))
print(np.linalg.norm(d.unitary()-d_u)<1e-3)

# %% [markdown]
# ## Construct GCI circuit
# In the initialization step, we have
# $$
# \bra{\psi_0(\theta)} H\ket{\psi_0(\theta)}=\bra{0}U_\theta^\dagger H U_\theta\ket{0}=\bra{0}A_0\ket{0}
# $$
# For one step of DBQA,
# $$
# V_1 = e^{itD}U^\dagger e^{-itH_0}Ue^{-itD}
# $$
# and that
# $$
# A_1 = V_1^\dagger U^\dagger H_0 U V_1.
# $$
#
# With this we find
# $$
# \langle 0|A_1|0\rangle =\langle \psi_1|H|\psi_1\rangle = \bra 0 U_1^\dagger H U_1\ket 0
# $$
# where
# $$
# |\psi_1\rangle = U* V_1|0\rangle.
# $$
#
# Therefore, our composed DBQA circuit should follow
#
# $$
# U_1 = U*V_1 = U_\theta e^{itD}U_\theta ^\dagger e^{-itH}U_\theta e^{-itD}
# $$
#
# $$
# U_1^{(RHOPF)} = U \cdot V_1^{(RHOPF)}=Ue^{-i\phi \sqrt t D}U^\dagger e^{-i\sqrt tH} U
#             e^{i(\phi+1)\sqrt t D}U^\dagger e^{i(1-\phi)\sqrt tH} U e^{-i\phi \sqrt t D}.
# $$

# %%
def GCI(H, H_sim_fun, D_circ_fun, init_circ, t):
    qc = Circuit(H.nqubits)
    H_sim = H_sim_fun(t)
    D_circ = D_circ_fun(t)
    qc.wire_names = init_circ.wire_names
    D_circ.wire_names = qc.wire_names
    H_sim.wire_names = qc.wire_names
    qc = qc + D_circ + init_circ + H_sim + init_circ.invert() + D_circ.invert() + init_circ
    return qc, h_expectation_from_circ(H, qc)

# %%
# test t=0 same value as E_init
t = 0
coefs = [1] * L
H_sim_fun = lambda t: XXZ_simulation(L, delta, t)
D_circ_fun = lambda t: magnetic_field_circ(coefs, t)
gci_circ, gci_val = GCI(H_XXZ, H_sim_fun, D_circ_fun, init_circ, t)
print(np.abs(gci_val-h_expectation_from_circ(H_XXZ, init_circ))<1e-3)

# %%
run_grid_search = False
if run_grid_search:
    t_space = np.linspace(0,0.3,20)
    E_ls = []
    for t in t_space:
        gci_circ, gci_val = GCI(H_XXZ, H_sim_fun, D_circ_fun, init_circ, t)
        E_ls.append(gci_val)

# %%
if run_grid_search:
    E_min = min(E_ls)
    min_idx = E_ls.index(E_min)
    t_min = t_space[min_idx]
    plt.plot(t_space, E_ls)
    plt.scatter(t_min, E_min, color='red', label=f"({t_min:.2f}, {E_min:.2f})")
    plt.title(f'DBQA gain with time - XXZ (L={L})')
    plt.xlabel('time')
    plt.ylabel(r'$\langle H\rangle$')
    plt.legend()

# %%
gci_circ.gate_names

# %%
print("Circuit depth:", gci_circ.depth)
print("Circuit total gate count:", gci_circ.ngates)
print("Circuit CX count:", gci_circ.gate_names['cx'])
print("Estimated equivalent CZ count:", gci_circ.gate_names['cx']+
      gci_circ.gate_names['rxx']+gci_circ.gate_names['ryy']+gci_circ.gate_names['rzz']
      )

# %% [markdown]
# ## Optimize parameters

# %% [markdown]
# ### Fixed D optimize t
#
# Here we expect the same value as the grid search but faster run time.

# %%
from scipy.optimize import minimize_scalar
coefs = [1] * L
def objective(t):
    H_sim_fun = lambda t: XXZ_simulation(L, delta, t)
    D_circ_fun = lambda t: magnetic_field_circ(coefs, t)
    gci_circ, gci_val = GCI(H_XXZ, H_sim_fun, D_circ_fun, init_circ, t)
    return gci_val

# %%
res = minimize_scalar(
    objective,                  
    method='brent',    
    options={'maxiter': 15,
             'xtol': 1e-3} 
)
print(res.fun)
print(res.x)

# %% [markdown]
# ### Optimize both D and t

# %%
from scipy.optimize import minimize
coefs = [1] * L
D_s = coefs + [0.1]
def objective(D_s):
    coefs = D_s[:-1]
    t = D_s[-1]
    H_sim_fun = lambda t: XXZ_simulation(L, delta, t)
    D_circ_fun = lambda t: magnetic_field_circ(coefs, t)
    gci_circ, gci_val = GCI(H_XXZ, H_sim_fun, D_circ_fun, init_circ, t)
    return gci_val

# %%
max_iter = 1000
result = minimize(
    objective,
    D_s,
    method="COBYLA",
    options={"disp": True, "maxiter": max_iter},
    tol=1e-2,
)

print(result.fun)
print(result.x)
